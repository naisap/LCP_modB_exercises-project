# %% [markdown]
# # CASE 1: **Harmonic oscillator potential**

# %% [markdown]
# ### 1. Inizialization

# %%
# %matplotlib inline

import numpy as np
import matplotlib.pyplot as plt
from scipy.constants import Boltzmann as kB
from numpy.random import randn as gauss
from numpy.random import rand as uniform

case_study = '1D_harmonic'

# %% [markdown]
# ### 2. Generate Trajectories
#
#
# Here it's defined the function that simulates the motion of the Brownian particle in the force field. Particularly, in this case of study, we consider a Brownian particle in a double well trap. The trajectory of the particle depends on two target parameters: the equilibrium distance L and the potential energy barrier height H.
#
# Comments:
#
# 1. The function that simulates the trajectories is *simulate_trajectory*.
# 2. Lambda functions scale_inputs, rescale_inputs, scale_targets, and rescale_targets must also be defined. For the best performance of the learning, the rescaling of both the inputs and targets should lead to values of order 1.

# %%
## define parameters
normal_values = True

# %%
if normal_values == True:
    
    ### follows the parameters used in DeepCalib
    
    ### Physical parameters 
    R = 1e-7                                # Radius of the Brownian particle [m]
    eta = 0.001                             # Viscosity of the medium [kg m^-1 s^-1]
    T = 300                                 # Temperature [K]
    k0 = 10                                 # Reference stiffness [fN \mu m ^-1]
    gamma0 = 6 * np.pi * eta * R            # Reference friction coefficient [kg s^-1]

    ### Simulation parameters
    N = 1000                   # Number of samples of the trajectory
    Dt = 1e-2                  # Timestep 
    oversampling = 5           # Simulation oversampling
    offset = 1000              # Number of equilibration timesteps
    batch_size = 32            # Number of trajectories

    ### Define functions to scale and rescale inputs
    scale_inputs = lambda x: x * 1e+6                    # Scales input trajectory to order 1
    rescale_inputs = lambda scaled_x: scaled_x * 1e-6    # Rescales input trajectory to physical units

    ### Define function to scale and rescale targets
    scale_targets = lambda k: np.log(k / k0)                               # Scales targets to order 1
    rescale_targets = lambda scaled_k: np.exp(scaled_k) * k0               # Inverse of targets_scaling

    def simulate_trajectory(batch_size=batch_size, 
                        T=T,
                        k0=k0,
                        gamma0=gamma0,
                        N=N, 
                        Dt=Dt, 
                        oversampling=oversampling, 
                        offset=offset):
    
        ### Randomize trajectory parameters
        k = k0 * (10**(uniform(batch_size) * 3 - 1.5))     # Generates random stiffness values that are uniformly distributed in log scale
        gamma = gamma0 * (uniform(batch_size) * .1 + .95)   # Marginal randomization of friction coefficient to tolarate small changes

        ### Simulate
        dt = Dt / oversampling                 # time step of the simulation
        x = np.zeros((batch_size, N))          # initialization of the x array
        D = kB * T / gamma                     # diffusion coefficient
        C1 = -k *1e-9 / gamma * dt             # drift coefficient of the Langevin equation
        C3 = np.sqrt(2 * D * dt)               # random walk coefficient of the Langevin equation
        X = x[:, 0]
        n = 0
        
        for t in range(offset):                      # Offset (for some prerun before running)
            X = X + C1 * X + C3 * gauss(batch_size)
            
        for t in range(N * oversampling):            # Simulation                
            X = X + C1 * X + C3 * gauss(batch_size)
            if t % oversampling == 0:                # We save every oversampling^th values 
                x[:, n] = X 
                n += 1
                
        inputs = scale_inputs(x)
        inputs_real = x
        targets = scale_targets(k)
        target_real = k

        return inputs, inputs_real, targets, target_real




else:
    ### larger values: natural units
    
    ### Physical parameters 
    R = 1                                   # Radius of the Brownian particle [m]
    eta = 0.001                             # Viscosity of the medium [kg m^-1 s^-1]
    kB = 1                                  # Boltzmann constant
    T = 1                                   # Temperature [K]
    k0 = 1                                  # Reference stiffness [fN \mu m ^-1]
    gamma0 = 1                              # Reference friction coefficient [kg s^-1]

    ### Simulation parameters
    N = 1000                         # Number of samples of the trajectory
    Dt = 2e-1                       # Timestep 
    oversampling = 5                  # Simulation oversampling
    offset = 1000                     # Number of equilibration timesteps
    batch_size = 32                   # Number of trajectories

    ### Define functions to scale and rescale inputs
    scale_inputs = lambda x: x * 1e+6                    # Scales input trajectory to order 1
    rescale_inputs = lambda scaled_x: scaled_x * 1e-6    # Rescales input trajectory to physical units

    ### Define function to scale and rescale targets
    scale_targets = lambda k: np.log(k / k0)                               # Scales targets to order 1
    rescale_targets = lambda scaled_k: np.exp(scaled_k) * k0               # Inverse of targets_scaling

    def simulate_trajectory(batch_size=batch_size, 
                        T=T,
                        k0=k0,
                        gamma0=gamma0,
                        N=N, 
                        Dt=Dt, 
                        oversampling=oversampling, 
                        offset=offset):#, 
                        #scale_inputs=scale_inputs, 
                        #scale_targets=scale_targets):
    
        ### Randomize trajectory parameters
        k = k0 * (10**(uniform(batch_size) * 3 - 1.5))      # Generates random stiffness values that are uniformly distributed in log scale
        gamma = gamma0 * (uniform(batch_size) * .1 + .95)   # Marginal randomization of friction coefficient to tolarate small changes

        ### Simulate
        dt = Dt / oversampling                 # time step of the simulation
        x = np.zeros((batch_size, N))          # initialization of the x array
        D = 1                                  # diffusion coefficient
        C1 = -k * 1 / 1 * dt                   # drift coefficient of the Langevin equation
        C3 = np.sqrt(2 * D * dt)               # random walk coefficient of the Langevin equation
        X = x[:, 0]
        n = 0
        
        for t in range(offset):                      # Offset (for some prerun before running)
            X = X + C1 * X + C3 * gauss(batch_size)
            
        for t in range(N * oversampling):            # Simulation                
            X = X + C1 * X + C3 * gauss(batch_size)
            if t % oversampling == 0:                # We save every oversampling^th values 
                x[:, n] = X 
                n += 1
                
        inputs = scale_inputs(x*1e-6)
        inputs_real = x*1e-6
        targets = scale_targets(k)
        target_real = k

        return inputs, inputs_real, targets, target_real

# %% [markdown]
# ### 3. Plot Trajectory Simulation

# %%
def plot_sample_trajectories(simulate_trajectory, number_of_trajectories_to_show):
    """
    
    Inputs:   
    
    simulate_trajectory:                 trajectroy generator function
    number_of_trajectories_to_show:      number of trajectories to be plotted as sample  
        
    Output:
    
    This function does not return any outputs, it only plots some sample trajectories to preview the generator function
   
    """ 
    import matplotlib.pyplot as plt
    inputs, targets = simulate_trajectory(number_of_trajectories_to_show)
    
    if len(inputs.names)>1:
        for scaled_values, scaled_targets, target_values in zip(inputs.scaled_values, targets.scaled_values, targets.values):
            plt.figure(figsize=(20, 5))    
            number_subplots = len(inputs.names)
            for subplot in range(number_subplots):
                plt.subplot(1, number_subplots, subplot+1)
                plt.plot(scaled_values[subplot])
                plt.xlabel('timestep', fontsize=18)
                plt.ylabel(inputs.scalings[subplot], fontsize=18)   

            title_text = 'Parameters: ' 
            for parameter in range(len(target_values)):
                title_text +=  ', ' + targets.names[parameter] + ' = ' + '%1.2e' % target_values[parameter]
            plt.title(title_text, fontsize=18)  

    else:
        for scaled_values, scaled_targets, target_values in zip(inputs.scaled_values, targets.scaled_values, targets.values):
            plt.figure(figsize=(20, 5))
            plt.plot(scaled_values)
            plt.xlabel('timestep', fontsize=18)
            plt.ylabel(inputs.scalings[0], fontsize=18)
            title_text = 'Parameters: ' 
            if len(targets.names)>1:
                for parameter in range(len(targets.names)):
                    title_text +=  ', ' + targets.names[parameter] + ' = ' + '%1.2e' % target_values[parameter]
                plt.title(title_text, fontsize=18)  
            else:
                plt.title(title_text + ' ' + targets.names[0] + ' = ' + '%1.2e' % target_values , fontsize=18)

# %%
### Show some examples of simulated trajectories
number_of_trajectories_to_show= 10
plot_sample_trajectories(simulate_trajectory, number_of_trajectories_to_show)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[5], line 3
#       1 ### Show some examples of simulated trajectories
#       2 number_of_trajectories_to_show= 10
# ----> 3 plot_sample_trajectories(simulate_trajectory, number_of_trajectories_to_show)
#
# Cell In[4], line 15, in plot_sample_trajectories(simulate_trajectory, number_of_trajectories_to_show)
#       2 """
#       3
#       4 Inputs:
#    (...)
#      12
#      13 """
#      14 import matplotlib.pyplot as plt
# ---> 15 inputs, targets = simulate_trajectory(number_of_trajectories_to_show)
#      17 if len(inputs.names)>1:
#      18     for scaled_values, scaled_targets, target_values in zip(inputs.scaled_values, targets.scaled_values, targets.values):
#
# ValueError: too many values to unpack (expected 2)

# %%
trajectory, _, target, target_real = simulate_trajectory(batch_size)
print(trajectory[0,:].shape)
plt.plot(trajectory[0,:])
# Out:
# (1000,)

# %%
a=plt.hist(trajectory[0])#x[0])
plt.show()
a_1,a_2 = a[0],a[1]

plt.plot(a_2[:-1],-np.log(a_1))
plt.show()

# %% [markdown]
# ### 4. COMPILE Deep Neural Network
#
# The parameters of the deep learning network are defined and the network created. The summary of the network is printed where the output shape and number of parameters for each layer can be visualized.
#
# Comments:
#
# 1. The parameter input_shape determines the shape of the input sequence, given by the number of time-steps times the number of samples in each input sequence. Make sure your input shape dimensions match the length of the input trajectory, in this example 2 x 500 = 1000.
# 2. The parmameter conv_layers_dimensions determines the number and size of LSTM layers.
# 3. The parameter number_of_outputs determines the number of outputs, i.e. the number of force field parameters to be estimated.

# %% [markdown]
# #### LSTM with attention
#
# CREATE MODEL

# %%
from src_models import models_DNN, train_DNN, test_DNN
# Out:
# 2023-06-22 20:18:45.026045: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 AVX512F AVX512_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
### Define parameters of the deep learning network
input_shape = (20, 50)      
lstm_layers_dimensions = (250, 50)
number_of_outputs = 1

DNN = 'LSTM'
attention = True

### Create deep learning network
network = models_DNN.create_deep_learning_network(input_shape, lstm_layers_dimensions, number_of_outputs, 
                                                      DNN,
                                                      attention)

### Print deep learning network summary
network.summary()
# Out:
# 2023-06-22 20:19:00.876061: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 AVX512F AVX512_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-06-22 20:19:00.876494: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 2. Tune using inter_op_parallelism_threads for best performance.
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 20, 50)]          0
#
#  lstm_0 (LSTM)               (None, 20, 250)           301000
#
#  lstm_1 (LSTM)               (None, 20, 50)            60200
#
#  attention (Attention)       (None, 50)                70
#
#  output (Dense)              (None, 1)                 51
#
# =================================================================
# Total params: 361,321
# Trainable params: 361,321
# Non-trainable params: 0
# _________________________________________________________________
# /home/david/anaconda3/envs/firstenv/lib/python3.10/site-packages/keras/optimizers/optimizer_v2/adam.py:117: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super().__init__(name, **kwargs)

# %% [markdown]
# ### 5. TRAIN Deep Neural Network
#
# The parameters for the training of the deep learning network are defined and the network is trained. The sample size, iteration number, MSE, MAE and the time of each iteration is printed.
#
# Comments:
#
# The parameter sample_sizes determines the sizes of the batches of trajectories used in the training.
# The parameter iteration_numbers determines the numbers of batches used in the training.
# The parameter verbose determines the frequency of the update messages. It can be either a boolean value (True/False) or a number between 0 and 1.

# %%
# %%time

sample_sizes = (32, 128, 512)#(32, 128, 512, 2048),
iteration_numbers = (3001, 2001, 1001)#(1001, 2001, 3001),#(3001, 2001, 1001, 101),
verbose = .1

training_history = train_DNN.train_deep_learning_network(network, simulate_trajectory, sample_sizes, iteration_numbers, verbose)
# Out:
# Sample size     32   iteration number      1   MSE     3.1884   MAE     1.5388   Time 6384.631872 ms
# Sample size     32   iteration number     11   MSE     1.0433   MAE     0.7864   Time 647.514105 ms
# Sample size     32   iteration number     21   MSE     0.8740   MAE     0.7916   Time 437.251806 ms
# Sample size     32   iteration number     31   MSE     0.5092   MAE     0.5967   Time 626.841545 ms
# Sample size     32   iteration number     41   MSE     0.3786   MAE     0.4879   Time 350.574493 ms
# Sample size     32   iteration number     51   MSE     0.2162   MAE     0.3773   Time 814.268112 ms
# Sample size     32   iteration number     61   MSE     0.2659   MAE     0.3974   Time 451.696873 ms
# Sample size     32   iteration number     71   MSE     0.1663   MAE     0.3253   Time 662.829876 ms
# Sample size     32   iteration number     81   MSE     0.4039   MAE     0.4825   Time 1064.558268 ms
# Sample size     32   iteration number     91   MSE     0.1562   MAE     0.3149   Time 1086.317062 ms
# Sample size     32   iteration number    101   MSE     0.2677   MAE     0.4276   Time 1154.892206 ms
# Sample size     32   iteration number    111   MSE     0.1035   MAE     0.2617   Time 471.333504 ms
# Sample size     32   iteration number    121   MSE     0.1703   MAE     0.3140   Time 436.555147 ms
# Sample size     32   iteration number    131   MSE     0.2687   MAE     0.4171   Time 661.239386 ms
# Sample size     32   iteration number    141   MSE     0.2041   MAE     0.3329   Time 374.863863 ms
# Sample size     32   iteration number    151   MSE     0.3494   MAE     0.4049   Time 299.514771 ms
# Sample size     32   iteration number    161   MSE     0.1682   MAE     0.2907   Time 428.218603 ms
# Sample size     32   iteration number    171   MSE     0.0912   MAE     0.2356   Time 515.560389 ms
# Sample size     32   iteration number    181   MSE     0.2411   MAE     0.3583   Time 621.391773 ms
# Sample size     32   iteration number    191   MSE     0.1946   MAE     0.3080   Time 687.640905 ms
# Sample size     32   iteration number    201   MSE     0.1675   MAE     0.2879   Time 239.296913 ms
# Sample size     32   iteration number    211   MSE     0.0651   MAE     0.2118   Time 401.857138 ms
# Sample size     32   iteration number    221   MSE     0.2016   MAE     0.3876   Time 281.981707 ms
# Sample size     32   iteration number    231   MSE     0.1396   MAE     0.2982   Time 249.850512 ms
# Sample size     32   iteration number    241   MSE     0.1824   MAE     0.2673   Time 288.481236 ms
# Sample size     32   iteration number    251   MSE     0.1831   MAE     0.3218   Time 300.468445 ms
# Sample size     32   iteration number    261   MSE     0.0951   MAE     0.2397   Time 292.169571 ms
# Sample size     32   iteration number    271   MSE     0.1034   MAE     0.2361   Time 232.905865 ms
# Sample size     32   iteration number    281   MSE     0.1015   MAE     0.2481   Time 257.642746 ms
# Sample size     32   iteration number    291   MSE     0.1642   MAE     0.3185   Time 131.122589 ms
# Sample size     32   iteration number    301   MSE     0.1959   MAE     0.3317   Time 225.099325 ms
# Sample size     32   iteration number    311   MSE     0.2732   MAE     0.3564   Time 247.279644 ms
# Sample size     32   iteration number    321   MSE     0.1141   MAE     0.2649   Time 249.777555 ms
# Sample size     32   iteration number    331   MSE     0.1302   MAE     0.2964   Time 415.459633 ms
# Sample size     32   iteration number    341   MSE     0.1502   MAE     0.2765   Time 236.287355 ms
# Sample size     32   iteration number    351   MSE     0.0820   MAE     0.2175   Time 265.745640 ms
# Sample size     32   iteration number    361   MSE     0.0893   MAE     0.2368   Time 256.692410 ms
# Sample size     32   iteration number    371   MSE     0.1240   MAE     0.2550   Time 334.779739 ms
# Sample size     32   iteration number    381   MSE     0.1176   MAE     0.2759   Time 176.796436 ms
# Sample size     32   iteration number    391   MSE     0.1322   MAE     0.2672   Time 248.537302 ms
# Sample size     32   iteration number    401   MSE     0.1362   MAE     0.2870   Time 139.630795 ms
# Sample size     32   iteration number    411   MSE     0.1498   MAE     0.2985   Time 242.450953 ms
# Sample size     32   iteration number    421   MSE     0.1399   MAE     0.2967   Time 250.959158 ms
# Sample size     32   iteration number    431   MSE     0.1192   MAE     0.2478   Time 250.276566 ms
# Sample size     32   iteration number    441   MSE     0.0914   MAE     0.2338   Time 284.585476 ms
# Sample size     32   iteration number    451   MSE     0.1457   MAE     0.2765   Time 427.749395 ms
# Sample size     32   iteration number    461   MSE     0.1933   MAE     0.2911   Time 530.972719 ms
# Sample size     32   iteration number    471   MSE     0.1087   MAE     0.2680   Time 165.279627 ms
# Sample size     32   iteration number    481   MSE     0.1470   MAE     0.2559   Time 188.981056 ms
# Sample size     32   iteration number    491   MSE     0.0744   MAE     0.2216   Time 229.825735 ms
# Sample size     32   iteration number    501   MSE     0.1934   MAE     0.3192   Time 398.910284 ms
# Sample size     32   iteration number    511   MSE     0.1136   MAE     0.2594   Time 264.047861 ms
# Sample size     32   iteration number    521   MSE     0.2854   MAE     0.3674   Time 716.812134 ms
# Sample size     32   iteration number    531   MSE     0.1522   MAE     0.2737   Time 221.709728 ms
# Sample size     32   iteration number    541   MSE     0.0559   MAE     0.1974   Time 231.845617 ms
# Sample size     32   iteration number    551   MSE     0.1220   MAE     0.2420   Time 278.537750 ms
# Sample size     32   iteration number    561   MSE     0.0777   MAE     0.2187   Time 195.837498 ms
# Sample size     32   iteration number    571   MSE     0.1291   MAE     0.2955   Time 340.557337 ms
# Sample size     32   iteration number    581   MSE     0.0652   MAE     0.1883   Time 786.501408 ms
# Sample size     32   iteration number    591   MSE     0.1586   MAE     0.2887   Time 430.874348 ms
# Sample size     32   iteration number    601   MSE     0.1439   MAE     0.2660   Time 670.768023 ms
# Sample size     32   iteration number    611   MSE     0.1805   MAE     0.2937   Time 757.393599 ms
# Sample size     32   iteration number    621   MSE     0.1147   MAE     0.2263   Time 435.379982 ms
# Sample size     32   iteration number    631   MSE     0.0782   MAE     0.2012   Time 390.713215 ms
# Sample size     32   iteration number    641   MSE     0.2289   MAE     0.3122   Time 470.592260 ms
# Sample size     32   iteration number    651   MSE     0.0561   MAE     0.1891   Time 476.777077 ms
# Sample size     32   iteration number    661   MSE     0.1356   MAE     0.2681   Time 1188.163042 ms
# Sample size     32   iteration number    671   MSE     0.1756   MAE     0.3219   Time 883.077860 ms
# Sample size     32   iteration number    681   MSE     0.0989   MAE     0.2289   Time 552.575111 ms
# Sample size     32   iteration number    691   MSE     0.1874   MAE     0.3137   Time 435.831547 ms
# Sample size     32   iteration number    701   MSE     0.1474   MAE     0.2653   Time 650.806427 ms
# Sample size     32   iteration number    711   MSE     0.1558   MAE     0.2799   Time 493.858576 ms
# Sample size     32   iteration number    721   MSE     0.1167   MAE     0.2527   Time 732.031107 ms
# Sample size     32   iteration number    731   MSE     0.0871   MAE     0.2251   Time 281.327009 ms
# Sample size     32   iteration number    741   MSE     0.1109   MAE     0.2573   Time 799.264193 ms
# Sample size     32   iteration number    751   MSE     0.1351   MAE     0.2394   Time 398.498058 ms
# Sample size     32   iteration number    761   MSE     0.1385   MAE     0.2471   Time 765.100479 ms
# Sample size     32   iteration number    771   MSE     0.1272   MAE     0.2727   Time 682.828903 ms
# Sample size     32   iteration number    781   MSE     0.0978   MAE     0.2390   Time 366.618395 ms
# Sample size     32   iteration number    791   MSE     0.0713   MAE     0.1954   Time 557.829618 ms
# Sample size     32   iteration number    801   MSE     0.1011   MAE     0.2261   Time 365.104914 ms
# Sample size     32   iteration number    811   MSE     0.1492   MAE     0.2709   Time 1013.103247 ms
# Sample size     32   iteration number    821   MSE     0.1127   MAE     0.2408   Time 820.668936 ms
# Sample size     32   iteration number    831   MSE     0.0622   MAE     0.1846   Time 1007.483244 ms
# Sample size     32   iteration number    841   MSE     0.0928   MAE     0.2082   Time 656.250238 ms
# Sample size     32   iteration number    851   MSE     0.1417   MAE     0.2364   Time 395.251036 ms
# Sample size     32   iteration number    861   MSE     0.1228   MAE     0.2647   Time 315.335751 ms
# Sample size     32   iteration number    871   MSE     0.0612   MAE     0.1877   Time 446.422338 ms
# Sample size     32   iteration number    881   MSE     0.1116   MAE     0.2379   Time 271.114826 ms
# Sample size     32   iteration number    891   MSE     0.2263   MAE     0.3187   Time 380.959511 ms
# Sample size     32   iteration number    901   MSE     0.0798   MAE     0.2211   Time 862.060547 ms
# Sample size     32   iteration number    911   MSE     0.2514   MAE     0.3152   Time 680.718899 ms
# Sample size     32   iteration number    921   MSE     0.1130   MAE     0.2351   Time 526.761055 ms
# Sample size     32   iteration number    931   MSE     0.1959   MAE     0.3032   Time 360.852003 ms
# Sample size     32   iteration number    941   MSE     0.2135   MAE     0.3532   Time 373.554468 ms
# Sample size     32   iteration number    951   MSE     0.0696   MAE     0.1957   Time 502.866507 ms
# Sample size     32   iteration number    961   MSE     0.0601   MAE     0.1971   Time 970.930576 ms
# Sample size     32   iteration number    971   MSE     0.0711   MAE     0.1886   Time 262.810707 ms
# Sample size     32   iteration number    981   MSE     0.1776   MAE     0.2883   Time 1099.943638 ms
# Sample size     32   iteration number    991   MSE     0.1417   MAE     0.2675   Time 449.365854 ms
# Sample size     32   iteration number   1001   MSE     0.1687   MAE     0.2968   Time 448.894262 ms
# Sample size     32   iteration number   1011   MSE     0.0746   MAE     0.1938   Time 555.382013 ms
# Sample size     32   iteration number   1021   MSE     0.1204   MAE     0.2342   Time 444.452524 ms
# Sample size     32   iteration number   1031   MSE     0.1294   MAE     0.2553   Time 612.544775 ms
# Sample size     32   iteration number   1041   MSE     0.0597   MAE     0.1787   Time 304.574490 ms
# Sample size     32   iteration number   1051   MSE     0.1401   MAE     0.2476   Time 884.763956 ms
# Sample size     32   iteration number   1061   MSE     0.1112   MAE     0.2595   Time 838.448524 ms
# Sample size     32   iteration number   1071   MSE     0.1258   MAE     0.2420   Time 855.720758 ms
# Sample size     32   iteration number   1081   MSE     0.0815   MAE     0.1803   Time 403.953314 ms
# Sample size     32   iteration number   1091   MSE     0.1088   MAE     0.2144   Time 639.701128 ms
# Sample size     32   iteration number   1101   MSE     0.1311   MAE     0.2821   Time 1033.970594 ms
# Sample size     32   iteration number   1111   MSE     0.0606   MAE     0.1769   Time 429.674625 ms
# Sample size     32   iteration number   1121   MSE     0.2022   MAE     0.3119   Time 430.493832 ms
# Sample size     32   iteration number   1131   MSE     0.0748   MAE     0.2059   Time 331.573486 ms
# Sample size     32   iteration number   1141   MSE     0.1274   MAE     0.2551   Time 745.214462 ms
# Sample size     32   iteration number   1151   MSE     0.0502   MAE     0.1566   Time 803.532362 ms
# Sample size     32   iteration number   1161   MSE     0.1333   MAE     0.2758   Time 497.398376 ms
# Sample size     32   iteration number   1171   MSE     0.0945   MAE     0.2519   Time 703.938723 ms
# Sample size     32   iteration number   1181   MSE     0.1303   MAE     0.2531   Time 734.412432 ms
# Sample size     32   iteration number   1191   MSE     0.0937   MAE     0.2319   Time 911.146641 ms
# Sample size     32   iteration number   1201   MSE     0.0678   MAE     0.1993   Time 448.929787 ms
# Sample size     32   iteration number   1211   MSE     0.0478   MAE     0.1652   Time 421.546459 ms
# Sample size     32   iteration number   1221   MSE     0.0653   MAE     0.1975   Time 418.179035 ms
# Sample size     32   iteration number   1231   MSE     0.2578   MAE     0.3417   Time 316.220999 ms
# Sample size     32   iteration number   1241   MSE     0.1362   MAE     0.2597   Time 580.599308 ms
# Sample size     32   iteration number   1251   MSE     0.0682   MAE     0.1995   Time 388.068676 ms
# Sample size     32   iteration number   1261   MSE     0.1365   MAE     0.2806   Time 489.157915 ms
# Sample size     32   iteration number   1271   MSE     0.0681   MAE     0.2012   Time 860.330820 ms
# Sample size     32   iteration number   1281   MSE     0.1160   MAE     0.2563   Time 342.636108 ms
# Sample size     32   iteration number   1291   MSE     0.0611   MAE     0.1595   Time 657.612085 ms
# Sample size     32   iteration number   1301   MSE     0.1602   MAE     0.2806   Time 625.730991 ms
# Sample size     32   iteration number   1311   MSE     0.0798   MAE     0.2024   Time 820.341825 ms
# Sample size     32   iteration number   1321   MSE     0.0782   MAE     0.2051   Time 1020.214081 ms
# Sample size     32   iteration number   1331   MSE     0.1095   MAE     0.2350   Time 905.490398 ms
# Sample size     32   iteration number   1341   MSE     0.1104   MAE     0.2291   Time 735.906363 ms
# Sample size     32   iteration number   1351   MSE     0.0918   MAE     0.2010   Time 804.876804 ms
# Sample size     32   iteration number   1361   MSE     0.2324   MAE     0.3381   Time 445.076704 ms
# Sample size     32   iteration number   1371   MSE     0.0556   MAE     0.1801   Time 684.998274 ms
# Sample size     32   iteration number   1381   MSE     0.2091   MAE     0.3155   Time 439.051390 ms
# Sample size     32   iteration number   1391   MSE     0.1693   MAE     0.2921   Time 709.447145 ms
# Sample size     32   iteration number   1401   MSE     0.1478   MAE     0.2905   Time 326.322079 ms
# Sample size     32   iteration number   1411   MSE     0.1479   MAE     0.2499   Time 777.729750 ms
# Sample size     32   iteration number   1421   MSE     0.1051   MAE     0.2532   Time 492.881060 ms
# Sample size     32   iteration number   1431   MSE     0.1018   MAE     0.1939   Time 485.752583 ms
# Sample size     32   iteration number   1441   MSE     0.1570   MAE     0.2886   Time 906.409025 ms
# Sample size     32   iteration number   1451   MSE     0.0932   MAE     0.2225   Time 933.255911 ms
# Sample size     32   iteration number   1461   MSE     0.2136   MAE     0.2508   Time 987.091780 ms
# Sample size     32   iteration number   1471   MSE     0.2264   MAE     0.2628   Time 531.241179 ms
# Sample size     32   iteration number   1481   MSE     0.1385   MAE     0.2619   Time 297.088623 ms
# Sample size     32   iteration number   1491   MSE     0.1812   MAE     0.2842   Time 482.018948 ms
# Sample size     32   iteration number   1501   MSE     0.1160   MAE     0.1922   Time 651.782751 ms
# Sample size     32   iteration number   1511   MSE     0.0719   MAE     0.1999   Time 487.264872 ms
# Sample size     32   iteration number   1521   MSE     0.1373   MAE     0.2568   Time 555.888891 ms
# Sample size     32   iteration number   1531   MSE     0.0775   MAE     0.1973   Time 485.867739 ms
# Sample size     32   iteration number   1541   MSE     0.0971   MAE     0.2525   Time 435.271025 ms
# Sample size     32   iteration number   1551   MSE     0.1261   MAE     0.2722   Time 265.284061 ms
# Sample size     32   iteration number   1561   MSE     0.0858   MAE     0.1955   Time 406.275511 ms
# Sample size     32   iteration number   1571   MSE     0.1173   MAE     0.2629   Time 1028.732777 ms
# Sample size     32   iteration number   1581   MSE     0.1677   MAE     0.2644   Time 998.702288 ms
# Sample size     32   iteration number   1591   MSE     0.1319   MAE     0.2581   Time 527.187824 ms
# Sample size     32   iteration number   1601   MSE     0.0864   MAE     0.2108   Time 494.372368 ms
# Sample size     32   iteration number   1611   MSE     0.1245   MAE     0.2357   Time 858.299017 ms
# Sample size     32   iteration number   1621   MSE     0.0871   MAE     0.2270   Time 590.982199 ms
# Sample size     32   iteration number   1631   MSE     0.1329   MAE     0.2514   Time 574.691772 ms
# Sample size     32   iteration number   1641   MSE     0.0955   MAE     0.2196   Time 1125.947475 ms
# Sample size     32   iteration number   1651   MSE     0.0927   MAE     0.2329   Time 607.826948 ms
# Sample size     32   iteration number   1661   MSE     0.1457   MAE     0.2891   Time 781.890154 ms
# Sample size     32   iteration number   1671   MSE     0.0991   MAE     0.2468   Time 360.182285 ms
# Sample size     32   iteration number   1681   MSE     0.1618   MAE     0.2772   Time 409.315586 ms
# Sample size     32   iteration number   1691   MSE     0.1056   MAE     0.2432   Time 394.826174 ms
# Sample size     32   iteration number   1701   MSE     0.0428   MAE     0.1615   Time 525.059700 ms
# Sample size     32   iteration number   1711   MSE     0.2172   MAE     0.3220   Time 719.080448 ms
# Sample size     32   iteration number   1721   MSE     0.2111   MAE     0.3135   Time 624.441385 ms
# Sample size     32   iteration number   1731   MSE     0.1652   MAE     0.2889   Time 404.003620 ms
# Sample size     32   iteration number   1741   MSE     0.0414   MAE     0.1435   Time 430.936575 ms
# Sample size     32   iteration number   1751   MSE     0.1350   MAE     0.2717   Time 673.547506 ms
# Sample size     32   iteration number   1761   MSE     0.0964   MAE     0.2352   Time 958.174944 ms
# Sample size     32   iteration number   1771   MSE     0.1130   MAE     0.2445   Time 472.385645 ms
# Sample size     32   iteration number   1781   MSE     0.1234   MAE     0.2870   Time 661.591768 ms
# Sample size     32   iteration number   1791   MSE     0.1071   MAE     0.2145   Time 645.834684 ms
# Sample size     32   iteration number   1801   MSE     0.1870   MAE     0.2930   Time 724.236250 ms
# Sample size     32   iteration number   1811   MSE     0.0647   MAE     0.1806   Time 831.249475 ms
# Sample size     32   iteration number   1821   MSE     0.1037   MAE     0.2361   Time 1032.382488 ms
# Sample size     32   iteration number   1831   MSE     0.1399   MAE     0.2477   Time 561.867714 ms
# Sample size     32   iteration number   1841   MSE     0.1318   MAE     0.2661   Time 492.207289 ms
# Sample size     32   iteration number   1851   MSE     0.0483   MAE     0.1664   Time 339.312553 ms
# Sample size     32   iteration number   1861   MSE     0.1517   MAE     0.2434   Time 841.390133 ms
# Sample size     32   iteration number   1871   MSE     0.0800   MAE     0.2103   Time 554.816246 ms
# Sample size     32   iteration number   1881   MSE     0.1443   MAE     0.2811   Time 539.094925 ms
# Sample size     32   iteration number   1891   MSE     0.0769   MAE     0.1936   Time 501.161575 ms
# Sample size     32   iteration number   1901   MSE     0.0775   MAE     0.1970   Time 551.538706 ms
# Sample size     32   iteration number   1911   MSE     0.1037   MAE     0.2082   Time 595.759630 ms
# Sample size     32   iteration number   1921   MSE     0.0815   MAE     0.2232   Time 756.182194 ms
# Sample size     32   iteration number   1931   MSE     0.0718   MAE     0.2169   Time 965.744019 ms
# Sample size     32   iteration number   1941   MSE     0.1253   MAE     0.2267   Time 815.029383 ms
# Sample size     32   iteration number   1951   MSE     0.0620   MAE     0.1934   Time 436.674118 ms
# Sample size     32   iteration number   1961   MSE     0.1382   MAE     0.2800   Time 509.399652 ms
# Sample size     32   iteration number   1971   MSE     0.1143   MAE     0.1803   Time 325.963974 ms
# Sample size     32   iteration number   1981   MSE     0.1582   MAE     0.2398   Time 422.727823 ms
# Sample size     32   iteration number   1991   MSE     0.1277   MAE     0.1954   Time 570.012093 ms
# Sample size     32   iteration number   2001   MSE     0.0895   MAE     0.2338   Time 394.706249 ms
# Sample size     32   iteration number   2011   MSE     0.1006   MAE     0.2232   Time 392.799854 ms
# Sample size     32   iteration number   2021   MSE     0.1241   MAE     0.2155   Time 439.203501 ms
# Sample size     32   iteration number   2031   MSE     0.0730   MAE     0.2027   Time 395.958900 ms
# Sample size     32   iteration number   2041   MSE     0.0569   MAE     0.1927   Time 371.473551 ms
# Sample size     32   iteration number   2051   MSE     0.1193   MAE     0.2379   Time 511.433125 ms
# Sample size     32   iteration number   2061   MSE     0.1233   MAE     0.2376   Time 597.565413 ms
# Sample size     32   iteration number   2071   MSE     0.0373   MAE     0.1505   Time 506.323814 ms
# Sample size     32   iteration number   2081   MSE     0.2430   MAE     0.3169   Time 563.366890 ms
# Sample size     32   iteration number   2091   MSE     0.0565   MAE     0.1768   Time 586.076975 ms
# Sample size     32   iteration number   2101   MSE     0.0936   MAE     0.2052   Time 689.807653 ms
# Sample size     32   iteration number   2111   MSE     0.1323   MAE     0.2428   Time 406.471729 ms
# Sample size     32   iteration number   2121   MSE     0.1223   MAE     0.2658   Time 1168.704271 ms
# Sample size     32   iteration number   2131   MSE     0.1193   MAE     0.2387   Time 435.456753 ms
# Sample size     32   iteration number   2141   MSE     0.1220   MAE     0.2310   Time 675.315619 ms
# Sample size     32   iteration number   2151   MSE     0.1016   MAE     0.2409   Time 501.748323 ms
# Sample size     32   iteration number   2161   MSE     0.1536   MAE     0.2598   Time 513.639688 ms
# Sample size     32   iteration number   2171   MSE     0.0969   MAE     0.2426   Time 461.670637 ms
# Sample size     32   iteration number   2181   MSE     0.0914   MAE     0.2105   Time 611.373425 ms
# Sample size     32   iteration number   2191   MSE     0.1193   MAE     0.2398   Time 562.669039 ms
# Sample size     32   iteration number   2201   MSE     0.1076   MAE     0.2048   Time 324.967623 ms
# Sample size     32   iteration number   2211   MSE     0.0458   MAE     0.1761   Time 457.582951 ms
# Sample size     32   iteration number   2221   MSE     0.1072   MAE     0.2228   Time 568.399906 ms
# Sample size     32   iteration number   2231   MSE     0.1471   MAE     0.2764   Time 364.994287 ms
# Sample size     32   iteration number   2241   MSE     0.1726   MAE     0.2955   Time 633.600950 ms
# Sample size     32   iteration number   2251   MSE     0.1275   MAE     0.2245   Time 561.914682 ms
# Sample size     32   iteration number   2261   MSE     0.1387   MAE     0.2652   Time 364.353180 ms
# Sample size     32   iteration number   2271   MSE     0.1407   MAE     0.2699   Time 726.136446 ms
# Sample size     32   iteration number   2281   MSE     0.1117   MAE     0.2361   Time 263.381243 ms
# Sample size     32   iteration number   2291   MSE     0.1550   MAE     0.2793   Time 419.053078 ms
# Sample size     32   iteration number   2301   MSE     0.2047   MAE     0.2985   Time 1061.086178 ms
# Sample size     32   iteration number   2311   MSE     0.1048   MAE     0.2410   Time 735.327005 ms
# Sample size     32   iteration number   2321   MSE     0.0745   MAE     0.2236   Time 440.493345 ms
# Sample size     32   iteration number   2331   MSE     0.1502   MAE     0.2820   Time 284.947634 ms
# Sample size     32   iteration number   2341   MSE     0.0377   MAE     0.1428   Time 225.751877 ms
# Sample size     32   iteration number   2351   MSE     0.1027   MAE     0.2180   Time 718.700647 ms
# Sample size     32   iteration number   2361   MSE     0.1047   MAE     0.2496   Time 701.470137 ms
# Sample size     32   iteration number   2371   MSE     0.0668   MAE     0.1900   Time 533.567190 ms
# Sample size     32   iteration number   2381   MSE     0.1221   MAE     0.2406   Time 355.642080 ms
# Sample size     32   iteration number   2391   MSE     0.0789   MAE     0.2152   Time 613.303900 ms
# Sample size     32   iteration number   2401   MSE     0.1398   MAE     0.2483   Time 325.313330 ms
# Sample size     32   iteration number   2411   MSE     0.1278   MAE     0.2654   Time 364.746094 ms
# Sample size     32   iteration number   2421   MSE     0.1250   MAE     0.2536   Time 458.567858 ms
# Sample size     32   iteration number   2431   MSE     0.0674   MAE     0.1889   Time 322.414398 ms
# Sample size     32   iteration number   2441   MSE     0.1228   MAE     0.2635   Time 857.213497 ms
# Sample size     32   iteration number   2451   MSE     0.1013   MAE     0.2323   Time 528.854847 ms
# Sample size     32   iteration number   2461   MSE     0.0414   MAE     0.1458   Time 332.792044 ms
# Sample size     32   iteration number   2471   MSE     0.0551   MAE     0.1716   Time 976.837635 ms
# Sample size     32   iteration number   2481   MSE     0.1532   MAE     0.2855   Time 1072.199821 ms
# Sample size     32   iteration number   2491   MSE     0.1498   MAE     0.2410   Time 1166.039228 ms
# Sample size     32   iteration number   2501   MSE     0.0752   MAE     0.1884   Time 869.714022 ms
# Sample size     32   iteration number   2511   MSE     0.1618   MAE     0.2648   Time 552.264929 ms
# Sample size     32   iteration number   2521   MSE     0.0722   MAE     0.1913   Time 409.766674 ms
# Sample size     32   iteration number   2531   MSE     0.1658   MAE     0.2544   Time 524.748802 ms
# Sample size     32   iteration number   2541   MSE     0.0676   MAE     0.1902   Time 484.564781 ms
# Sample size     32   iteration number   2551   MSE     0.0620   MAE     0.1605   Time 857.387304 ms
# Sample size     32   iteration number   2561   MSE     0.1063   MAE     0.2355   Time 382.173777 ms
# Sample size     32   iteration number   2571   MSE     0.1300   MAE     0.2471   Time 425.755978 ms
# Sample size     32   iteration number   2581   MSE     0.1014   MAE     0.2353   Time 671.581745 ms
# Sample size     32   iteration number   2591   MSE     0.1068   MAE     0.2254   Time 350.739717 ms
# Sample size     32   iteration number   2601   MSE     0.0442   MAE     0.1384   Time 370.923996 ms
# Sample size     32   iteration number   2611   MSE     0.1005   MAE     0.2256   Time 693.572044 ms
# Sample size     32   iteration number   2621   MSE     0.0750   MAE     0.1944   Time 808.720589 ms
# Sample size     32   iteration number   2631   MSE     0.0857   MAE     0.2105   Time 521.851540 ms
# Sample size     32   iteration number   2641   MSE     0.0870   MAE     0.2115   Time 1101.930618 ms
# Sample size     32   iteration number   2651   MSE     0.0967   MAE     0.1977   Time 783.023357 ms
# Sample size     32   iteration number   2661   MSE     0.0775   MAE     0.1862   Time 457.283735 ms
# Sample size     32   iteration number   2671   MSE     0.0762   MAE     0.1988   Time 856.462717 ms
# Sample size     32   iteration number   2681   MSE     0.1090   MAE     0.2108   Time 735.110283 ms
# Sample size     32   iteration number   2691   MSE     0.0820   MAE     0.1964   Time 538.692951 ms
# Sample size     32   iteration number   2701   MSE     0.0827   MAE     0.1909   Time 646.623611 ms
# Sample size     32   iteration number   2711   MSE     0.1275   MAE     0.2517   Time 602.465153 ms
# Sample size     32   iteration number   2721   MSE     0.0762   MAE     0.2095   Time 354.172945 ms
# Sample size     32   iteration number   2731   MSE     0.0581   MAE     0.1651   Time 441.233873 ms
# Sample size     32   iteration number   2741   MSE     0.0650   MAE     0.1960   Time 605.100632 ms
# Sample size     32   iteration number   2751   MSE     0.1448   MAE     0.2439   Time 274.778605 ms
# Sample size     32   iteration number   2761   MSE     0.1139   MAE     0.2616   Time 789.970398 ms
# Sample size     32   iteration number   2771   MSE     0.1157   MAE     0.2500   Time 458.203793 ms
# Sample size     32   iteration number   2781   MSE     0.0656   MAE     0.2024   Time 529.314756 ms
# Sample size     32   iteration number   2791   MSE     0.0728   MAE     0.2063   Time 465.524673 ms
# Sample size     32   iteration number   2801   MSE     0.0470   MAE     0.1593   Time 422.573090 ms
# Sample size     32   iteration number   2811   MSE     0.1846   MAE     0.3136   Time 401.534557 ms
# Sample size     32   iteration number   2821   MSE     0.1857   MAE     0.2345   Time 482.497454 ms
# Sample size     32   iteration number   2831   MSE     0.0983   MAE     0.2267   Time 938.568830 ms
# Sample size     32   iteration number   2841   MSE     0.1864   MAE     0.2902   Time 378.159046 ms
# Sample size     32   iteration number   2851   MSE     0.0961   MAE     0.1828   Time 584.562778 ms
# Sample size     32   iteration number   2861   MSE     0.1170   MAE     0.2312   Time 586.524487 ms
# Sample size     32   iteration number   2871   MSE     0.0848   MAE     0.1774   Time 616.531610 ms
# Sample size     32   iteration number   2881   MSE     0.1273   MAE     0.2666   Time 498.923302 ms
# Sample size     32   iteration number   2891   MSE     0.0807   MAE     0.2032   Time 726.007700 ms
# Sample size     32   iteration number   2901   MSE     0.1264   MAE     0.2322   Time 383.074045 ms
# Sample size     32   iteration number   2911   MSE     0.1707   MAE     0.2982   Time 603.015423 ms
# Sample size     32   iteration number   2921   MSE     0.0779   MAE     0.1905   Time 298.346281 ms
# Sample size     32   iteration number   2931   MSE     0.1664   MAE     0.2722   Time 461.649179 ms
# Sample size     32   iteration number   2941   MSE     0.0658   MAE     0.1911   Time 293.611050 ms
# Sample size     32   iteration number   2951   MSE     0.1313   MAE     0.2566   Time 676.803589 ms
# Sample size     32   iteration number   2961   MSE     0.0428   MAE     0.1576   Time 418.407202 ms
# Sample size     32   iteration number   2971   MSE     0.0965   MAE     0.2137   Time 764.856577 ms
# Sample size     32   iteration number   2981   MSE     0.0777   MAE     0.2140   Time 562.287569 ms
# Sample size     32   iteration number   2991   MSE     0.1798   MAE     0.2860   Time 801.909685 ms
# Sample size     32   iteration number   3001   MSE     0.1335   MAE     0.2693   Time 576.313972 ms
# Sample size    128   iteration number      1   MSE     0.1265   MAE     0.2335   Time 4669.958830 ms
# Sample size    128   iteration number     11   MSE     0.1390   MAE     0.2501   Time 547.973871 ms
# Sample size    128   iteration number     21   MSE     0.1124   MAE     0.2292   Time 926.767588 ms
# Sample size    128   iteration number     31   MSE     0.1106   MAE     0.2220   Time 569.825411 ms
# Sample size    128   iteration number     41   MSE     0.1207   MAE     0.2339   Time 404.039145 ms
# Sample size    128   iteration number     51   MSE     0.0738   MAE     0.1937   Time 590.340614 ms
# Sample size    128   iteration number     61   MSE     0.1239   MAE     0.2414   Time 597.882271 ms
# Sample size    128   iteration number     71   MSE     0.0679   MAE     0.1802   Time 614.927292 ms
# Sample size    128   iteration number     81   MSE     0.1009   MAE     0.2297   Time 697.163105 ms
# Sample size    128   iteration number     91   MSE     0.1157   MAE     0.2367   Time 627.295256 ms
# Sample size    128   iteration number    101   MSE     0.0971   MAE     0.2170   Time 386.382580 ms
# Sample size    128   iteration number    111   MSE     0.0976   MAE     0.2109   Time 598.775387 ms
# Sample size    128   iteration number    121   MSE     0.1288   MAE     0.2370   Time 773.711920 ms
# Sample size    128   iteration number    131   MSE     0.0862   MAE     0.2078   Time 1080.415010 ms
# Sample size    128   iteration number    141   MSE     0.1392   MAE     0.2543   Time 404.776335 ms
# Sample size    128   iteration number    151   MSE     0.1297   MAE     0.2463   Time 491.065025 ms
# Sample size    128   iteration number    161   MSE     0.0784   MAE     0.1974   Time 1150.488615 ms
# Sample size    128   iteration number    171   MSE     0.1280   MAE     0.2510   Time 386.850119 ms
# Sample size    128   iteration number    181   MSE     0.1062   MAE     0.2307   Time 607.413769 ms
# Sample size    128   iteration number    191   MSE     0.0866   MAE     0.2004   Time 714.131594 ms
# Sample size    128   iteration number    201   MSE     0.0982   MAE     0.2138   Time 446.323872 ms
# Sample size    128   iteration number    211   MSE     0.1453   MAE     0.2553   Time 453.459978 ms
# Sample size    128   iteration number    221   MSE     0.1270   MAE     0.2383   Time 651.062965 ms
# Sample size    128   iteration number    231   MSE     0.1462   MAE     0.2472   Time 570.144176 ms
# Sample size    128   iteration number    241   MSE     0.1071   MAE     0.2074   Time 671.485901 ms
# Sample size    128   iteration number    251   MSE     0.1224   MAE     0.2337   Time 566.224813 ms
# Sample size    128   iteration number    261   MSE     0.1050   MAE     0.2242   Time 766.404390 ms
# Sample size    128   iteration number    271   MSE     0.1571   MAE     0.2675   Time 960.135460 ms
# Sample size    128   iteration number    281   MSE     0.0840   MAE     0.2014   Time 493.308783 ms
# Sample size    128   iteration number    291   MSE     0.1401   MAE     0.2634   Time 1192.913532 ms
# Sample size    128   iteration number    301   MSE     0.0914   MAE     0.2020   Time 759.021044 ms
# Sample size    128   iteration number    311   MSE     0.1300   MAE     0.2365   Time 428.737879 ms
# Sample size    128   iteration number    321   MSE     0.1272   MAE     0.2340   Time 590.639353 ms
# Sample size    128   iteration number    331   MSE     0.1105   MAE     0.2214   Time 514.207363 ms
# Sample size    128   iteration number    341   MSE     0.1136   MAE     0.2241   Time 1000.725985 ms
# Sample size    128   iteration number    351   MSE     0.0973   MAE     0.2048   Time 683.137178 ms
# Sample size    128   iteration number    361   MSE     0.1107   MAE     0.2283   Time 1102.150440 ms
# Sample size    128   iteration number    371   MSE     0.0871   MAE     0.2088   Time 703.398705 ms
# Sample size    128   iteration number    381   MSE     0.0692   MAE     0.1897   Time 721.572399 ms
# Sample size    128   iteration number    391   MSE     0.1176   MAE     0.2505   Time 1159.166098 ms
# Sample size    128   iteration number    401   MSE     0.0672   MAE     0.1713   Time 830.698967 ms
# Sample size    128   iteration number    411   MSE     0.1020   MAE     0.2368   Time 452.098370 ms
# Sample size    128   iteration number    421   MSE     0.1358   MAE     0.2356   Time 815.590143 ms
# Sample size    128   iteration number    431   MSE     0.1149   MAE     0.2343   Time 691.055059 ms
# Sample size    128   iteration number    441   MSE     0.0917   MAE     0.2136   Time 842.962027 ms
# Sample size    128   iteration number    451   MSE     0.1276   MAE     0.2427   Time 607.907534 ms
# Sample size    128   iteration number    461   MSE     0.1002   MAE     0.2250   Time 437.382221 ms
# Sample size    128   iteration number    471   MSE     0.1244   MAE     0.2372   Time 539.146900 ms
# Sample size    128   iteration number    481   MSE     0.1496   MAE     0.2395   Time 940.701485 ms
# Sample size    128   iteration number    491   MSE     0.0915   MAE     0.2155   Time 1022.834539 ms
# Sample size    128   iteration number    501   MSE     0.1263   MAE     0.2525   Time 844.902039 ms
# Sample size    128   iteration number    511   MSE     0.1070   MAE     0.2212   Time 860.394001 ms
# Sample size    128   iteration number    521   MSE     0.0780   MAE     0.1984   Time 404.066563 ms
# Sample size    128   iteration number    531   MSE     0.1057   MAE     0.2253   Time 853.999376 ms
# Sample size    128   iteration number    541   MSE     0.1112   MAE     0.2306   Time 932.774067 ms
# Sample size    128   iteration number    551   MSE     0.1307   MAE     0.2338   Time 912.299395 ms
# Sample size    128   iteration number    561   MSE     0.1357   MAE     0.2287   Time 929.595232 ms
# Sample size    128   iteration number    571   MSE     0.0877   MAE     0.2053   Time 565.408707 ms
# Sample size    128   iteration number    581   MSE     0.1218   MAE     0.2231   Time 409.923315 ms
# Sample size    128   iteration number    591   MSE     0.1154   MAE     0.2222   Time 516.056538 ms
# Sample size    128   iteration number    601   MSE     0.1018   MAE     0.2227   Time 629.695654 ms
# Sample size    128   iteration number    611   MSE     0.1167   MAE     0.2325   Time 1059.203148 ms
# Sample size    128   iteration number    621   MSE     0.0874   MAE     0.2081   Time 701.305866 ms
# Sample size    128   iteration number    631   MSE     0.0997   MAE     0.2197   Time 624.933243 ms
# Sample size    128   iteration number    641   MSE     0.1192   MAE     0.2410   Time 828.773737 ms
# Sample size    128   iteration number    651   MSE     0.1036   MAE     0.2000   Time 1102.193594 ms
# Sample size    128   iteration number    661   MSE     0.1064   MAE     0.2202   Time 1216.297626 ms
# Sample size    128   iteration number    671   MSE     0.1403   MAE     0.2462   Time 816.305876 ms
# Sample size    128   iteration number    681   MSE     0.1041   MAE     0.2109   Time 656.807423 ms
# Sample size    128   iteration number    691   MSE     0.1117   MAE     0.2052   Time 763.988495 ms
# Sample size    128   iteration number    701   MSE     0.1055   MAE     0.2212   Time 746.847391 ms
# Sample size    128   iteration number    711   MSE     0.1797   MAE     0.2600   Time 582.012177 ms
# Sample size    128   iteration number    721   MSE     0.0763   MAE     0.1942   Time 642.939091 ms
# Sample size    128   iteration number    731   MSE     0.0797   MAE     0.2049   Time 1025.331497 ms
# Sample size    128   iteration number    741   MSE     0.0937   MAE     0.2200   Time 652.795792 ms
# Sample size    128   iteration number    751   MSE     0.1501   MAE     0.2603   Time 552.750826 ms
# Sample size    128   iteration number    761   MSE     0.0645   MAE     0.1827   Time 782.109499 ms
# Sample size    128   iteration number    771   MSE     0.1624   MAE     0.2788   Time 464.199066 ms
# Sample size    128   iteration number    781   MSE     0.1268   MAE     0.2407   Time 654.519081 ms
# Sample size    128   iteration number    791   MSE     0.0698   MAE     0.1819   Time 999.808788 ms
# Sample size    128   iteration number    801   MSE     0.1365   MAE     0.2394   Time 461.138725 ms
# Sample size    128   iteration number    811   MSE     0.1481   MAE     0.2451   Time 609.457254 ms
# Sample size    128   iteration number    821   MSE     0.1284   MAE     0.2508   Time 890.833139 ms
# Sample size    128   iteration number    831   MSE     0.1149   MAE     0.2134   Time 826.853514 ms
# Sample size    128   iteration number    841   MSE     0.1047   MAE     0.2193   Time 906.800270 ms
# Sample size    128   iteration number    851   MSE     0.0702   MAE     0.1854   Time 780.318737 ms
# Sample size    128   iteration number    861   MSE     0.1726   MAE     0.2716   Time 781.267881 ms
# Sample size    128   iteration number    871   MSE     0.1253   MAE     0.2330   Time 597.721815 ms
# Sample size    128   iteration number    881   MSE     0.0982   MAE     0.2180   Time 483.376503 ms
# Sample size    128   iteration number    891   MSE     0.1087   MAE     0.2264   Time 738.438606 ms
# Sample size    128   iteration number    901   MSE     0.0887   MAE     0.2097   Time 654.536009 ms
# Sample size    128   iteration number    911   MSE     0.1626   MAE     0.2360   Time 868.345022 ms
# Sample size    128   iteration number    921   MSE     0.1449   MAE     0.2617   Time 785.368681 ms
# Sample size    128   iteration number    931   MSE     0.1038   MAE     0.2180   Time 738.151312 ms
# Sample size    128   iteration number    941   MSE     0.1099   MAE     0.2241   Time 716.120005 ms
# Sample size    128   iteration number    951   MSE     0.0852   MAE     0.2082   Time 1064.359188 ms
# Sample size    128   iteration number    961   MSE     0.0898   MAE     0.2033   Time 1022.725344 ms
# Sample size    128   iteration number    971   MSE     0.0755   MAE     0.1893   Time 857.199430 ms
# Sample size    128   iteration number    981   MSE     0.1153   MAE     0.2360   Time 843.734026 ms
# Sample size    128   iteration number    991   MSE     0.1053   MAE     0.2325   Time 597.014189 ms
# Sample size    128   iteration number   1001   MSE     0.1005   MAE     0.2175   Time 611.163616 ms
# Sample size    128   iteration number   1011   MSE     0.0995   MAE     0.2154   Time 1018.886805 ms
# Sample size    128   iteration number   1021   MSE     0.1115   MAE     0.2492   Time 900.491953 ms
# Sample size    128   iteration number   1031   MSE     0.1134   MAE     0.2125   Time 557.410955 ms
# Sample size    128   iteration number   1041   MSE     0.1151   MAE     0.2242   Time 595.544338 ms
# Sample size    128   iteration number   1051   MSE     0.0946   MAE     0.2115   Time 514.230013 ms
# Sample size    128   iteration number   1061   MSE     0.0899   MAE     0.2142   Time 616.985798 ms
# Sample size    128   iteration number   1071   MSE     0.1005   MAE     0.2263   Time 651.646376 ms
# Sample size    128   iteration number   1081   MSE     0.0698   MAE     0.1835   Time 799.077749 ms
# Sample size    128   iteration number   1091   MSE     0.0918   MAE     0.2166   Time 754.566193 ms
# Sample size    128   iteration number   1101   MSE     0.0847   MAE     0.2080   Time 517.366648 ms
# Sample size    128   iteration number   1111   MSE     0.1243   MAE     0.2503   Time 630.295277 ms
# Sample size    128   iteration number   1121   MSE     0.1229   MAE     0.2409   Time 758.415461 ms
# Sample size    128   iteration number   1131   MSE     0.1338   MAE     0.2472   Time 791.340828 ms
# Sample size    128   iteration number   1141   MSE     0.0813   MAE     0.1975   Time 487.372398 ms
# Sample size    128   iteration number   1151   MSE     0.0955   MAE     0.2227   Time 569.429159 ms
# Sample size    128   iteration number   1161   MSE     0.0970   MAE     0.2258   Time 678.333044 ms
# Sample size    128   iteration number   1171   MSE     0.1406   MAE     0.2487   Time 1288.815975 ms
# Sample size    128   iteration number   1181   MSE     0.0901   MAE     0.2057   Time 578.562260 ms
# Sample size    128   iteration number   1191   MSE     0.1641   MAE     0.2644   Time 762.124300 ms
# Sample size    128   iteration number   1201   MSE     0.0869   MAE     0.1938   Time 1037.823200 ms
# Sample size    128   iteration number   1211   MSE     0.0725   MAE     0.1918   Time 701.764345 ms
# Sample size    128   iteration number   1221   MSE     0.0919   MAE     0.2074   Time 720.334530 ms
# Sample size    128   iteration number   1231   MSE     0.1009   MAE     0.2269   Time 490.793943 ms
# Sample size    128   iteration number   1241   MSE     0.0936   MAE     0.2019   Time 922.598124 ms
# Sample size    128   iteration number   1251   MSE     0.0993   MAE     0.2094   Time 1024.067163 ms
# Sample size    128   iteration number   1261   MSE     0.1456   MAE     0.2632   Time 1071.944714 ms
# Sample size    128   iteration number   1271   MSE     0.0749   MAE     0.1946   Time 530.498981 ms
# Sample size    128   iteration number   1281   MSE     0.0893   MAE     0.2037   Time 919.876337 ms
# Sample size    128   iteration number   1291   MSE     0.1092   MAE     0.2081   Time 765.196562 ms
# Sample size    128   iteration number   1301   MSE     0.0890   MAE     0.2085   Time 621.652126 ms
# Sample size    128   iteration number   1311   MSE     0.0811   MAE     0.1933   Time 1033.730507 ms
# Sample size    128   iteration number   1321   MSE     0.1129   MAE     0.2261   Time 797.961473 ms
# Sample size    128   iteration number   1331   MSE     0.0868   MAE     0.2067   Time 789.676905 ms
# Sample size    128   iteration number   1341   MSE     0.1495   MAE     0.2405   Time 468.982220 ms
# Sample size    128   iteration number   1351   MSE     0.1003   MAE     0.2170   Time 518.859148 ms
# Sample size    128   iteration number   1361   MSE     0.1235   MAE     0.2185   Time 619.330406 ms
# Sample size    128   iteration number   1371   MSE     0.0926   MAE     0.2264   Time 665.752411 ms
# Sample size    128   iteration number   1381   MSE     0.0820   MAE     0.2022   Time 1291.275024 ms
# Sample size    128   iteration number   1391   MSE     0.0828   MAE     0.1947   Time 863.177299 ms
# Sample size    128   iteration number   1401   MSE     0.0951   MAE     0.2176   Time 805.901527 ms
# Sample size    128   iteration number   1411   MSE     0.1337   MAE     0.2296   Time 630.542278 ms
# Sample size    128   iteration number   1421   MSE     0.0806   MAE     0.2021   Time 616.176367 ms
# Sample size    128   iteration number   1431   MSE     0.1057   MAE     0.2033   Time 774.700403 ms
# Sample size    128   iteration number   1441   MSE     0.1348   MAE     0.2390   Time 506.408453 ms
# Sample size    128   iteration number   1451   MSE     0.1302   MAE     0.2521   Time 604.283333 ms
# Sample size    128   iteration number   1461   MSE     0.1101   MAE     0.2150   Time 900.869370 ms
# Sample size    128   iteration number   1471   MSE     0.0856   MAE     0.1951   Time 1136.887789 ms
# Sample size    128   iteration number   1481   MSE     0.1256   MAE     0.2335   Time 863.421440 ms
# Sample size    128   iteration number   1491   MSE     0.1086   MAE     0.2306   Time 580.502033 ms
# Sample size    128   iteration number   1501   MSE     0.1290   MAE     0.2431   Time 863.211632 ms
# Sample size    128   iteration number   1511   MSE     0.1297   MAE     0.2329   Time 586.014271 ms
# Sample size    128   iteration number   1521   MSE     0.1569   MAE     0.2676   Time 443.160534 ms
# Sample size    128   iteration number   1531   MSE     0.1125   MAE     0.2277   Time 645.569086 ms
# Sample size    128   iteration number   1541   MSE     0.1068   MAE     0.2139   Time 674.392939 ms
# Sample size    128   iteration number   1551   MSE     0.1130   MAE     0.2140   Time 563.513041 ms
# Sample size    128   iteration number   1561   MSE     0.0880   MAE     0.2141   Time 899.139166 ms
# Sample size    128   iteration number   1571   MSE     0.1094   MAE     0.2370   Time 738.497972 ms
# Sample size    128   iteration number   1581   MSE     0.0853   MAE     0.1951   Time 1113.624811 ms
# Sample size    128   iteration number   1591   MSE     0.1485   MAE     0.2386   Time 592.411280 ms
# Sample size    128   iteration number   1601   MSE     0.1547   MAE     0.2691   Time 986.469030 ms
# Sample size    128   iteration number   1611   MSE     0.1082   MAE     0.2263   Time 848.961115 ms
# Sample size    128   iteration number   1621   MSE     0.0871   MAE     0.2123   Time 513.647556 ms
# Sample size    128   iteration number   1631   MSE     0.1145   MAE     0.2156   Time 811.844110 ms
# Sample size    128   iteration number   1641   MSE     0.1034   MAE     0.2133   Time 538.349867 ms
# Sample size    128   iteration number   1651   MSE     0.1207   MAE     0.2312   Time 552.540541 ms
# Sample size    128   iteration number   1661   MSE     0.0874   MAE     0.2153   Time 642.024517 ms
# Sample size    128   iteration number   1671   MSE     0.1465   MAE     0.2673   Time 946.139574 ms
# Sample size    128   iteration number   1681   MSE     0.0842   MAE     0.2083   Time 1035.354137 ms
# Sample size    128   iteration number   1691   MSE     0.1589   MAE     0.2535   Time 603.016615 ms
# Sample size    128   iteration number   1701   MSE     0.1034   MAE     0.2235   Time 1088.045120 ms
# Sample size    128   iteration number   1711   MSE     0.1033   MAE     0.2038   Time 850.445271 ms
# Sample size    128   iteration number   1721   MSE     0.1011   MAE     0.2111   Time 1159.795761 ms
# Sample size    128   iteration number   1731   MSE     0.0901   MAE     0.1993   Time 482.495785 ms
# Sample size    128   iteration number   1741   MSE     0.1064   MAE     0.2226   Time 937.029123 ms
# Sample size    128   iteration number   1751   MSE     0.1167   MAE     0.2546   Time 777.012110 ms
# Sample size    128   iteration number   1761   MSE     0.1470   MAE     0.2667   Time 418.660641 ms
# Sample size    128   iteration number   1771   MSE     0.0818   MAE     0.1994   Time 1121.641159 ms
# Sample size    128   iteration number   1781   MSE     0.1382   MAE     0.2519   Time 646.963596 ms
# Sample size    128   iteration number   1791   MSE     0.0966   MAE     0.2075   Time 703.929186 ms
# Sample size    128   iteration number   1801   MSE     0.1063   MAE     0.2280   Time 873.974562 ms
# Sample size    128   iteration number   1811   MSE     0.0913   MAE     0.2091   Time 1042.522669 ms
# Sample size    128   iteration number   1821   MSE     0.1398   MAE     0.2542   Time 536.987543 ms
# Sample size    128   iteration number   1831   MSE     0.1054   MAE     0.2188   Time 714.638710 ms
# Sample size    128   iteration number   1841   MSE     0.1130   MAE     0.2264   Time 975.448608 ms
# Sample size    128   iteration number   1851   MSE     0.0833   MAE     0.1970   Time 830.728531 ms
# Sample size    128   iteration number   1861   MSE     0.1481   MAE     0.2709   Time 1026.004791 ms
# Sample size    128   iteration number   1871   MSE     0.0683   MAE     0.1834   Time 575.375795 ms
# Sample size    128   iteration number   1881   MSE     0.0972   MAE     0.2063   Time 795.821905 ms
# Sample size    128   iteration number   1891   MSE     0.0936   MAE     0.2080   Time 780.622721 ms
# Sample size    128   iteration number   1901   MSE     0.1029   MAE     0.2070   Time 1076.666594 ms
# Sample size    128   iteration number   1911   MSE     0.1271   MAE     0.2349   Time 1063.545942 ms
# Sample size    128   iteration number   1921   MSE     0.1019   MAE     0.2245   Time 673.162699 ms
# Sample size    128   iteration number   1931   MSE     0.1121   MAE     0.2201   Time 731.240988 ms
# Sample size    128   iteration number   1941   MSE     0.0942   MAE     0.2190   Time 609.166384 ms
# Sample size    128   iteration number   1951   MSE     0.1969   MAE     0.2643   Time 872.428894 ms
# Sample size    128   iteration number   1961   MSE     0.1222   MAE     0.2232   Time 725.730658 ms
# Sample size    128   iteration number   1971   MSE     0.1106   MAE     0.2195   Time 543.636322 ms
# Sample size    128   iteration number   1981   MSE     0.0825   MAE     0.2063   Time 551.296949 ms
# Sample size    128   iteration number   1991   MSE     0.0885   MAE     0.2032   Time 734.595060 ms
# Sample size    128   iteration number   2001   MSE     0.0871   MAE     0.1901   Time 614.193439 ms
# Sample size    512   iteration number      1   MSE     0.1113   MAE     0.2154   Time 1189.752817 ms
# Sample size    512   iteration number     11   MSE     0.1039   MAE     0.2125   Time 1097.791195 ms
# Sample size    512   iteration number     21   MSE     0.0977   MAE     0.2063   Time 1263.171434 ms
# Sample size    512   iteration number     31   MSE     0.1152   MAE     0.2183   Time 1195.457697 ms
# Sample size    512   iteration number     41   MSE     0.1225   MAE     0.2397   Time 1097.339392 ms
# Sample size    512   iteration number     51   MSE     0.1355   MAE     0.2342   Time 1111.196280 ms
# Sample size    512   iteration number     61   MSE     0.1087   MAE     0.2225   Time 1133.986950 ms
# Sample size    512   iteration number     71   MSE     0.0789   MAE     0.1906   Time 1116.749525 ms
# Sample size    512   iteration number     81   MSE     0.1216   MAE     0.2337   Time 1025.734425 ms
# Sample size    512   iteration number     91   MSE     0.0988   MAE     0.2078   Time 1278.920650 ms
# Sample size    512   iteration number    101   MSE     0.1095   MAE     0.2174   Time 1026.243448 ms
# Sample size    512   iteration number    111   MSE     0.1025   MAE     0.2103   Time 1013.009071 ms
# Sample size    512   iteration number    121   MSE     0.1177   MAE     0.2252   Time 1132.627964 ms
# Sample size    512   iteration number    131   MSE     0.1070   MAE     0.2166   Time 1056.041241 ms
# Sample size    512   iteration number    141   MSE     0.0979   MAE     0.2029   Time 1056.904078 ms
# Sample size    512   iteration number    151   MSE     0.1052   MAE     0.2171   Time 1130.311251 ms
# Sample size    512   iteration number    161   MSE     0.0951   MAE     0.2053   Time 851.369619 ms
# Sample size    512   iteration number    171   MSE     0.1113   MAE     0.2179   Time 949.079037 ms
# Sample size    512   iteration number    181   MSE     0.1177   MAE     0.2242   Time 1100.932837 ms
# Sample size    512   iteration number    191   MSE     0.1235   MAE     0.2378   Time 1297.578573 ms
# Sample size    512   iteration number    201   MSE     0.1014   MAE     0.2095   Time 1150.917292 ms
# Sample size    512   iteration number    211   MSE     0.1072   MAE     0.2120   Time 1141.767263 ms
# Sample size    512   iteration number    221   MSE     0.0919   MAE     0.2026   Time 1096.675158 ms
# Sample size    512   iteration number    231   MSE     0.1165   MAE     0.2197   Time 1197.276831 ms
# Sample size    512   iteration number    241   MSE     0.1097   MAE     0.2183   Time 1193.043947 ms
# Sample size    512   iteration number    251   MSE     0.1120   MAE     0.2186   Time 750.576496 ms
# Sample size    512   iteration number    261   MSE     0.1073   MAE     0.2126   Time 926.615477 ms
# Sample size    512   iteration number    271   MSE     0.0868   MAE     0.1943   Time 1070.739031 ms
# Sample size    512   iteration number    281   MSE     0.0991   MAE     0.2101   Time 935.345650 ms
# Sample size    512   iteration number    291   MSE     0.1075   MAE     0.2164   Time 1091.754198 ms
# Sample size    512   iteration number    301   MSE     0.0949   MAE     0.2045   Time 1223.696470 ms
# Sample size    512   iteration number    311   MSE     0.1059   MAE     0.2117   Time 948.330879 ms
# Sample size    512   iteration number    321   MSE     0.0943   MAE     0.1916   Time 1174.557209 ms
# Sample size    512   iteration number    331   MSE     0.1218   MAE     0.2263   Time 1040.793657 ms
# Sample size    512   iteration number    341   MSE     0.1326   MAE     0.2417   Time 1016.736746 ms
# Sample size    512   iteration number    351   MSE     0.1150   MAE     0.2168   Time 1324.635744 ms
# Sample size    512   iteration number    361   MSE     0.1292   MAE     0.2300   Time 930.204391 ms
# Sample size    512   iteration number    371   MSE     0.1024   MAE     0.2064   Time 1247.484446 ms
# Sample size    512   iteration number    381   MSE     0.1001   MAE     0.2174   Time 1019.348145 ms
# Sample size    512   iteration number    391   MSE     0.1052   MAE     0.2144   Time 970.618725 ms
# Sample size    512   iteration number    401   MSE     0.1191   MAE     0.2326   Time 1158.540964 ms
# Sample size    512   iteration number    411   MSE     0.0999   MAE     0.2097   Time 1077.786207 ms
# Sample size    512   iteration number    421   MSE     0.1263   MAE     0.2294   Time 970.815182 ms
# Sample size    512   iteration number    431   MSE     0.0959   MAE     0.2037   Time 838.793039 ms
# Sample size    512   iteration number    441   MSE     0.1104   MAE     0.2303   Time 1012.955904 ms
# Sample size    512   iteration number    451   MSE     0.1082   MAE     0.2159   Time 1023.880243 ms
# Sample size    512   iteration number    461   MSE     0.0877   MAE     0.1963   Time 994.127512 ms
# Sample size    512   iteration number    471   MSE     0.0987   MAE     0.2036   Time 1095.285177 ms
# Sample size    512   iteration number    481   MSE     0.1109   MAE     0.2166   Time 986.164570 ms
# Sample size    512   iteration number    491   MSE     0.1041   MAE     0.2139   Time 1022.424936 ms
# Sample size    512   iteration number    501   MSE     0.0967   MAE     0.1992   Time 1376.649380 ms
# Sample size    512   iteration number    511   MSE     0.0808   MAE     0.1931   Time 1149.386883 ms
# Sample size    512   iteration number    521   MSE     0.1164   MAE     0.2220   Time 1413.548946 ms
# Sample size    512   iteration number    531   MSE     0.0968   MAE     0.2134   Time 1221.500158 ms
# Sample size    512   iteration number    541   MSE     0.1150   MAE     0.2286   Time 1015.016317 ms
# Sample size    512   iteration number    551   MSE     0.0957   MAE     0.2103   Time 1446.537256 ms
# Sample size    512   iteration number    561   MSE     0.0997   MAE     0.2049   Time 928.394318 ms
# Sample size    512   iteration number    571   MSE     0.1110   MAE     0.2252   Time 1269.722939 ms
# Sample size    512   iteration number    581   MSE     0.1313   MAE     0.2408   Time 1070.394754 ms
# Sample size    512   iteration number    591   MSE     0.1255   MAE     0.2325   Time 1220.665216 ms
# Sample size    512   iteration number    601   MSE     0.1083   MAE     0.2234   Time 1500.392199 ms
# Sample size    512   iteration number    611   MSE     0.0890   MAE     0.2011   Time 1104.181767 ms
# Sample size    512   iteration number    621   MSE     0.1004   MAE     0.2132   Time 802.422523 ms
# Sample size    512   iteration number    631   MSE     0.1190   MAE     0.2232   Time 1224.423409 ms
# Sample size    512   iteration number    641   MSE     0.0957   MAE     0.2163   Time 818.869114 ms
# Sample size    512   iteration number    651   MSE     0.1161   MAE     0.2267   Time 1085.993767 ms
# Sample size    512   iteration number    661   MSE     0.1159   MAE     0.2179   Time 945.518970 ms
# Sample size    512   iteration number    671   MSE     0.1023   MAE     0.2097   Time 1023.174763 ms
# Sample size    512   iteration number    681   MSE     0.1231   MAE     0.2292   Time 1084.596395 ms
# Sample size    512   iteration number    691   MSE     0.1019   MAE     0.2172   Time 1264.664412 ms
# Sample size    512   iteration number    701   MSE     0.1066   MAE     0.2163   Time 1178.434849 ms
# Sample size    512   iteration number    711   MSE     0.1161   MAE     0.2246   Time 1243.109703 ms
# Sample size    512   iteration number    721   MSE     0.0773   MAE     0.1915   Time 1097.931147 ms
# Sample size    512   iteration number    731   MSE     0.1297   MAE     0.2380   Time 1023.327112 ms
# Sample size    512   iteration number    741   MSE     0.1311   MAE     0.2300   Time 1284.197092 ms
# Sample size    512   iteration number    751   MSE     0.1140   MAE     0.2105   Time 1045.617819 ms
# Sample size    512   iteration number    761   MSE     0.0996   MAE     0.2010   Time 1154.322386 ms
# Sample size    512   iteration number    771   MSE     0.1039   MAE     0.2150   Time 1141.117573 ms
# Sample size    512   iteration number    781   MSE     0.1149   MAE     0.2198   Time 1425.823689 ms
# Sample size    512   iteration number    791   MSE     0.1038   MAE     0.2111   Time 1163.361549 ms
# Sample size    512   iteration number    801   MSE     0.1134   MAE     0.2193   Time 1191.211700 ms
# Sample size    512   iteration number    811   MSE     0.1010   MAE     0.2045   Time 939.662695 ms
# Sample size    512   iteration number    821   MSE     0.1280   MAE     0.2374   Time 1142.912388 ms
# Sample size    512   iteration number    831   MSE     0.1037   MAE     0.2101   Time 1100.266695 ms
# Sample size    512   iteration number    841   MSE     0.1032   MAE     0.2223   Time 736.292362 ms
# Sample size    512   iteration number    851   MSE     0.1209   MAE     0.2209   Time 982.632399 ms
# Sample size    512   iteration number    861   MSE     0.1161   MAE     0.2263   Time 1043.253422 ms
# Sample size    512   iteration number    871   MSE     0.0977   MAE     0.2030   Time 1629.010439 ms
# Sample size    512   iteration number    881   MSE     0.1262   MAE     0.2163   Time 1361.699820 ms
# Sample size    512   iteration number    891   MSE     0.1008   MAE     0.2146   Time 766.716242 ms
# Sample size    512   iteration number    901   MSE     0.1098   MAE     0.2205   Time 1334.676743 ms
# Sample size    512   iteration number    911   MSE     0.0940   MAE     0.2094   Time 1325.417757 ms
# Sample size    512   iteration number    921   MSE     0.1091   MAE     0.2158   Time 1509.993553 ms
# Sample size    512   iteration number    931   MSE     0.1017   MAE     0.2118   Time 1057.134390 ms
# Sample size    512   iteration number    941   MSE     0.1047   MAE     0.2187   Time 954.201460 ms
# Sample size    512   iteration number    951   MSE     0.0988   MAE     0.2171   Time 1194.024086 ms
# Sample size    512   iteration number    961   MSE     0.1156   MAE     0.2199   Time 1012.283802 ms
# Sample size    512   iteration number    971   MSE     0.1368   MAE     0.2347   Time 1112.100840 ms
# Sample size    512   iteration number    981   MSE     0.1176   MAE     0.2260   Time 1127.286196 ms
# Sample size    512   iteration number    991   MSE     0.1033   MAE     0.2178   Time 1110.689402 ms
# Sample size    512   iteration number   1001   MSE     0.1059   MAE     0.2189   Time 844.251156 ms
# CPU times: user 1h 48min 45s, sys: 2h 48min 55s, total: 4h 37min 41s
# Wall time: 1h 26min 19s

# %% [markdown]
# ### 6. TEST MODEL

# %%
def predict(network, trajectory):
    """ Predict parameters of the force field from the trajectory using the deep learnign network.
    
    Inputs:
    network: deep learning network
    image: trajectroy [numpy array of real numbers]
    
    Output:
    predicted_targets: predicted parameters of the calibrated force field [1D numpy array containing outputs]
    """
    
    from numpy import reshape
    
    network_blocksize = network.get_layer(index=0).get_config()['batch_input_shape'][1:][1]
    predicted_targets = network.predict(reshape(trajectory, [1,round(trajectory.size/network_blocksize),network_blocksize]))   
        
    return predicted_targets


def test_performance(simulate_trajectory, network, rescale_targets, number_of_predictions_to_show=100):#, dt = 1e-1):

    import numpy as np

    
    network_blocksize = network.get_layer(index=0).get_config()['batch_input_shape'][1:][1]


    predictions_scaled = []
    predictions_physical = []

    batch_size = number_of_predictions_to_show
    trajectory, trajectory_real, targets, targets_real = simulate_trajectory(batch_size)
    targets_physical = list(targets_real)#targets.values)
    targets_scaled = list(targets)#.scaled_values)
    #trajectory = trajectory.scaled_values
    trajectory_dimensions = [number_of_predictions_to_show, round(trajectory.size/network_blocksize/number_of_predictions_to_show) , network_blocksize]
    trajectories = np.array(trajectory).reshape(trajectory_dimensions)
       

    for i in range(number_of_predictions_to_show):
        predictions = predict(network, trajectories[i])


        predictions_scaled.append(predictions[0])
        predictions_physical.append(rescale_targets(*predictions[0]))

    number_of_outputs = network.get_layer(index=-1).get_config()['units']    

    targets_physical = np.array(targets_physical).transpose()
    targets_scaled = np.array(targets_scaled).transpose()
    predictions_scaled = np.array(predictions_scaled).transpose()
    predictions_physical = np.array(predictions_physical).transpose()

    # Do not show results at the edges of the training range 

    if number_of_outputs>1:

        ind = np.isfinite(targets_scaled[0])
        for target_number in range(number_of_outputs):
            target_max = .9 * np.max(targets_scaled[target_number]) + .1 * np.min(targets_scaled[target_number])
            target_min = .1 * np.max(targets_scaled[target_number]) + .9 * np.min(targets_scaled[target_number])
            ind = np.logical_and(ind, targets_scaled[target_number] < target_max)
            ind = np.logical_and(ind, targets_scaled[target_number] > target_min)
    else:
        target_max = .9 * np.max(targets_scaled) + .1 * np.min(targets_scaled)
        target_min = .1 * np.max(targets_scaled) + .9 * np.min(targets_scaled)
        ind = np.logical_and(targets_scaled < target_max, targets_scaled > target_min)

    return targets_scaled, targets_physical, predictions_scaled, predictions_physical, ind


def plot_test_performance(targets_scaled, targets_physical, predictions_scaled, predictions_physical, ind, network):
    
    import matplotlib.pyplot as plt
    import numpy as np
    #from . import predict

    number_of_outputs = network.get_layer(index=-1).get_config()['units']    
    
    if number_of_outputs>1:

        for target_number in range(number_of_outputs):
            plt.figure(figsize=(20, 10))

            plt.subplot(121)
            plt.plot(targets_scaled[target_number],
                     predictions_scaled[target_number],
                     '.')
            #plt.xlabel(targets.scalings[target_number], fontsize=18)
            #plt.ylabel('Predicted ' + targets.scalings[target_number], fontsize=18)
            plt.axis('square')
            plt.title('Prediction performance in scaled units', fontsize=18)

            plt.subplot(122)
            plt.plot(targets_physical[target_number],
                     predictions_physical[target_number],
                    '.')
            #plt.xlabel(targets.names[target_number], fontsize=18)
            #plt.ylabel('Predicted ' + targets.names[target_number], fontsize=18)
            plt.axis('square')
            plt.title('Prediction performance in real units', fontsize=18)


    else: 
        plt.figure(figsize=(20, 10))

        plt.subplot(121)
        plt.plot(targets_scaled[ind],
                 predictions_scaled.transpose()[ind],
                 '.')
        #plt.xlabel(targets.scalings[0], fontsize=18)
        #plt.ylabel('Predicted ' + targets.scalings[0], fontsize=18)
        plt.axis('square')
        plt.title('Prediction performance in scaled units', fontsize=18)

        plt.subplot(122)
        plt.plot(targets_physical[ind],
                 predictions_physical.transpose()[ind],
                '.')
        #plt.xlabel(targets.names[0], fontsize=18)
        #plt.ylabel('Predicted ' + targets.names[0], fontsize=18)
        plt.axis('square')
        plt.title('Prediction performance in real units', fontsize=18)

# %%
# %%time

number_of_predictions_to_show = 1000
prediction_test = test_performance(simulate_trajectory, network, rescale_targets, number_of_predictions_to_show)
# Out:
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 0s 132ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 124ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 101ms/step
# 1/1 [==============================] - 0s 76ms/step
# 1/1 [==============================] - 0s 77ms/step
# 1/1 [==============================] - 0s 107ms/step
# 1/1 [==============================] - 0s 88ms/step
# 1/1 [==============================] - 0s 102ms/step
# 1/1 [==============================] - 0s 81ms/step
# 1/1 [==============================] - 0s 89ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 61ms/step
# 1/1 [==============================] - 0s 81ms/step
# 1/1 [==============================] - 0s 132ms/step
# 1/1 [==============================] - 0s 118ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 88ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 152ms/step
# 1/1 [==============================] - 0s 100ms/step
# 1/1 [==============================] - 0s 108ms/step
# 1/1 [==============================] - 0s 76ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 99ms/step
# 1/1 [==============================] - 0s 91ms/step
# 1/1 [==============================] - 0s 143ms/step
# 1/1 [==============================] - 0s 84ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 136ms/step
# 1/1 [==============================] - 0s 176ms/step
# 1/1 [==============================] - 0s 125ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 117ms/step
# 1/1 [==============================] - 0s 129ms/step
# 1/1 [==============================] - 0s 156ms/step
# 1/1 [==============================] - 0s 58ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 95ms/step
# 1/1 [==============================] - 0s 110ms/step
# 1/1 [==============================] - 0s 112ms/step
# 1/1 [==============================] - 0s 131ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 87ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 73ms/step
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 101ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 76ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 131ms/step
# 1/1 [==============================] - 0s 73ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 155ms/step
# 1/1 [==============================] - 0s 113ms/step
# 1/1 [==============================] - 0s 54ms/step
# 1/1 [==============================] - 0s 90ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 134ms/step
# 1/1 [==============================] - 0s 98ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 115ms/step
# 1/1 [==============================] - 0s 101ms/step
# 1/1 [==============================] - 0s 74ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 114ms/step
# 1/1 [==============================] - 0s 145ms/step
# 1/1 [==============================] - 0s 125ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 84ms/step
# 1/1 [==============================] - 0s 95ms/step
# 1/1 [==============================] - 0s 82ms/step
# 1/1 [==============================] - 0s 102ms/step
# 1/1 [==============================] - 0s 118ms/step
# 1/1 [==============================] - 0s 90ms/step
# 1/1 [==============================] - 0s 61ms/step
# 1/1 [==============================] - 0s 111ms/step
# 1/1 [==============================] - 0s 103ms/step
# 1/1 [==============================] - 0s 85ms/step
# 1/1 [==============================] - 0s 101ms/step
# 1/1 [==============================] - 0s 96ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 78ms/step
# 1/1 [==============================] - 0s 144ms/step
# 1/1 [==============================] - 0s 107ms/step
# 1/1 [==============================] - 0s 100ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 83ms/step
# 1/1 [==============================] - 0s 84ms/step
# 1/1 [==============================] - 0s 117ms/step
# 1/1 [==============================] - 0s 126ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 103ms/step
# 1/1 [==============================] - 0s 138ms/step
# 1/1 [==============================] - 0s 129ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 54ms/step
# 1/1 [==============================] - 0s 117ms/step
# 1/1 [==============================] - 0s 85ms/step
# 1/1 [==============================] - 0s 149ms/step
# 1/1 [==============================] - 0s 125ms/step
# 1/1 [==============================] - 0s 99ms/step
# 1/1 [==============================] - 0s 176ms/step
# 1/1 [==============================] - 0s 84ms/step
# 1/1 [==============================] - 0s 76ms/step
# 1/1 [==============================] - 0s 128ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 84ms/step
# 1/1 [==============================] - 0s 150ms/step
# 1/1 [==============================] - 0s 124ms/step
# 1/1 [==============================] - 0s 72ms/step
# 1/1 [==============================] - 0s 116ms/step
# 1/1 [==============================] - 0s 114ms/step
# 1/1 [==============================] - 0s 74ms/step
# 1/1 [==============================] - 0s 107ms/step
# 1/1 [==============================] - 0s 109ms/step
# 1/1 [==============================] - 0s 104ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 146ms/step
# 1/1 [==============================] - 0s 74ms/step
# 1/1 [==============================] - 0s 103ms/step
# 1/1 [==============================] - 0s 78ms/step
# 1/1 [==============================] - 0s 101ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 96ms/step
# 1/1 [==============================] - 0s 137ms/step
# 1/1 [==============================] - 0s 122ms/step
# 1/1 [==============================] - 0s 91ms/step
# 1/1 [==============================] - 0s 85ms/step
# 1/1 [==============================] - 0s 57ms/step
# 1/1 [==============================] - 0s 116ms/step
# 1/1 [==============================] - 0s 192ms/step
# 1/1 [==============================] - 0s 113ms/step
# 1/1 [==============================] - 0s 141ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 98ms/step
# 1/1 [==============================] - 0s 134ms/step
# 1/1 [==============================] - 0s 89ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 60ms/step
# 1/1 [==============================] - 0s 88ms/step
# 1/1 [==============================] - 0s 75ms/step
# 1/1 [==============================] - 0s 108ms/step
# 1/1 [==============================] - 0s 110ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 118ms/step
# 1/1 [==============================] - 0s 71ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 127ms/step
# 1/1 [==============================] - 0s 209ms/step
# 1/1 [==============================] - 0s 145ms/step
# 1/1 [==============================] - 0s 89ms/step
# 1/1 [==============================] - 0s 131ms/step
# 1/1 [==============================] - 0s 159ms/step
# 1/1 [==============================] - 0s 127ms/step
# 1/1 [==============================] - 0s 111ms/step
# 1/1 [==============================] - 0s 107ms/step
# 1/1 [==============================] - 0s 83ms/step
# 1/1 [==============================] - 0s 72ms/step
# 1/1 [==============================] - 0s 78ms/step
# 1/1 [==============================] - 0s 128ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 184ms/step
# 1/1 [==============================] - 0s 98ms/step
# 1/1 [==============================] - 0s 113ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 72ms/step
# 1/1 [==============================] - 0s 132ms/step
# 1/1 [==============================] - 0s 153ms/step
# 1/1 [==============================] - 0s 141ms/step
# 1/1 [==============================] - 0s 121ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 107ms/step
# 1/1 [==============================] - 0s 84ms/step
# 1/1 [==============================] - 0s 83ms/step
# 1/1 [==============================] - 0s 105ms/step
# 1/1 [==============================] - 0s 127ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 128ms/step
# 1/1 [==============================] - 0s 132ms/step
# 1/1 [==============================] - 0s 109ms/step
# 1/1 [==============================] - 0s 82ms/step
# 1/1 [==============================] - 0s 83ms/step
# 1/1 [==============================] - 0s 135ms/step
# 1/1 [==============================] - 0s 145ms/step
# 1/1 [==============================] - 0s 86ms/step
# 1/1 [==============================] - 0s 98ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 80ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 170ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 149ms/step
# 1/1 [==============================] - 0s 85ms/step
# 1/1 [==============================] - 0s 98ms/step
# 1/1 [==============================] - 0s 107ms/step
# 1/1 [==============================] - 0s 77ms/step
# 1/1 [==============================] - 0s 134ms/step
# 1/1 [==============================] - 0s 78ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 123ms/step
# 1/1 [==============================] - 0s 84ms/step
# 1/1 [==============================] - 0s 154ms/step
# 1/1 [==============================] - 0s 159ms/step
# 1/1 [==============================] - 0s 59ms/step
# 1/1 [==============================] - 0s 96ms/step
# 1/1 [==============================] - 0s 129ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 102ms/step
# 1/1 [==============================] - 0s 118ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 57ms/step
# 1/1 [==============================] - 0s 191ms/step
# 1/1 [==============================] - 0s 82ms/step
# 1/1 [==============================] - 0s 83ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 71ms/step
# 1/1 [==============================] - 0s 79ms/step
# 1/1 [==============================] - 0s 172ms/step
# 1/1 [==============================] - 0s 137ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 87ms/step
# 1/1 [==============================] - 0s 71ms/step
# 1/1 [==============================] - 0s 108ms/step
# 1/1 [==============================] - 0s 165ms/step
# 1/1 [==============================] - 0s 110ms/step
# 1/1 [==============================] - 0s 133ms/step
# 1/1 [==============================] - 0s 82ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 103ms/step
# 1/1 [==============================] - 0s 132ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 113ms/step
# 1/1 [==============================] - 0s 60ms/step
# 1/1 [==============================] - 0s 83ms/step
# 1/1 [==============================] - 0s 142ms/step
# 1/1 [==============================] - 0s 109ms/step
# 1/1 [==============================] - 0s 97ms/step
# 1/1 [==============================] - 0s 83ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 131ms/step
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 74ms/step
# 1/1 [==============================] - 0s 54ms/step
# 1/1 [==============================] - 0s 77ms/step
# 1/1 [==============================] - 0s 76ms/step
# 1/1 [==============================] - 0s 77ms/step
# 1/1 [==============================] - 0s 54ms/step
# 1/1 [==============================] - 0s 83ms/step
# 1/1 [==============================] - 0s 189ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 89ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 110ms/step
# 1/1 [==============================] - 0s 117ms/step
# 1/1 [==============================] - 0s 171ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 100ms/step
# 1/1 [==============================] - 0s 92ms/step
# 1/1 [==============================] - 0s 57ms/step
# 1/1 [==============================] - 0s 147ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 95ms/step
# 1/1 [==============================] - 0s 136ms/step
# 1/1 [==============================] - 0s 127ms/step
# 1/1 [==============================] - 0s 73ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 80ms/step
# 1/1 [==============================] - 0s 80ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 73ms/step
# 1/1 [==============================] - 0s 59ms/step
# 1/1 [==============================] - 0s 109ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 57ms/step
# 1/1 [==============================] - 0s 101ms/step
# 1/1 [==============================] - 0s 57ms/step
# 1/1 [==============================] - 0s 86ms/step
# 1/1 [==============================] - 0s 89ms/step
# 1/1 [==============================] - 0s 81ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 98ms/step
# 1/1 [==============================] - 0s 109ms/step
# 1/1 [==============================] - 0s 88ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 54ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 118ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 97ms/step
# 1/1 [==============================] - 0s 73ms/step
# 1/1 [==============================] - 0s 58ms/step
# 1/1 [==============================] - 0s 95ms/step
# 1/1 [==============================] - 0s 56ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 77ms/step
# 1/1 [==============================] - 0s 84ms/step
# 1/1 [==============================] - 0s 135ms/step
# 1/1 [==============================] - 0s 71ms/step
# 1/1 [==============================] - 0s 121ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 86ms/step
# 1/1 [==============================] - 0s 87ms/step
# 1/1 [==============================] - 0s 110ms/step
# 1/1 [==============================] - 0s 92ms/step
# 1/1 [==============================] - 0s 112ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 78ms/step
# 1/1 [==============================] - 0s 100ms/step
# 1/1 [==============================] - 0s 126ms/step
# 1/1 [==============================] - 0s 78ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 87ms/step
# 1/1 [==============================] - 0s 82ms/step
# 1/1 [==============================] - 0s 76ms/step
# 1/1 [==============================] - 0s 80ms/step
# 1/1 [==============================] - 0s 85ms/step
# 1/1 [==============================] - 0s 83ms/step
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 80ms/step
# 1/1 [==============================] - 0s 84ms/step
# 1/1 [==============================] - 0s 89ms/step
# 1/1 [==============================] - 0s 72ms/step
# 1/1 [==============================] - 0s 96ms/step
# 1/1 [==============================] - 0s 61ms/step
# 1/1 [==============================] - 0s 100ms/step
# 1/1 [==============================] - 0s 83ms/step
# 1/1 [==============================] - 0s 100ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 106ms/step
# 1/1 [==============================] - 0s 85ms/step
# 1/1 [==============================] - 0s 105ms/step
# 1/1 [==============================] - 0s 79ms/step
# 1/1 [==============================] - 0s 76ms/step
# 1/1 [==============================] - 0s 72ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 75ms/step
# 1/1 [==============================] - 0s 145ms/step
# 1/1 [==============================] - 0s 79ms/step
# 1/1 [==============================] - 0s 107ms/step
# 1/1 [==============================] - 0s 148ms/step
# 1/1 [==============================] - 0s 107ms/step
# 1/1 [==============================] - 0s 112ms/step
# 1/1 [==============================] - 0s 87ms/step
# 1/1 [==============================] - 0s 81ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 89ms/step
# 1/1 [==============================] - 0s 95ms/step
# 1/1 [==============================] - 0s 174ms/step
# 1/1 [==============================] - 0s 86ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 120ms/step
# 1/1 [==============================] - 0s 73ms/step
# 1/1 [==============================] - 0s 81ms/step
# 1/1 [==============================] - 0s 102ms/step
# 1/1 [==============================] - 0s 178ms/step
# 1/1 [==============================] - 0s 199ms/step
# 1/1 [==============================] - 0s 110ms/step
# 1/1 [==============================] - 0s 140ms/step
# 1/1 [==============================] - 0s 97ms/step
# 1/1 [==============================] - 0s 61ms/step
# 1/1 [==============================] - 0s 115ms/step
# 1/1 [==============================] - 0s 164ms/step
# 1/1 [==============================] - 0s 101ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 89ms/step
# 1/1 [==============================] - 0s 79ms/step
# 1/1 [==============================] - 0s 91ms/step
# 1/1 [==============================] - 0s 104ms/step
# 1/1 [==============================] - 0s 60ms/step
# 1/1 [==============================] - 0s 97ms/step
# 1/1 [==============================] - 0s 80ms/step
# 1/1 [==============================] - 0s 106ms/step
# 1/1 [==============================] - 0s 154ms/step
# 1/1 [==============================] - 0s 73ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 167ms/step
# 1/1 [==============================] - 0s 124ms/step
# 1/1 [==============================] - 0s 54ms/step
# 1/1 [==============================] - 0s 116ms/step
# 1/1 [==============================] - 0s 137ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 135ms/step
# 1/1 [==============================] - 0s 122ms/step
# 1/1 [==============================] - 0s 102ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 129ms/step
# 1/1 [==============================] - 0s 117ms/step
# 1/1 [==============================] - 0s 100ms/step
# 1/1 [==============================] - 0s 95ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 129ms/step
# 1/1 [==============================] - 0s 99ms/step
# 1/1 [==============================] - 0s 88ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 71ms/step
# 1/1 [==============================] - 0s 107ms/step
# 1/1 [==============================] - 0s 139ms/step
# 1/1 [==============================] - 0s 75ms/step
# 1/1 [==============================] - 0s 108ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 87ms/step
# 1/1 [==============================] - 0s 114ms/step
# 1/1 [==============================] - 0s 85ms/step
# 1/1 [==============================] - 0s 98ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 113ms/step
# 1/1 [==============================] - 0s 60ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 126ms/step
# 1/1 [==============================] - 0s 121ms/step
# 1/1 [==============================] - 0s 60ms/step
# 1/1 [==============================] - 0s 73ms/step
# 1/1 [==============================] - 0s 110ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 61ms/step
# 1/1 [==============================] - 0s 91ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 117ms/step
# 1/1 [==============================] - 0s 87ms/step
# 1/1 [==============================] - 0s 87ms/step
# 1/1 [==============================] - 0s 122ms/step
# 1/1 [==============================] - 0s 119ms/step
# 1/1 [==============================] - 0s 131ms/step
# 1/1 [==============================] - 0s 125ms/step
# 1/1 [==============================] - 0s 106ms/step
# 1/1 [==============================] - 0s 88ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 79ms/step
# 1/1 [==============================] - 0s 87ms/step
# 1/1 [==============================] - 0s 75ms/step
# 1/1 [==============================] - 0s 99ms/step
# 1/1 [==============================] - 0s 141ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 91ms/step
# 1/1 [==============================] - 0s 112ms/step
# 1/1 [==============================] - 0s 73ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 125ms/step
# 1/1 [==============================] - 0s 77ms/step
# 1/1 [==============================] - 0s 124ms/step
# 1/1 [==============================] - 0s 97ms/step
# 1/1 [==============================] - 0s 107ms/step
# 1/1 [==============================] - 0s 121ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 116ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 118ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 246ms/step
# 1/1 [==============================] - 0s 183ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 71ms/step
# 1/1 [==============================] - 0s 120ms/step
# 1/1 [==============================] - 0s 82ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 138ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 115ms/step
# 1/1 [==============================] - 0s 131ms/step
# 1/1 [==============================] - 0s 112ms/step
# 1/1 [==============================] - 0s 143ms/step
# 1/1 [==============================] - 0s 124ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 76ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 164ms/step
# 1/1 [==============================] - 0s 84ms/step
# 1/1 [==============================] - 0s 127ms/step
# 1/1 [==============================] - 0s 179ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 111ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 118ms/step
# 1/1 [==============================] - 0s 155ms/step
# 1/1 [==============================] - 0s 89ms/step
# 1/1 [==============================] - 0s 71ms/step
# 1/1 [==============================] - 0s 91ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 72ms/step
# 1/1 [==============================] - 0s 103ms/step
# 1/1 [==============================] - 0s 85ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 56ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 56ms/step
# 1/1 [==============================] - 0s 88ms/step
# 1/1 [==============================] - 0s 75ms/step
# 1/1 [==============================] - 0s 72ms/step
# 1/1 [==============================] - 0s 84ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 109ms/step
# 1/1 [==============================] - 0s 82ms/step
# 1/1 [==============================] - 0s 128ms/step
# 1/1 [==============================] - 0s 72ms/step
# 1/1 [==============================] - 0s 154ms/step
# 1/1 [==============================] - 0s 179ms/step
# 1/1 [==============================] - 0s 80ms/step
# 1/1 [==============================] - 0s 100ms/step
# 1/1 [==============================] - 0s 91ms/step
# 1/1 [==============================] - 0s 109ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 80ms/step
# 1/1 [==============================] - 0s 95ms/step
# 1/1 [==============================] - 0s 118ms/step
# 1/1 [==============================] - 0s 61ms/step
# 1/1 [==============================] - 0s 90ms/step
# 1/1 [==============================] - 0s 95ms/step
# 1/1 [==============================] - 0s 129ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 102ms/step
# 1/1 [==============================] - 0s 106ms/step
# 1/1 [==============================] - 0s 98ms/step
# 1/1 [==============================] - 0s 73ms/step
# 1/1 [==============================] - 0s 111ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 115ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 126ms/step
# 1/1 [==============================] - 0s 107ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 123ms/step
# 1/1 [==============================] - 0s 144ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 103ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 89ms/step
# 1/1 [==============================] - 0s 173ms/step
# 1/1 [==============================] - 0s 135ms/step
# 1/1 [==============================] - 0s 109ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 118ms/step
# 1/1 [==============================] - 0s 96ms/step
# 1/1 [==============================] - 0s 149ms/step
# 1/1 [==============================] - 0s 124ms/step
# 1/1 [==============================] - 0s 84ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 90ms/step
# 1/1 [==============================] - 0s 114ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 97ms/step
# 1/1 [==============================] - 0s 133ms/step
# 1/1 [==============================] - 0s 57ms/step
# 1/1 [==============================] - 0s 142ms/step
# 1/1 [==============================] - 0s 135ms/step
# 1/1 [==============================] - 0s 126ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 130ms/step
# 1/1 [==============================] - 0s 73ms/step
# 1/1 [==============================] - 0s 121ms/step
# 1/1 [==============================] - 0s 85ms/step
# 1/1 [==============================] - 0s 59ms/step
# 1/1 [==============================] - 0s 132ms/step
# 1/1 [==============================] - 0s 91ms/step
# 1/1 [==============================] - 0s 118ms/step
# 1/1 [==============================] - 0s 117ms/step
# 1/1 [==============================] - 0s 126ms/step
# 1/1 [==============================] - 0s 109ms/step
# 1/1 [==============================] - 0s 146ms/step
# 1/1 [==============================] - 0s 87ms/step
# 1/1 [==============================] - 0s 126ms/step
# 1/1 [==============================] - 0s 59ms/step
# 1/1 [==============================] - 0s 86ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 120ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 72ms/step
# 1/1 [==============================] - 0s 83ms/step
# 1/1 [==============================] - 0s 130ms/step
# 1/1 [==============================] - 0s 106ms/step
# 1/1 [==============================] - 0s 73ms/step
# 1/1 [==============================] - 0s 103ms/step
# 1/1 [==============================] - 0s 74ms/step
# 1/1 [==============================] - 0s 136ms/step
# 1/1 [==============================] - 0s 97ms/step
# 1/1 [==============================] - 0s 83ms/step
# 1/1 [==============================] - 0s 117ms/step
# 1/1 [==============================] - 0s 200ms/step
# 1/1 [==============================] - 0s 111ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 71ms/step
# 1/1 [==============================] - 0s 136ms/step
# 1/1 [==============================] - 0s 172ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 119ms/step
# 1/1 [==============================] - 0s 76ms/step
# 1/1 [==============================] - 0s 80ms/step
# 1/1 [==============================] - 0s 141ms/step
# 1/1 [==============================] - 0s 150ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 108ms/step
# 1/1 [==============================] - 0s 90ms/step
# 1/1 [==============================] - 0s 73ms/step
# 1/1 [==============================] - 0s 120ms/step
# 1/1 [==============================] - 0s 71ms/step
# 1/1 [==============================] - 0s 97ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 57ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 78ms/step
# 1/1 [==============================] - 0s 76ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 118ms/step
# 1/1 [==============================] - 0s 74ms/step
# 1/1 [==============================] - 0s 75ms/step
# 1/1 [==============================] - 0s 91ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 89ms/step
# 1/1 [==============================] - 0s 95ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 90ms/step
# 1/1 [==============================] - 0s 98ms/step
# 1/1 [==============================] - 0s 136ms/step
# 1/1 [==============================] - 0s 91ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 177ms/step
# 1/1 [==============================] - 0s 115ms/step
# 1/1 [==============================] - 0s 72ms/step
# 1/1 [==============================] - 0s 226ms/step
# 1/1 [==============================] - 0s 163ms/step
# 1/1 [==============================] - 0s 85ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 124ms/step
# 1/1 [==============================] - 0s 110ms/step
# 1/1 [==============================] - 0s 75ms/step
# 1/1 [==============================] - 0s 88ms/step
# 1/1 [==============================] - 0s 99ms/step
# 1/1 [==============================] - 0s 108ms/step
# 1/1 [==============================] - 0s 56ms/step
# 1/1 [==============================] - 0s 171ms/step
# 1/1 [==============================] - 0s 100ms/step
# 1/1 [==============================] - 0s 99ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 116ms/step
# 1/1 [==============================] - 0s 137ms/step
# 1/1 [==============================] - 0s 140ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 169ms/step
# 1/1 [==============================] - 0s 92ms/step
# 1/1 [==============================] - 0s 82ms/step
# 1/1 [==============================] - 0s 100ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 57ms/step
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 92ms/step
# 1/1 [==============================] - 0s 117ms/step
# 1/1 [==============================] - 0s 162ms/step
# 1/1 [==============================] - 0s 132ms/step
# 1/1 [==============================] - 0s 107ms/step
# 1/1 [==============================] - 0s 121ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 103ms/step
# 1/1 [==============================] - 0s 99ms/step
# 1/1 [==============================] - 0s 103ms/step
# 1/1 [==============================] - 0s 78ms/step
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 57ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 112ms/step
# 1/1 [==============================] - 0s 108ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 77ms/step
# 1/1 [==============================] - 0s 101ms/step
# 1/1 [==============================] - 0s 102ms/step
# 1/1 [==============================] - 0s 105ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 79ms/step
# 1/1 [==============================] - 0s 84ms/step
# 1/1 [==============================] - 0s 83ms/step
# 1/1 [==============================] - 0s 86ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 133ms/step
# 1/1 [==============================] - 0s 103ms/step
# 1/1 [==============================] - 0s 120ms/step
# 1/1 [==============================] - 0s 78ms/step
# 1/1 [==============================] - 0s 73ms/step
# 1/1 [==============================] - 0s 173ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 133ms/step
# 1/1 [==============================] - 0s 59ms/step
# 1/1 [==============================] - 0s 58ms/step
# 1/1 [==============================] - 0s 74ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 149ms/step
# 1/1 [==============================] - 0s 60ms/step
# 1/1 [==============================] - 0s 71ms/step
# 1/1 [==============================] - 0s 97ms/step
# 1/1 [==============================] - 0s 83ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 103ms/step
# 1/1 [==============================] - 0s 99ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 58ms/step
# 1/1 [==============================] - 0s 108ms/step
# 1/1 [==============================] - 0s 107ms/step
# 1/1 [==============================] - 0s 95ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 95ms/step
# 1/1 [==============================] - 0s 137ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 60ms/step
# 1/1 [==============================] - 0s 105ms/step
# 1/1 [==============================] - 0s 127ms/step
# 1/1 [==============================] - 0s 59ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 129ms/step
# 1/1 [==============================] - 0s 155ms/step
# 1/1 [==============================] - 0s 84ms/step
# 1/1 [==============================] - 0s 121ms/step
# 1/1 [==============================] - 0s 148ms/step
# 1/1 [==============================] - 0s 137ms/step
# 1/1 [==============================] - 0s 73ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 106ms/step
# 1/1 [==============================] - 0s 127ms/step
# 1/1 [==============================] - 0s 89ms/step
# 1/1 [==============================] - 0s 154ms/step
# 1/1 [==============================] - 0s 126ms/step
# 1/1 [==============================] - 0s 106ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 74ms/step
# 1/1 [==============================] - 0s 87ms/step
# 1/1 [==============================] - 0s 118ms/step
# 1/1 [==============================] - 0s 97ms/step
# 1/1 [==============================] - 0s 74ms/step
# 1/1 [==============================] - 0s 57ms/step
# 1/1 [==============================] - 0s 112ms/step
# 1/1 [==============================] - 0s 109ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 140ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 59ms/step
# 1/1 [==============================] - 0s 128ms/step
# 1/1 [==============================] - 0s 119ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 83ms/step
# 1/1 [==============================] - 0s 102ms/step
# 1/1 [==============================] - 0s 91ms/step
# 1/1 [==============================] - 0s 71ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 73ms/step
# 1/1 [==============================] - 0s 91ms/step
# 1/1 [==============================] - 0s 117ms/step
# 1/1 [==============================] - 0s 95ms/step
# 1/1 [==============================] - 0s 88ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 131ms/step
# 1/1 [==============================] - 0s 56ms/step
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 127ms/step
# 1/1 [==============================] - 0s 162ms/step
# 1/1 [==============================] - 0s 180ms/step
# 1/1 [==============================] - 0s 99ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 87ms/step
# 1/1 [==============================] - 0s 79ms/step
# 1/1 [==============================] - 0s 77ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 134ms/step
# 1/1 [==============================] - 0s 146ms/step
# 1/1 [==============================] - 0s 129ms/step
# 1/1 [==============================] - 0s 95ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 120ms/step
# 1/1 [==============================] - 0s 57ms/step
# 1/1 [==============================] - 0s 108ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 79ms/step
# 1/1 [==============================] - 0s 74ms/step
# 2023-06-22 21:48:53.803659: W tensorflow/core/data/root_dataset.cc:266] Optimization loop failed: CANCELLED: Operation was cancelled
# 1/1 [==============================] - 0s 143ms/step
# 1/1 [==============================] - 0s 61ms/step
# 1/1 [==============================] - 0s 119ms/step
# 1/1 [==============================] - 0s 58ms/step
# 1/1 [==============================] - 0s 86ms/step
# 1/1 [==============================] - 0s 78ms/step
# 1/1 [==============================] - 0s 136ms/step
# 1/1 [==============================] - 0s 104ms/step
# 1/1 [==============================] - 0s 146ms/step
# 1/1 [==============================] - 0s 112ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 80ms/step
# 1/1 [==============================] - 0s 56ms/step
# 1/1 [==============================] - 0s 95ms/step
# 1/1 [==============================] - 0s 156ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 119ms/step
# 1/1 [==============================] - 0s 95ms/step
# 1/1 [==============================] - 0s 54ms/step
# 1/1 [==============================] - 0s 71ms/step
# 1/1 [==============================] - 0s 119ms/step
# 1/1 [==============================] - 0s 84ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 57ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 121ms/step
# 1/1 [==============================] - 0s 86ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 123ms/step
# 1/1 [==============================] - 0s 85ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 112ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 100ms/step
# 1/1 [==============================] - 0s 92ms/step
# 1/1 [==============================] - 0s 109ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 121ms/step
# 1/1 [==============================] - 0s 113ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 81ms/step
# 1/1 [==============================] - 0s 101ms/step
# 1/1 [==============================] - 0s 82ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 105ms/step
# 1/1 [==============================] - 0s 114ms/step
# 1/1 [==============================] - 0s 119ms/step
# 1/1 [==============================] - 0s 117ms/step
# 1/1 [==============================] - 0s 77ms/step
# 1/1 [==============================] - 0s 84ms/step
# 1/1 [==============================] - 0s 104ms/step
# 1/1 [==============================] - 0s 95ms/step
# 1/1 [==============================] - 0s 97ms/step
# 1/1 [==============================] - 0s 137ms/step
# 1/1 [==============================] - 0s 139ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 95ms/step
# 1/1 [==============================] - 0s 100ms/step
# 1/1 [==============================] - 0s 122ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 115ms/step
# 1/1 [==============================] - 0s 80ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 72ms/step
# 1/1 [==============================] - 0s 115ms/step
# 1/1 [==============================] - 0s 146ms/step
# 1/1 [==============================] - 0s 112ms/step
# 1/1 [==============================] - 0s 140ms/step
# 1/1 [==============================] - 0s 84ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 106ms/step
# 1/1 [==============================] - 0s 122ms/step
# 1/1 [==============================] - 0s 86ms/step
# 1/1 [==============================] - 0s 78ms/step
# 1/1 [==============================] - 0s 78ms/step
# 1/1 [==============================] - 0s 100ms/step
# 1/1 [==============================] - 0s 126ms/step
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 86ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 114ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 124ms/step
# 1/1 [==============================] - 0s 177ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 136ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 90ms/step
# 1/1 [==============================] - 0s 106ms/step
# 1/1 [==============================] - 0s 124ms/step
# 1/1 [==============================] - 0s 71ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 101ms/step
# 1/1 [==============================] - 0s 72ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 126ms/step
# 1/1 [==============================] - 0s 72ms/step
# 1/1 [==============================] - 0s 98ms/step
# 1/1 [==============================] - 0s 137ms/step
# 1/1 [==============================] - 0s 73ms/step
# 1/1 [==============================] - 0s 76ms/step
# 1/1 [==============================] - 0s 79ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 95ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 98ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 175ms/step
# 1/1 [==============================] - 0s 80ms/step
# 1/1 [==============================] - 0s 146ms/step
# 1/1 [==============================] - 0s 135ms/step
# 1/1 [==============================] - 0s 137ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 124ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 128ms/step
# 1/1 [==============================] - 0s 143ms/step
# 1/1 [==============================] - 0s 78ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 99ms/step
# 1/1 [==============================] - 0s 90ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 114ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 89ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 71ms/step
# 1/1 [==============================] - 0s 146ms/step
# 1/1 [==============================] - 0s 124ms/step
# 1/1 [==============================] - 0s 105ms/step
# 1/1 [==============================] - 0s 127ms/step
# 1/1 [==============================] - 0s 146ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 77ms/step
# 1/1 [==============================] - 0s 61ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 85ms/step
# 1/1 [==============================] - 0s 41ms/step
# CPU times: user 4min 10s, sys: 8min 38s, total: 12min 49s
# Wall time: 3min 35s

# %% [markdown]
# ### 7. Store Training and Predicted history

# %%
import pickle
def save_data(a, name):
    with open('{}.pkl'.format(name), 'wb') as f:
        pickle.dump(a, f) #, protocol=pickle.HIGHEST_PROTOCOL)
    # close file
    f.close()

#from datetime import datetime
#date = datetime.today().strftime('%Y-%m-%d')

## file name
name_train = 'training_history_{}_{}'.format(DNN, case_study)
name_pred = 'prediction_{}_test_{}'.format(DNN, case_study)

if normal_values == False:
    name_train = name_train + '_B'
    name_pred = name_pred + '_B'
if attention == True:
    name_train = name_train + '_attention'
    name_pred = name_pred + '_attention' 

# save train data
save_data(training_history, name_train)
# save test data
save_data(prediction_test, name_pred)

#load
#with open('filename.pickle', 'rb') as handle:
#    b = pickle.load(handle)

# %% [markdown]
# ### 8. Plot results

# %%
### Plot learning performance
number_of_timesteps_for_average = 100
train_DNN.plot_learning_performance(training_history, number_of_timesteps_for_average)

# %%
# average MSE and MAE
avg_mae= round(sum(training_history["MAE"])/len(training_history["MAE"]), 5)
avg_mse=round(sum(training_history["MSE"])/len(training_history["MSE"]), 5)
print('MSE: ',avg_mae)
print('MAE: ',avg_mae)
# Out:
# MSE:  0.23717
# MAE:  0.23717

# %%
### Plot test performance
plot_test_performance(prediction_test[0], prediction_test[1], prediction_test[2], prediction_test[3], prediction_test[4], network)

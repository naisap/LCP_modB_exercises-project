# %% [markdown]
# # CASE 1: **Harmonic oscillator potential**

# %% [markdown]
# ### 1. Inizialization

# %%
# %matplotlib inline

import numpy as np
import matplotlib.pyplot as plt
from scipy.constants import Boltzmann as kB
from numpy.random import randn as gauss
from numpy.random import rand as uniform

case_study = '1D_harmonic'

# %% [markdown]
# ### 2. Generate Trajectories
#
#
# Here it's defined the function that simulates the motion of the Brownian particle in the force field. Particularly, in this case of study, we consider a Brownian particle in a double well trap. The trajectory of the particle depends on two target parameters: the equilibrium distance L and the potential energy barrier height H.
#
# Comments:
#
# 1. The function that simulates the trajectories is *simulate_trajectory*.
# 2. Lambda functions scale_inputs, rescale_inputs, scale_targets, and rescale_targets must also be defined. For the best performance of the learning, the rescaling of both the inputs and targets should lead to values of order 1.

# %%
## define parameters
normal_values = True

# %%
if normal_values == True:
    
    ### follows the parameters used in DeepCalib
    
    ### Physical parameters 
    R = 1e-7                                # Radius of the Brownian particle [m]
    eta = 0.001                             # Viscosity of the medium [kg m^-1 s^-1]
    T = 300                                 # Temperature [K]
    k0 = 10                                 # Reference stiffness [fN \mu m ^-1]
    gamma0 = 6 * np.pi * eta * R            # Reference friction coefficient [kg s^-1]

    ### Simulation parameters
    N = 1000                   # Number of samples of the trajectory
    Dt = 1e-2                  # Timestep 
    oversampling = 5           # Simulation oversampling
    offset = 1000              # Number of equilibration timesteps
    batch_size = 32            # Number of trajectories

    ### Define functions to scale and rescale inputs
    scale_inputs = lambda x: x * 1e+6                    # Scales input trajectory to order 1
    rescale_inputs = lambda scaled_x: scaled_x * 1e-6    # Rescales input trajectory to physical units

    ### Define function to scale and rescale targets
    scale_targets = lambda k: np.log(k / k0)                               # Scales targets to order 1
    rescale_targets = lambda scaled_k: np.exp(scaled_k) * k0               # Inverse of targets_scaling

    def simulate_trajectory(batch_size=batch_size, 
                        T=T,
                        k0=k0,
                        gamma0=gamma0,
                        N=N, 
                        Dt=Dt, 
                        oversampling=oversampling, 
                        offset=offset):
    
        ### Randomize trajectory parameters
        k = k0 * (10**(uniform(batch_size) * 3 - 1.5))     # Generates random stiffness values that are uniformly distributed in log scale
        gamma = gamma0 * (uniform(batch_size) * .1 + .95)   # Marginal randomization of friction coefficient to tolarate small changes

        ### Simulate
        dt = Dt / oversampling                 # time step of the simulation
        x = np.zeros((batch_size, N))          # initialization of the x array
        D = kB * T / gamma                     # diffusion coefficient
        C1 = -k *1e-9 / gamma * dt             # drift coefficient of the Langevin equation
        C3 = np.sqrt(2 * D * dt)               # random walk coefficient of the Langevin equation
        X = x[:, 0]
        n = 0
        
        for t in range(offset):                      # Offset (for some prerun before running)
            X = X + C1 * X + C3 * gauss(batch_size)
            
        for t in range(N * oversampling):            # Simulation                
            X = X + C1 * X + C3 * gauss(batch_size)
            if t % oversampling == 0:                # We save every oversampling^th values 
                x[:, n] = X 
                n += 1
                
        inputs = scale_inputs(x)
        inputs_real = x
        targets = scale_targets(k)
        target_real = k

        return inputs, inputs_real, targets, target_real




else:
    ### larger values: natural units
    
    ### Physical parameters 
    R = 1                                   # Radius of the Brownian particle [m]
    eta = 0.001                             # Viscosity of the medium [kg m^-1 s^-1]
    kB = 1                                  # Boltzmann constant
    T = 1                                   # Temperature [K]
    k0 = 1                                  # Reference stiffness [fN \mu m ^-1]
    gamma0 = 1                              # Reference friction coefficient [kg s^-1]

    ### Simulation parameters
    N = 1000                         # Number of samples of the trajectory
    Dt = 2e-1                       # Timestep 
    oversampling = 5                  # Simulation oversampling
    offset = 1000                     # Number of equilibration timesteps
    batch_size = 32                   # Number of trajectories

    ### Define functions to scale and rescale inputs
    scale_inputs = lambda x: x * 1e+6                    # Scales input trajectory to order 1
    rescale_inputs = lambda scaled_x: scaled_x * 1e-6    # Rescales input trajectory to physical units

    ### Define function to scale and rescale targets
    scale_targets = lambda k: np.log(k / k0)                               # Scales targets to order 1
    rescale_targets = lambda scaled_k: np.exp(scaled_k) * k0               # Inverse of targets_scaling

    def simulate_trajectory(batch_size=batch_size, 
                        T=T,
                        k0=k0,
                        gamma0=gamma0,
                        N=N, 
                        Dt=Dt, 
                        oversampling=oversampling, 
                        offset=offset):#, 
                        #scale_inputs=scale_inputs, 
                        #scale_targets=scale_targets):
    
        ### Randomize trajectory parameters
        k = k0 * (10**(uniform(batch_size) * 3 - 1.5))      # Generates random stiffness values that are uniformly distributed in log scale
        gamma = gamma0 * (uniform(batch_size) * .1 + .95)   # Marginal randomization of friction coefficient to tolarate small changes

        ### Simulate
        dt = Dt / oversampling                 # time step of the simulation
        x = np.zeros((batch_size, N))          # initialization of the x array
        D = 1                                  # diffusion coefficient
        C1 = -k * 1 / 1 * dt                   # drift coefficient of the Langevin equation
        C3 = np.sqrt(2 * D * dt)               # random walk coefficient of the Langevin equation
        X = x[:, 0]
        n = 0
        
        for t in range(offset):                      # Offset (for some prerun before running)
            X = X + C1 * X + C3 * gauss(batch_size)
            
        for t in range(N * oversampling):            # Simulation                
            X = X + C1 * X + C3 * gauss(batch_size)
            if t % oversampling == 0:                # We save every oversampling^th values 
                x[:, n] = X 
                n += 1
                
        inputs = scale_inputs(x*1e-6)
        inputs_real = x*1e-6
        targets = scale_targets(k)
        target_real = k

        return inputs, inputs_real, targets, target_real

# %% [markdown]
# ### 3. Plot Trajectory Simulation

# %%
def plot_sample_trajectories(simulate_trajectory, number_of_trajectories_to_show):
    """
    
    Inputs:   
    
    simulate_trajectory:                 trajectroy generator function
    number_of_trajectories_to_show:      number of trajectories to be plotted as sample  
        
    Output:
    
    This function does not return any outputs, it only plots some sample trajectories to preview the generator function
   
    """ 
    import matplotlib.pyplot as plt
    inputs, targets = simulate_trajectory(number_of_trajectories_to_show)
    
    if len(inputs.names)>1:
        for scaled_values, scaled_targets, target_values in zip(inputs.scaled_values, targets.scaled_values, targets.values):
            plt.figure(figsize=(20, 5))    
            number_subplots = len(inputs.names)
            for subplot in range(number_subplots):
                plt.subplot(1, number_subplots, subplot+1)
                plt.plot(scaled_values[subplot])
                plt.xlabel('timestep', fontsize=18)
                plt.ylabel(inputs.scalings[subplot], fontsize=18)   

            title_text = 'Parameters: ' 
            for parameter in range(len(target_values)):
                title_text +=  ', ' + targets.names[parameter] + ' = ' + '%1.2e' % target_values[parameter]
            plt.title(title_text, fontsize=18)  

    else:
        for scaled_values, scaled_targets, target_values in zip(inputs.scaled_values, targets.scaled_values, targets.values):
            plt.figure(figsize=(20, 5))
            plt.plot(scaled_values)
            plt.xlabel('timestep', fontsize=18)
            plt.ylabel(inputs.scalings[0], fontsize=18)
            title_text = 'Parameters: ' 
            if len(targets.names)>1:
                for parameter in range(len(targets.names)):
                    title_text +=  ', ' + targets.names[parameter] + ' = ' + '%1.2e' % target_values[parameter]
                plt.title(title_text, fontsize=18)  
            else:
                plt.title(title_text + ' ' + targets.names[0] + ' = ' + '%1.2e' % target_values , fontsize=18)

# %%
### Show some examples of simulated trajectories
number_of_trajectories_to_show= 10
plot_sample_trajectories(simulate_trajectory, number_of_trajectories_to_show)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[5], line 3
#       1 ### Show some examples of simulated trajectories
#       2 number_of_trajectories_to_show= 10
# ----> 3 plot_sample_trajectories(simulate_trajectory, number_of_trajectories_to_show)
#
# Cell In[4], line 15, in plot_sample_trajectories(simulate_trajectory, number_of_trajectories_to_show)
#       2 """
#       3
#       4 Inputs:
#    (...)
#      12
#      13 """
#      14 import matplotlib.pyplot as plt
# ---> 15 inputs, targets = simulate_trajectory(number_of_trajectories_to_show)
#      17 if len(inputs.names)>1:
#      18     for scaled_values, scaled_targets, target_values in zip(inputs.scaled_values, targets.scaled_values, targets.values):
#
# ValueError: too many values to unpack (expected 2)

# %%
trajectory, _, target, target_real = simulate_trajectory(batch_size)
print(trajectory[0,:].shape)
plt.plot(trajectory[0,:])
# Out:
# (1000,)

# %%
a=plt.hist(trajectory[0])#x[0])
plt.show()
a_1,a_2 = a[0],a[1]

plt.plot(a_2[:-1],-np.log(a_1))
plt.show()

# %% [markdown]
# ### 4. COMPILE Deep Neural Network
#
# The parameters of the deep learning network are defined and the network created. The summary of the network is printed where the output shape and number of parameters for each layer can be visualized.
#
# Comments:
#
# 1. The parameter input_shape determines the shape of the input sequence, given by the number of time-steps times the number of samples in each input sequence. Make sure your input shape dimensions match the length of the input trajectory, in this example 2 x 500 = 1000.
# 2. The parmameter conv_layers_dimensions determines the number and size of LSTM layers.
# 3. The parameter number_of_outputs determines the number of outputs, i.e. the number of force field parameters to be estimated.

# %% [markdown]
# #### LSTM with attention
#
# CREATE MODEL

# %%
from src_models import models_DNN, train_DNN, test_DNN
# Out:
# 2023-06-22 20:22:50.658872: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 AVX512F AVX512_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
### Define parameters of the deep learning network
input_shape = (None, 50)      
lstm_layers_dimensions = (250, 50)
number_of_outputs = 1

DNN = 'GRU'
attention = False

### Create deep learning network
network = models_DNN.create_deep_learning_network(input_shape, lstm_layers_dimensions, number_of_outputs, 
                                                      DNN,
                                                      attention)

### Print deep learning network summary
network.summary()
# Out:
# 2023-06-22 20:22:57.687865: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 AVX512F AVX512_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-06-22 20:22:57.688234: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 2. Tune using inter_op_parallelism_threads for best performance.
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_1 (GRU)                (None, None, 250)         226500
#
#  lstm_2 (GRU)                (None, 50)                45300
#
#  output (Dense)              (None, 1)                 51
#
# =================================================================
# Total params: 271,851
# Trainable params: 271,851
# Non-trainable params: 0
# _________________________________________________________________
# /home/david/anaconda3/envs/firstenv/lib/python3.10/site-packages/keras/optimizers/optimizer_v2/adam.py:117: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super().__init__(name, **kwargs)

# %% [markdown]
# ### 5. TRAIN Deep Neural Network
#
# The parameters for the training of the deep learning network are defined and the network is trained. The sample size, iteration number, MSE, MAE and the time of each iteration is printed.
#
# Comments:
#
# The parameter sample_sizes determines the sizes of the batches of trajectories used in the training.
# The parameter iteration_numbers determines the numbers of batches used in the training.
# The parameter verbose determines the frequency of the update messages. It can be either a boolean value (True/False) or a number between 0 and 1.

# %%
# %%time

sample_sizes = (32, 128, 512)#(32, 128, 512, 2048),
iteration_numbers = (3001, 2001, 1001)#(1001, 2001, 3001),#(3001, 2001, 1001, 101),
verbose = .1

training_history = train_DNN.train_deep_learning_network(network, simulate_trajectory, sample_sizes, iteration_numbers, verbose)
# Out:
# Sample size     32   iteration number      1   MSE     4.8626   MAE     1.9225   Time 5902.504444 ms
# Sample size     32   iteration number     11   MSE     1.4513   MAE     1.0563   Time 389.546394 ms
# Sample size     32   iteration number     21   MSE     0.8574   MAE     0.8001   Time 372.792482 ms
# Sample size     32   iteration number     31   MSE     0.4091   MAE     0.5153   Time 289.171696 ms
# Sample size     32   iteration number     41   MSE     0.3782   MAE     0.4938   Time 450.895786 ms
# Sample size     32   iteration number     51   MSE     0.2668   MAE     0.4215   Time 336.564779 ms
# Sample size     32   iteration number     61   MSE     0.3256   MAE     0.4285   Time 327.122927 ms
# Sample size     32   iteration number     71   MSE     0.3416   MAE     0.4761   Time 486.043215 ms
# Sample size     32   iteration number     81   MSE     0.1705   MAE     0.3624   Time 376.645565 ms
# Sample size     32   iteration number     91   MSE     0.1694   MAE     0.3279   Time 425.572634 ms
# Sample size     32   iteration number    101   MSE     0.1946   MAE     0.3605   Time 437.767506 ms
# Sample size     32   iteration number    111   MSE     0.2276   MAE     0.3763   Time 536.988974 ms
# Sample size     32   iteration number    121   MSE     0.1918   MAE     0.3768   Time 330.539942 ms
# Sample size     32   iteration number    131   MSE     0.3094   MAE     0.4143   Time 243.147135 ms
# Sample size     32   iteration number    141   MSE     0.1270   MAE     0.2755   Time 392.930269 ms
# Sample size     32   iteration number    151   MSE     0.2447   MAE     0.3519   Time 888.262987 ms
# Sample size     32   iteration number    161   MSE     0.1815   MAE     0.3398   Time 389.583588 ms
# Sample size     32   iteration number    171   MSE     0.1698   MAE     0.2955   Time 493.327856 ms
# Sample size     32   iteration number    181   MSE     0.0807   MAE     0.2237   Time 680.307627 ms
# Sample size     32   iteration number    191   MSE     0.1581   MAE     0.3176   Time 474.922657 ms
# Sample size     32   iteration number    201   MSE     0.1143   MAE     0.2416   Time 308.812380 ms
# Sample size     32   iteration number    211   MSE     0.1466   MAE     0.2868   Time 289.714098 ms
# Sample size     32   iteration number    221   MSE     0.1165   MAE     0.2265   Time 688.402653 ms
# Sample size     32   iteration number    231   MSE     0.0938   MAE     0.2117   Time 422.013521 ms
# Sample size     32   iteration number    241   MSE     0.1530   MAE     0.2801   Time 402.317762 ms
# Sample size     32   iteration number    251   MSE     0.0740   MAE     0.2061   Time 518.312216 ms
# Sample size     32   iteration number    261   MSE     0.3120   MAE     0.3629   Time 294.299841 ms
# Sample size     32   iteration number    271   MSE     0.1825   MAE     0.3503   Time 466.563225 ms
# Sample size     32   iteration number    281   MSE     0.1323   MAE     0.2699   Time 280.692577 ms
# Sample size     32   iteration number    291   MSE     0.1724   MAE     0.3416   Time 374.332428 ms
# Sample size     32   iteration number    301   MSE     0.2280   MAE     0.3382   Time 1116.899014 ms
# Sample size     32   iteration number    311   MSE     0.1627   MAE     0.3070   Time 670.879602 ms
# Sample size     32   iteration number    321   MSE     0.1456   MAE     0.3026   Time 480.347633 ms
# Sample size     32   iteration number    331   MSE     0.1264   MAE     0.2814   Time 200.729609 ms
# Sample size     32   iteration number    341   MSE     0.2166   MAE     0.3345   Time 376.707554 ms
# Sample size     32   iteration number    351   MSE     0.1426   MAE     0.2832   Time 496.022463 ms
# Sample size     32   iteration number    361   MSE     0.1156   MAE     0.2789   Time 549.641609 ms
# Sample size     32   iteration number    371   MSE     0.1602   MAE     0.3116   Time 503.499269 ms
# Sample size     32   iteration number    381   MSE     0.1125   MAE     0.2742   Time 433.206797 ms
# Sample size     32   iteration number    391   MSE     0.0952   MAE     0.2581   Time 1030.802011 ms
# Sample size     32   iteration number    401   MSE     0.0987   MAE     0.2549   Time 368.835926 ms
# Sample size     32   iteration number    411   MSE     0.0845   MAE     0.2238   Time 339.730024 ms
# Sample size     32   iteration number    421   MSE     0.1729   MAE     0.3133   Time 658.950806 ms
# Sample size     32   iteration number    431   MSE     0.1512   MAE     0.3039   Time 350.455284 ms
# Sample size     32   iteration number    441   MSE     0.1037   MAE     0.2405   Time 428.479433 ms
# Sample size     32   iteration number    451   MSE     0.1229   MAE     0.2402   Time 890.988827 ms
# Sample size     32   iteration number    461   MSE     0.1578   MAE     0.3277   Time 350.413561 ms
# Sample size     32   iteration number    471   MSE     0.1010   MAE     0.2514   Time 339.242220 ms
# Sample size     32   iteration number    481   MSE     0.0937   MAE     0.2167   Time 348.954439 ms
# Sample size     32   iteration number    491   MSE     0.1183   MAE     0.2294   Time 400.701523 ms
# Sample size     32   iteration number    501   MSE     0.1179   MAE     0.2315   Time 365.818977 ms
# Sample size     32   iteration number    511   MSE     0.1239   MAE     0.2545   Time 280.321598 ms
# Sample size     32   iteration number    521   MSE     0.1317   MAE     0.2778   Time 691.448212 ms
# Sample size     32   iteration number    531   MSE     0.1364   MAE     0.2552   Time 541.230202 ms
# Sample size     32   iteration number    541   MSE     0.2218   MAE     0.3237   Time 447.944403 ms
# Sample size     32   iteration number    551   MSE     0.1027   MAE     0.2332   Time 837.333441 ms
# Sample size     32   iteration number    561   MSE     0.0732   MAE     0.2138   Time 537.300348 ms
# Sample size     32   iteration number    571   MSE     0.0382   MAE     0.1713   Time 554.749727 ms
# Sample size     32   iteration number    581   MSE     0.2558   MAE     0.3616   Time 525.342941 ms
# Sample size     32   iteration number    591   MSE     0.2065   MAE     0.3479   Time 372.239351 ms
# Sample size     32   iteration number    601   MSE     0.1086   MAE     0.2579   Time 545.332432 ms
# Sample size     32   iteration number    611   MSE     0.1107   MAE     0.2399   Time 359.231472 ms
# Sample size     32   iteration number    621   MSE     0.2453   MAE     0.2839   Time 451.013565 ms
# Sample size     32   iteration number    631   MSE     0.1310   MAE     0.2964   Time 515.482426 ms
# Sample size     32   iteration number    641   MSE     0.1142   MAE     0.2774   Time 931.906223 ms
# Sample size     32   iteration number    651   MSE     0.1190   MAE     0.2466   Time 667.209864 ms
# Sample size     32   iteration number    661   MSE     0.1625   MAE     0.2861   Time 589.324713 ms
# Sample size     32   iteration number    671   MSE     0.4118   MAE     0.3053   Time 750.670195 ms
# Sample size     32   iteration number    681   MSE     0.0992   MAE     0.2444   Time 611.736059 ms
# Sample size     32   iteration number    691   MSE     0.0927   MAE     0.2298   Time 449.444532 ms
# Sample size     32   iteration number    701   MSE     0.1792   MAE     0.2891   Time 825.991631 ms
# Sample size     32   iteration number    711   MSE     0.0731   MAE     0.1935   Time 769.901752 ms
# Sample size     32   iteration number    721   MSE     0.1184   MAE     0.2562   Time 481.786013 ms
# Sample size     32   iteration number    731   MSE     0.1614   MAE     0.2599   Time 668.853760 ms
# Sample size     32   iteration number    741   MSE     0.1579   MAE     0.3346   Time 298.765421 ms
# Sample size     32   iteration number    751   MSE     0.1237   MAE     0.2671   Time 1169.285536 ms
# Sample size     32   iteration number    761   MSE     0.1267   MAE     0.2207   Time 363.498449 ms
# Sample size     32   iteration number    771   MSE     0.1749   MAE     0.3006   Time 313.379526 ms
# Sample size     32   iteration number    781   MSE     0.2335   MAE     0.3105   Time 442.628384 ms
# Sample size     32   iteration number    791   MSE     0.1079   MAE     0.2341   Time 521.020174 ms
# Sample size     32   iteration number    801   MSE     0.0823   MAE     0.2286   Time 628.921032 ms
# Sample size     32   iteration number    811   MSE     0.1359   MAE     0.2984   Time 471.189976 ms
# Sample size     32   iteration number    821   MSE     0.0770   MAE     0.2080   Time 768.623590 ms
# Sample size     32   iteration number    831   MSE     0.0944   MAE     0.2008   Time 614.915609 ms
# Sample size     32   iteration number    841   MSE     0.1624   MAE     0.2722   Time 253.185511 ms
# Sample size     32   iteration number    851   MSE     0.1860   MAE     0.2888   Time 777.607441 ms
# Sample size     32   iteration number    861   MSE     0.1187   MAE     0.2260   Time 591.820955 ms
# Sample size     32   iteration number    871   MSE     0.0888   MAE     0.2117   Time 722.823381 ms
# Sample size     32   iteration number    881   MSE     0.1280   MAE     0.2752   Time 448.180199 ms
# Sample size     32   iteration number    891   MSE     0.1074   MAE     0.2536   Time 776.256800 ms
# Sample size     32   iteration number    901   MSE     0.0693   MAE     0.2007   Time 419.989109 ms
# Sample size     32   iteration number    911   MSE     0.0981   MAE     0.2123   Time 468.838692 ms
# Sample size     32   iteration number    921   MSE     0.1782   MAE     0.2989   Time 362.128735 ms
# Sample size     32   iteration number    931   MSE     0.1008   MAE     0.2408   Time 432.047367 ms
# Sample size     32   iteration number    941   MSE     0.0860   MAE     0.2241   Time 216.503143 ms
# Sample size     32   iteration number    951   MSE     0.1088   MAE     0.2355   Time 395.393610 ms
# Sample size     32   iteration number    961   MSE     0.2133   MAE     0.3649   Time 351.251602 ms
# Sample size     32   iteration number    971   MSE     0.1002   MAE     0.2331   Time 527.188778 ms
# Sample size     32   iteration number    981   MSE     0.1366   MAE     0.2595   Time 463.895559 ms
# Sample size     32   iteration number    991   MSE     0.0980   MAE     0.2261   Time 344.694853 ms
# Sample size     32   iteration number   1001   MSE     0.0763   MAE     0.2094   Time 278.665304 ms
# Sample size     32   iteration number   1011   MSE     0.2756   MAE     0.3531   Time 482.439041 ms
# Sample size     32   iteration number   1021   MSE     0.0834   MAE     0.2006   Time 312.730551 ms
# Sample size     32   iteration number   1031   MSE     0.1225   MAE     0.2252   Time 462.786436 ms
# Sample size     32   iteration number   1041   MSE     0.2760   MAE     0.3654   Time 660.885572 ms
# Sample size     32   iteration number   1051   MSE     0.1626   MAE     0.2741   Time 445.900202 ms
# Sample size     32   iteration number   1061   MSE     0.1861   MAE     0.3140   Time 374.818325 ms
# Sample size     32   iteration number   1071   MSE     0.2406   MAE     0.3370   Time 220.715523 ms
# Sample size     32   iteration number   1081   MSE     0.1039   MAE     0.2459   Time 994.054794 ms
# Sample size     32   iteration number   1091   MSE     0.2118   MAE     0.3175   Time 454.828262 ms
# Sample size     32   iteration number   1101   MSE     0.0899   MAE     0.2322   Time 322.211981 ms
# Sample size     32   iteration number   1111   MSE     0.0636   MAE     0.1821   Time 445.686579 ms
# Sample size     32   iteration number   1121   MSE     0.0939   MAE     0.2500   Time 436.446905 ms
# Sample size     32   iteration number   1131   MSE     0.1050   MAE     0.2444   Time 1363.960028 ms
# Sample size     32   iteration number   1141   MSE     0.2265   MAE     0.3162   Time 690.408707 ms
# Sample size     32   iteration number   1151   MSE     0.2411   MAE     0.3426   Time 197.942019 ms
# Sample size     32   iteration number   1161   MSE     0.0921   MAE     0.2163   Time 492.673397 ms
# Sample size     32   iteration number   1171   MSE     0.1129   MAE     0.2377   Time 766.446114 ms
# Sample size     32   iteration number   1181   MSE     0.2119   MAE     0.3024   Time 761.621475 ms
# Sample size     32   iteration number   1191   MSE     0.1525   MAE     0.2792   Time 379.466295 ms
# Sample size     32   iteration number   1201   MSE     0.1401   MAE     0.2810   Time 493.597507 ms
# Sample size     32   iteration number   1211   MSE     0.0751   MAE     0.2096   Time 387.116432 ms
# Sample size     32   iteration number   1221   MSE     0.0963   MAE     0.2303   Time 977.322102 ms
# Sample size     32   iteration number   1231   MSE     0.1861   MAE     0.2700   Time 756.045103 ms
# Sample size     32   iteration number   1241   MSE     0.1808   MAE     0.3060   Time 530.658722 ms
# Sample size     32   iteration number   1251   MSE     0.0701   MAE     0.2160   Time 720.534563 ms
# Sample size     32   iteration number   1261   MSE     0.1461   MAE     0.2532   Time 543.308735 ms
# Sample size     32   iteration number   1271   MSE     0.1117   MAE     0.2405   Time 677.767277 ms
# Sample size     32   iteration number   1281   MSE     0.1583   MAE     0.2919   Time 366.820335 ms
# Sample size     32   iteration number   1291   MSE     0.2230   MAE     0.3299   Time 430.891514 ms
# Sample size     32   iteration number   1301   MSE     0.1226   MAE     0.2434   Time 648.101330 ms
# Sample size     32   iteration number   1311   MSE     0.1598   MAE     0.2920   Time 560.306549 ms
# Sample size     32   iteration number   1321   MSE     0.1862   MAE     0.2909   Time 504.899979 ms
# Sample size     32   iteration number   1331   MSE     0.1556   MAE     0.2701   Time 545.280457 ms
# Sample size     32   iteration number   1341   MSE     0.2326   MAE     0.2738   Time 511.444092 ms
# Sample size     32   iteration number   1351   MSE     0.1233   MAE     0.2773   Time 363.102674 ms
# Sample size     32   iteration number   1361   MSE     0.0790   MAE     0.2386   Time 509.996891 ms
# Sample size     32   iteration number   1371   MSE     0.0714   MAE     0.1889   Time 855.655909 ms
# Sample size     32   iteration number   1381   MSE     0.1727   MAE     0.2277   Time 1200.350523 ms
# Sample size     32   iteration number   1391   MSE     0.0759   MAE     0.2050   Time 332.238913 ms
# Sample size     32   iteration number   1401   MSE     0.1439   MAE     0.2634   Time 732.070446 ms
# Sample size     32   iteration number   1411   MSE     0.1564   MAE     0.2967   Time 495.649099 ms
# Sample size     32   iteration number   1421   MSE     0.1760   MAE     0.2634   Time 473.990202 ms
# Sample size     32   iteration number   1431   MSE     0.1765   MAE     0.2561   Time 1022.719145 ms
# Sample size     32   iteration number   1441   MSE     0.1004   MAE     0.1935   Time 365.115404 ms
# Sample size     32   iteration number   1451   MSE     0.1128   MAE     0.2372   Time 842.066288 ms
# Sample size     32   iteration number   1461   MSE     0.1129   MAE     0.2298   Time 579.129696 ms
# Sample size     32   iteration number   1471   MSE     0.2065   MAE     0.3278   Time 551.533937 ms
# Sample size     32   iteration number   1481   MSE     0.0935   MAE     0.2510   Time 388.978243 ms
# Sample size     32   iteration number   1491   MSE     0.1261   MAE     0.2323   Time 313.827515 ms
# Sample size     32   iteration number   1501   MSE     0.1272   MAE     0.2461   Time 679.725409 ms
# Sample size     32   iteration number   1511   MSE     0.2615   MAE     0.3562   Time 781.188726 ms
# Sample size     32   iteration number   1521   MSE     0.1051   MAE     0.2212   Time 631.003141 ms
# Sample size     32   iteration number   1531   MSE     0.1759   MAE     0.3350   Time 409.312487 ms
# Sample size     32   iteration number   1541   MSE     0.0594   MAE     0.1962   Time 270.188332 ms
# Sample size     32   iteration number   1551   MSE     0.0883   MAE     0.2264   Time 1008.259535 ms
# Sample size     32   iteration number   1561   MSE     0.1367   MAE     0.2818   Time 755.632401 ms
# Sample size     32   iteration number   1571   MSE     0.1259   MAE     0.2883   Time 362.922430 ms
# Sample size     32   iteration number   1581   MSE     0.0691   MAE     0.1916   Time 942.894220 ms
# Sample size     32   iteration number   1591   MSE     0.1712   MAE     0.2787   Time 432.256699 ms
# Sample size     32   iteration number   1601   MSE     0.0638   MAE     0.1956   Time 1004.942656 ms
# Sample size     32   iteration number   1611   MSE     0.0990   MAE     0.2368   Time 449.384928 ms
# Sample size     32   iteration number   1621   MSE     0.1843   MAE     0.2813   Time 743.440390 ms
# Sample size     32   iteration number   1631   MSE     0.0651   MAE     0.1825   Time 471.472979 ms
# Sample size     32   iteration number   1641   MSE     0.0753   MAE     0.1974   Time 389.230967 ms
# Sample size     32   iteration number   1651   MSE     0.0923   MAE     0.2191   Time 377.464056 ms
# Sample size     32   iteration number   1661   MSE     0.0571   MAE     0.1684   Time 608.281136 ms
# Sample size     32   iteration number   1671   MSE     0.1293   MAE     0.2097   Time 565.535069 ms
# Sample size     32   iteration number   1681   MSE     0.1288   MAE     0.2444   Time 646.379232 ms
# Sample size     32   iteration number   1691   MSE     0.0892   MAE     0.1992   Time 1053.775311 ms
# Sample size     32   iteration number   1701   MSE     0.0601   MAE     0.1708   Time 781.548977 ms
# Sample size     32   iteration number   1711   MSE     0.1281   MAE     0.2457   Time 1015.673399 ms
# Sample size     32   iteration number   1721   MSE     0.1487   MAE     0.2340   Time 394.977331 ms
# Sample size     32   iteration number   1731   MSE     0.1321   MAE     0.2540   Time 897.137165 ms
# Sample size     32   iteration number   1741   MSE     0.1806   MAE     0.2800   Time 663.619757 ms
# Sample size     32   iteration number   1751   MSE     0.1962   MAE     0.2734   Time 385.109425 ms
# Sample size     32   iteration number   1761   MSE     0.1408   MAE     0.2440   Time 320.517778 ms
# Sample size     32   iteration number   1771   MSE     0.1490   MAE     0.2914   Time 389.768124 ms
# Sample size     32   iteration number   1781   MSE     0.0970   MAE     0.2303   Time 398.290634 ms
# Sample size     32   iteration number   1791   MSE     0.1452   MAE     0.2319   Time 358.628035 ms
# Sample size     32   iteration number   1801   MSE     0.1146   MAE     0.2277   Time 297.056913 ms
# Sample size     32   iteration number   1811   MSE     0.2621   MAE     0.3773   Time 587.420940 ms
# Sample size     32   iteration number   1821   MSE     0.1197   MAE     0.2553   Time 558.184385 ms
# Sample size     32   iteration number   1831   MSE     0.1144   MAE     0.2536   Time 555.619717 ms
# Sample size     32   iteration number   1841   MSE     0.1709   MAE     0.2442   Time 555.592299 ms
# Sample size     32   iteration number   1851   MSE     0.1394   MAE     0.2480   Time 197.921038 ms
# Sample size     32   iteration number   1861   MSE     0.1137   MAE     0.2618   Time 475.375175 ms
# Sample size     32   iteration number   1871   MSE     0.1791   MAE     0.3439   Time 557.737589 ms
# Sample size     32   iteration number   1881   MSE     0.0505   MAE     0.1770   Time 488.224268 ms
# Sample size     32   iteration number   1891   MSE     0.3158   MAE     0.3766   Time 489.953995 ms
# Sample size     32   iteration number   1901   MSE     0.0562   MAE     0.1598   Time 708.950043 ms
# Sample size     32   iteration number   1911   MSE     0.1037   MAE     0.2375   Time 455.312729 ms
# Sample size     32   iteration number   1921   MSE     0.1073   MAE     0.2226   Time 495.307207 ms
# Sample size     32   iteration number   1931   MSE     0.1587   MAE     0.2634   Time 507.097006 ms
# Sample size     32   iteration number   1941   MSE     0.2223   MAE     0.3456   Time 567.326546 ms
# Sample size     32   iteration number   1951   MSE     0.0933   MAE     0.2071   Time 597.094059 ms
# Sample size     32   iteration number   1961   MSE     0.1267   MAE     0.2575   Time 389.989138 ms
# Sample size     32   iteration number   1971   MSE     0.1120   MAE     0.2537   Time 223.665714 ms
# Sample size     32   iteration number   1981   MSE     0.0927   MAE     0.2130   Time 714.699507 ms
# Sample size     32   iteration number   1991   MSE     0.0813   MAE     0.2203   Time 375.651121 ms
# Sample size     32   iteration number   2001   MSE     0.0634   MAE     0.1950   Time 627.416134 ms
# Sample size     32   iteration number   2011   MSE     0.0891   MAE     0.2113   Time 160.948992 ms
# Sample size     32   iteration number   2021   MSE     0.1056   MAE     0.2247   Time 693.136215 ms
# Sample size     32   iteration number   2031   MSE     0.1786   MAE     0.2981   Time 417.246819 ms
# Sample size     32   iteration number   2041   MSE     0.2347   MAE     0.3389   Time 528.724194 ms
# Sample size     32   iteration number   2051   MSE     0.0757   MAE     0.2140   Time 1077.911854 ms
# Sample size     32   iteration number   2061   MSE     0.1137   MAE     0.2433   Time 556.985855 ms
# Sample size     32   iteration number   2071   MSE     0.0634   MAE     0.1847   Time 1121.850014 ms
# Sample size     32   iteration number   2081   MSE     0.2297   MAE     0.3098   Time 814.529657 ms
# Sample size     32   iteration number   2091   MSE     0.1075   MAE     0.2327   Time 640.673637 ms
# Sample size     32   iteration number   2101   MSE     0.0949   MAE     0.2405   Time 338.739634 ms
# Sample size     32   iteration number   2111   MSE     0.1018   MAE     0.2322   Time 406.871080 ms
# Sample size     32   iteration number   2121   MSE     0.1571   MAE     0.2433   Time 695.254564 ms
# Sample size     32   iteration number   2131   MSE     0.0820   MAE     0.2112   Time 285.344839 ms
# Sample size     32   iteration number   2141   MSE     0.1603   MAE     0.3134   Time 149.816751 ms
# Sample size     32   iteration number   2151   MSE     0.1530   MAE     0.2947   Time 372.217178 ms
# Sample size     32   iteration number   2161   MSE     0.0653   MAE     0.1697   Time 268.306494 ms
# Sample size     32   iteration number   2171   MSE     0.1262   MAE     0.2808   Time 436.997890 ms
# Sample size     32   iteration number   2181   MSE     0.1444   MAE     0.2524   Time 981.536627 ms
# Sample size     32   iteration number   2191   MSE     0.2285   MAE     0.2787   Time 831.948280 ms
# Sample size     32   iteration number   2201   MSE     0.0533   MAE     0.1735   Time 831.665516 ms
# Sample size     32   iteration number   2211   MSE     0.1125   MAE     0.2487   Time 477.280378 ms
# Sample size     32   iteration number   2221   MSE     0.1608   MAE     0.2570   Time 771.618605 ms
# Sample size     32   iteration number   2231   MSE     0.0719   MAE     0.1895   Time 852.558136 ms
# Sample size     32   iteration number   2241   MSE     0.1592   MAE     0.2845   Time 452.414274 ms
# Sample size     32   iteration number   2251   MSE     0.0408   MAE     0.1560   Time 541.348219 ms
# Sample size     32   iteration number   2261   MSE     0.0869   MAE     0.2136   Time 281.275749 ms
# Sample size     32   iteration number   2271   MSE     0.1075   MAE     0.2553   Time 358.588696 ms
# Sample size     32   iteration number   2281   MSE     0.1733   MAE     0.2967   Time 323.041916 ms
# Sample size     32   iteration number   2291   MSE     0.1264   MAE     0.2580   Time 789.972305 ms
# Sample size     32   iteration number   2301   MSE     0.1645   MAE     0.3082   Time 650.487661 ms
# Sample size     32   iteration number   2311   MSE     0.0968   MAE     0.2198   Time 776.170254 ms
# Sample size     32   iteration number   2321   MSE     0.2320   MAE     0.3082   Time 691.095114 ms
# Sample size     32   iteration number   2331   MSE     0.1733   MAE     0.2436   Time 603.674173 ms
# Sample size     32   iteration number   2341   MSE     0.0477   MAE     0.1617   Time 939.841270 ms
# Sample size     32   iteration number   2351   MSE     0.0879   MAE     0.1929   Time 488.037586 ms
# Sample size     32   iteration number   2361   MSE     0.1913   MAE     0.3276   Time 949.963808 ms
# Sample size     32   iteration number   2371   MSE     0.0822   MAE     0.2273   Time 881.271362 ms
# Sample size     32   iteration number   2381   MSE     0.0832   MAE     0.2295   Time 843.971729 ms
# Sample size     32   iteration number   2391   MSE     0.1495   MAE     0.2480   Time 754.862547 ms
# Sample size     32   iteration number   2401   MSE     0.2135   MAE     0.3365   Time 653.125763 ms
# Sample size     32   iteration number   2411   MSE     0.0603   MAE     0.1814   Time 326.988935 ms
# Sample size     32   iteration number   2421   MSE     0.2026   MAE     0.3116   Time 334.398031 ms
# Sample size     32   iteration number   2431   MSE     0.0796   MAE     0.2249   Time 356.800556 ms
# Sample size     32   iteration number   2441   MSE     0.0563   MAE     0.1900   Time 286.692142 ms
# Sample size     32   iteration number   2451   MSE     0.1081   MAE     0.2205   Time 765.270710 ms
# Sample size     32   iteration number   2461   MSE     0.1534   MAE     0.2772   Time 262.114763 ms
# Sample size     32   iteration number   2471   MSE     0.1123   MAE     0.2655   Time 298.803329 ms
# Sample size     32   iteration number   2481   MSE     0.0974   MAE     0.2482   Time 412.155867 ms
# Sample size     32   iteration number   2491   MSE     0.1248   MAE     0.2436   Time 383.847713 ms
# Sample size     32   iteration number   2501   MSE     0.1935   MAE     0.2843   Time 547.682047 ms
# Sample size     32   iteration number   2511   MSE     0.1797   MAE     0.2641   Time 375.395775 ms
# Sample size     32   iteration number   2521   MSE     0.2417   MAE     0.3773   Time 468.669891 ms
# Sample size     32   iteration number   2531   MSE     0.0963   MAE     0.2185   Time 645.421267 ms
# Sample size     32   iteration number   2541   MSE     0.1055   MAE     0.2251   Time 266.744137 ms
# Sample size     32   iteration number   2551   MSE     0.1461   MAE     0.2904   Time 664.378166 ms
# Sample size     32   iteration number   2561   MSE     0.1584   MAE     0.2371   Time 659.803867 ms
# Sample size     32   iteration number   2571   MSE     0.1265   MAE     0.2686   Time 326.700211 ms
# Sample size     32   iteration number   2581   MSE     0.1461   MAE     0.2708   Time 981.408834 ms
# Sample size     32   iteration number   2591   MSE     0.0731   MAE     0.2029   Time 378.769398 ms
# Sample size     32   iteration number   2601   MSE     0.1510   MAE     0.2743   Time 329.421043 ms
# Sample size     32   iteration number   2611   MSE     0.1367   MAE     0.2519   Time 662.142754 ms
# Sample size     32   iteration number   2621   MSE     0.0496   MAE     0.1635   Time 355.307102 ms
# Sample size     32   iteration number   2631   MSE     0.0927   MAE     0.2045   Time 357.915401 ms
# Sample size     32   iteration number   2641   MSE     0.1223   MAE     0.2137   Time 260.165691 ms
# Sample size     32   iteration number   2651   MSE     0.1633   MAE     0.2922   Time 375.891447 ms
# Sample size     32   iteration number   2661   MSE     0.1922   MAE     0.3275   Time 610.659122 ms
# Sample size     32   iteration number   2671   MSE     0.0962   MAE     0.2088   Time 648.850441 ms
# Sample size     32   iteration number   2681   MSE     0.1570   MAE     0.3086   Time 264.469147 ms
# Sample size     32   iteration number   2691   MSE     0.0960   MAE     0.2352   Time 596.271276 ms
# Sample size     32   iteration number   2701   MSE     0.1016   MAE     0.2211   Time 762.201548 ms
# Sample size     32   iteration number   2711   MSE     0.0612   MAE     0.1844   Time 389.826059 ms
# Sample size     32   iteration number   2721   MSE     0.2107   MAE     0.3548   Time 528.232098 ms
# Sample size     32   iteration number   2731   MSE     0.1884   MAE     0.2993   Time 849.558830 ms
# Sample size     32   iteration number   2741   MSE     0.0852   MAE     0.1980   Time 347.144127 ms
# Sample size     32   iteration number   2751   MSE     0.1049   MAE     0.2313   Time 404.097080 ms
# Sample size     32   iteration number   2761   MSE     0.0912   MAE     0.2469   Time 755.265236 ms
# Sample size     32   iteration number   2771   MSE     0.0755   MAE     0.2036   Time 281.305552 ms
# Sample size     32   iteration number   2781   MSE     0.1403   MAE     0.2623   Time 308.622837 ms
# Sample size     32   iteration number   2791   MSE     0.0836   MAE     0.2047   Time 493.798494 ms
# Sample size     32   iteration number   2801   MSE     0.0772   MAE     0.2100   Time 927.314758 ms
# Sample size     32   iteration number   2811   MSE     0.1349   MAE     0.2539   Time 400.833368 ms
# Sample size     32   iteration number   2821   MSE     0.0964   MAE     0.2360   Time 492.482424 ms
# Sample size     32   iteration number   2831   MSE     0.1254   MAE     0.2378   Time 446.591377 ms
# Sample size     32   iteration number   2841   MSE     0.0640   MAE     0.1786   Time 475.325108 ms
# Sample size     32   iteration number   2851   MSE     0.1604   MAE     0.2895   Time 370.861053 ms
# Sample size     32   iteration number   2861   MSE     0.1260   MAE     0.2427   Time 212.932825 ms
# Sample size     32   iteration number   2871   MSE     0.0865   MAE     0.2259   Time 897.716284 ms
# Sample size     32   iteration number   2881   MSE     0.0794   MAE     0.2162   Time 371.552706 ms
# Sample size     32   iteration number   2891   MSE     0.2688   MAE     0.3142   Time 692.399025 ms
# Sample size     32   iteration number   2901   MSE     0.0703   MAE     0.1994   Time 383.947372 ms
# Sample size     32   iteration number   2911   MSE     0.0564   MAE     0.1789   Time 611.183405 ms
# Sample size     32   iteration number   2921   MSE     0.1135   MAE     0.2254   Time 319.506884 ms
# Sample size     32   iteration number   2931   MSE     0.1257   MAE     0.2355   Time 293.561220 ms
# Sample size     32   iteration number   2941   MSE     0.1223   MAE     0.2343   Time 439.354181 ms
# Sample size     32   iteration number   2951   MSE     0.1515   MAE     0.2573   Time 1104.607821 ms
# Sample size     32   iteration number   2961   MSE     0.1216   MAE     0.2179   Time 239.784002 ms
# Sample size     32   iteration number   2971   MSE     0.0825   MAE     0.2145   Time 201.171398 ms
# Sample size     32   iteration number   2981   MSE     0.0933   MAE     0.2125   Time 240.458488 ms
# Sample size     32   iteration number   2991   MSE     0.1040   MAE     0.2368   Time 416.395664 ms
# Sample size     32   iteration number   3001   MSE     0.2185   MAE     0.3347   Time 275.885582 ms
# Sample size    128   iteration number      1   MSE     0.0963   MAE     0.2015   Time 4420.169115 ms
# Sample size    128   iteration number     11   MSE     0.1139   MAE     0.2253   Time 536.583662 ms
# Sample size    128   iteration number     21   MSE     0.1353   MAE     0.2546   Time 881.741762 ms
# Sample size    128   iteration number     31   MSE     0.0998   MAE     0.2194   Time 903.287411 ms
# Sample size    128   iteration number     41   MSE     0.1292   MAE     0.2308   Time 744.708538 ms
# Sample size    128   iteration number     51   MSE     0.1070   MAE     0.1976   Time 676.757336 ms
# Sample size    128   iteration number     61   MSE     0.1373   MAE     0.2554   Time 475.572586 ms
# Sample size    128   iteration number     71   MSE     0.0919   MAE     0.1945   Time 618.009567 ms
# Sample size    128   iteration number     81   MSE     0.1301   MAE     0.2499   Time 643.153191 ms
# Sample size    128   iteration number     91   MSE     0.0967   MAE     0.2078   Time 567.382812 ms
# Sample size    128   iteration number    101   MSE     0.0826   MAE     0.1985   Time 561.058998 ms
# Sample size    128   iteration number    111   MSE     0.1431   MAE     0.2545   Time 661.646128 ms
# Sample size    128   iteration number    121   MSE     0.1008   MAE     0.2329   Time 473.368168 ms
# Sample size    128   iteration number    131   MSE     0.0975   MAE     0.2220   Time 742.264509 ms
# Sample size    128   iteration number    141   MSE     0.0774   MAE     0.1992   Time 753.714323 ms
# Sample size    128   iteration number    151   MSE     0.1099   MAE     0.2193   Time 717.822552 ms
# Sample size    128   iteration number    161   MSE     0.0889   MAE     0.1989   Time 525.142670 ms
# Sample size    128   iteration number    171   MSE     0.1108   MAE     0.2089   Time 868.403673 ms
# Sample size    128   iteration number    181   MSE     0.1210   MAE     0.2287   Time 584.956646 ms
# Sample size    128   iteration number    191   MSE     0.0850   MAE     0.2011   Time 579.414129 ms
# Sample size    128   iteration number    201   MSE     0.1128   MAE     0.2274   Time 1202.335835 ms
# Sample size    128   iteration number    211   MSE     0.1296   MAE     0.2454   Time 551.656961 ms
# Sample size    128   iteration number    221   MSE     0.1153   MAE     0.2206   Time 1099.041462 ms
# Sample size    128   iteration number    231   MSE     0.1020   MAE     0.2075   Time 640.266895 ms
# Sample size    128   iteration number    241   MSE     0.0982   MAE     0.2174   Time 777.854681 ms
# Sample size    128   iteration number    251   MSE     0.0851   MAE     0.2017   Time 809.339046 ms
# Sample size    128   iteration number    261   MSE     0.1117   MAE     0.2232   Time 1102.072239 ms
# Sample size    128   iteration number    271   MSE     0.1122   MAE     0.2251   Time 818.305016 ms
# Sample size    128   iteration number    281   MSE     0.0971   MAE     0.2136   Time 1058.033705 ms
# Sample size    128   iteration number    291   MSE     0.1478   MAE     0.2887   Time 700.367689 ms
# Sample size    128   iteration number    301   MSE     0.0858   MAE     0.2022   Time 840.548754 ms
# Sample size    128   iteration number    311   MSE     0.0790   MAE     0.1969   Time 536.362886 ms
# Sample size    128   iteration number    321   MSE     0.1074   MAE     0.2108   Time 575.750113 ms
# Sample size    128   iteration number    331   MSE     0.1065   MAE     0.2185   Time 676.896811 ms
# Sample size    128   iteration number    341   MSE     0.1168   MAE     0.2323   Time 795.442104 ms
# Sample size    128   iteration number    351   MSE     0.0858   MAE     0.1877   Time 626.804829 ms
# Sample size    128   iteration number    361   MSE     0.1226   MAE     0.2456   Time 751.425982 ms
# Sample size    128   iteration number    371   MSE     0.1257   MAE     0.2479   Time 682.046890 ms
# Sample size    128   iteration number    381   MSE     0.0852   MAE     0.1994   Time 709.682941 ms
# Sample size    128   iteration number    391   MSE     0.0949   MAE     0.2171   Time 423.575640 ms
# Sample size    128   iteration number    401   MSE     0.1204   MAE     0.2266   Time 512.404442 ms
# Sample size    128   iteration number    411   MSE     0.0922   MAE     0.2098   Time 506.207943 ms
# Sample size    128   iteration number    421   MSE     0.1068   MAE     0.2203   Time 806.026697 ms
# Sample size    128   iteration number    431   MSE     0.1420   MAE     0.2579   Time 1109.081984 ms
# Sample size    128   iteration number    441   MSE     0.1176   MAE     0.2304   Time 880.230427 ms
# Sample size    128   iteration number    451   MSE     0.1137   MAE     0.2298   Time 794.640303 ms
# Sample size    128   iteration number    461   MSE     0.1228   MAE     0.2447   Time 1056.888103 ms
# Sample size    128   iteration number    471   MSE     0.0990   MAE     0.2196   Time 604.863167 ms
# Sample size    128   iteration number    481   MSE     0.1011   MAE     0.2208   Time 767.426014 ms
# Sample size    128   iteration number    491   MSE     0.1397   MAE     0.2299   Time 558.984518 ms
# Sample size    128   iteration number    501   MSE     0.1018   MAE     0.2095   Time 946.056128 ms
# Sample size    128   iteration number    511   MSE     0.1022   MAE     0.2278   Time 894.785643 ms
# Sample size    128   iteration number    521   MSE     0.1205   MAE     0.2277   Time 616.874218 ms
# Sample size    128   iteration number    531   MSE     0.0864   MAE     0.2012   Time 671.350718 ms
# Sample size    128   iteration number    541   MSE     0.0929   MAE     0.2088   Time 478.423595 ms
# Sample size    128   iteration number    551   MSE     0.1153   MAE     0.2282   Time 1054.143906 ms
# Sample size    128   iteration number    561   MSE     0.0932   MAE     0.2108   Time 907.348156 ms
# Sample size    128   iteration number    571   MSE     0.1233   MAE     0.2293   Time 743.352413 ms
# Sample size    128   iteration number    581   MSE     0.1127   MAE     0.2205   Time 389.209747 ms
# Sample size    128   iteration number    591   MSE     0.1419   MAE     0.2480   Time 581.244707 ms
# Sample size    128   iteration number    601   MSE     0.1033   MAE     0.2079   Time 660.997629 ms
# Sample size    128   iteration number    611   MSE     0.1127   MAE     0.2369   Time 709.392309 ms
# Sample size    128   iteration number    621   MSE     0.0786   MAE     0.2041   Time 693.171024 ms
# Sample size    128   iteration number    631   MSE     0.1032   MAE     0.2137   Time 573.232651 ms
# Sample size    128   iteration number    641   MSE     0.0995   MAE     0.2130   Time 853.639364 ms
# Sample size    128   iteration number    651   MSE     0.1001   MAE     0.2272   Time 605.842113 ms
# Sample size    128   iteration number    661   MSE     0.0874   MAE     0.2041   Time 994.728565 ms
# Sample size    128   iteration number    671   MSE     0.1090   MAE     0.2217   Time 797.596455 ms
# Sample size    128   iteration number    681   MSE     0.1087   MAE     0.2162   Time 813.530684 ms
# Sample size    128   iteration number    691   MSE     0.0940   MAE     0.2053   Time 1074.131727 ms
# Sample size    128   iteration number    701   MSE     0.0839   MAE     0.1933   Time 403.966904 ms
# Sample size    128   iteration number    711   MSE     0.1416   MAE     0.2609   Time 730.506182 ms
# Sample size    128   iteration number    721   MSE     0.0908   MAE     0.2087   Time 344.140053 ms
# Sample size    128   iteration number    731   MSE     0.0853   MAE     0.2104   Time 702.028275 ms
# Sample size    128   iteration number    741   MSE     0.1000   MAE     0.2073   Time 498.431444 ms
# Sample size    128   iteration number    751   MSE     0.1103   MAE     0.2238   Time 616.691351 ms
# Sample size    128   iteration number    761   MSE     0.0977   MAE     0.2143   Time 791.414261 ms
# Sample size    128   iteration number    771   MSE     0.1025   MAE     0.2206   Time 708.131075 ms
# Sample size    128   iteration number    781   MSE     0.1112   MAE     0.2388   Time 1057.433367 ms
# Sample size    128   iteration number    791   MSE     0.1242   MAE     0.2487   Time 703.148603 ms
# Sample size    128   iteration number    801   MSE     0.0980   MAE     0.2070   Time 787.599802 ms
# Sample size    128   iteration number    811   MSE     0.1217   MAE     0.2143   Time 1040.200472 ms
# Sample size    128   iteration number    821   MSE     0.1364   MAE     0.2429   Time 682.170630 ms
# Sample size    128   iteration number    831   MSE     0.0944   MAE     0.2147   Time 1003.837109 ms
# Sample size    128   iteration number    841   MSE     0.1084   MAE     0.2216   Time 810.775757 ms
# Sample size    128   iteration number    851   MSE     0.1228   MAE     0.2424   Time 624.969244 ms
# Sample size    128   iteration number    861   MSE     0.0859   MAE     0.1898   Time 552.525759 ms
# Sample size    128   iteration number    871   MSE     0.0807   MAE     0.1958   Time 941.603661 ms
# Sample size    128   iteration number    881   MSE     0.1046   MAE     0.2230   Time 533.624649 ms
# Sample size    128   iteration number    891   MSE     0.0950   MAE     0.2108   Time 679.959297 ms
# Sample size    128   iteration number    901   MSE     0.0777   MAE     0.1981   Time 511.667490 ms
# Sample size    128   iteration number    911   MSE     0.1239   MAE     0.2338   Time 927.190542 ms
# Sample size    128   iteration number    921   MSE     0.1272   MAE     0.2369   Time 797.868013 ms
# Sample size    128   iteration number    931   MSE     0.1106   MAE     0.2216   Time 502.233505 ms
# Sample size    128   iteration number    941   MSE     0.0861   MAE     0.1924   Time 649.667025 ms
# Sample size    128   iteration number    951   MSE     0.1298   MAE     0.2270   Time 915.572166 ms
# Sample size    128   iteration number    961   MSE     0.0772   MAE     0.1804   Time 693.978548 ms
# Sample size    128   iteration number    971   MSE     0.1749   MAE     0.2739   Time 846.198082 ms
# Sample size    128   iteration number    981   MSE     0.1283   MAE     0.2443   Time 633.882284 ms
# Sample size    128   iteration number    991   MSE     0.1520   MAE     0.2392   Time 520.503521 ms
# Sample size    128   iteration number   1001   MSE     0.1250   MAE     0.2343   Time 488.114119 ms
# Sample size    128   iteration number   1011   MSE     0.1032   MAE     0.2123   Time 635.503769 ms
# Sample size    128   iteration number   1021   MSE     0.1074   MAE     0.2170   Time 709.653139 ms
# Sample size    128   iteration number   1031   MSE     0.1482   MAE     0.2373   Time 1066.752672 ms
# Sample size    128   iteration number   1041   MSE     0.1261   MAE     0.2281   Time 844.464540 ms
# Sample size    128   iteration number   1051   MSE     0.0750   MAE     0.1980   Time 466.944218 ms
# Sample size    128   iteration number   1061   MSE     0.1129   MAE     0.2387   Time 629.132271 ms
# Sample size    128   iteration number   1071   MSE     0.0988   MAE     0.2005   Time 710.079908 ms
# Sample size    128   iteration number   1081   MSE     0.0647   MAE     0.1849   Time 712.066889 ms
# Sample size    128   iteration number   1091   MSE     0.1099   MAE     0.2223   Time 482.974291 ms
# Sample size    128   iteration number   1101   MSE     0.1166   MAE     0.2331   Time 912.525177 ms
# Sample size    128   iteration number   1111   MSE     0.1218   MAE     0.2304   Time 657.905579 ms
# Sample size    128   iteration number   1121   MSE     0.1320   MAE     0.2326   Time 731.396675 ms
# Sample size    128   iteration number   1131   MSE     0.1066   MAE     0.2107   Time 580.254793 ms
# Sample size    128   iteration number   1141   MSE     0.1038   MAE     0.2196   Time 597.858906 ms
# Sample size    128   iteration number   1151   MSE     0.0922   MAE     0.1991   Time 716.660261 ms
# Sample size    128   iteration number   1161   MSE     0.1164   MAE     0.2197   Time 667.513371 ms
# Sample size    128   iteration number   1171   MSE     0.1239   MAE     0.2450   Time 686.798334 ms
# Sample size    128   iteration number   1181   MSE     0.0940   MAE     0.2108   Time 616.973877 ms
# Sample size    128   iteration number   1191   MSE     0.0984   MAE     0.2148   Time 729.683399 ms
# Sample size    128   iteration number   1201   MSE     0.1067   MAE     0.2212   Time 864.233255 ms
# Sample size    128   iteration number   1211   MSE     0.1187   MAE     0.2321   Time 1091.987371 ms
# Sample size    128   iteration number   1221   MSE     0.0818   MAE     0.2062   Time 605.819702 ms
# Sample size    128   iteration number   1231   MSE     0.0772   MAE     0.1722   Time 983.296871 ms
# Sample size    128   iteration number   1241   MSE     0.1126   MAE     0.2243   Time 671.744347 ms
# Sample size    128   iteration number   1251   MSE     0.0613   MAE     0.1720   Time 880.568266 ms
# Sample size    128   iteration number   1261   MSE     0.1184   MAE     0.2519   Time 912.505388 ms
# Sample size    128   iteration number   1271   MSE     0.1452   MAE     0.2602   Time 788.708925 ms
# Sample size    128   iteration number   1281   MSE     0.0845   MAE     0.1926   Time 517.180443 ms
# Sample size    128   iteration number   1291   MSE     0.1307   MAE     0.2354   Time 521.590471 ms
# Sample size    128   iteration number   1301   MSE     0.1105   MAE     0.2244   Time 980.944157 ms
# Sample size    128   iteration number   1311   MSE     0.1229   MAE     0.2556   Time 627.801895 ms
# Sample size    128   iteration number   1321   MSE     0.1067   MAE     0.2346   Time 812.820435 ms
# Sample size    128   iteration number   1331   MSE     0.1019   MAE     0.2237   Time 840.713263 ms
# Sample size    128   iteration number   1341   MSE     0.1025   MAE     0.2119   Time 727.523327 ms
# Sample size    128   iteration number   1351   MSE     0.1073   MAE     0.2145   Time 658.601999 ms
# Sample size    128   iteration number   1361   MSE     0.1323   MAE     0.2343   Time 775.730610 ms
# Sample size    128   iteration number   1371   MSE     0.1042   MAE     0.2273   Time 645.706654 ms
# Sample size    128   iteration number   1381   MSE     0.1062   MAE     0.2369   Time 842.731237 ms
# Sample size    128   iteration number   1391   MSE     0.1092   MAE     0.2280   Time 450.371981 ms
# Sample size    128   iteration number   1401   MSE     0.0979   MAE     0.2080   Time 406.238794 ms
# Sample size    128   iteration number   1411   MSE     0.1062   MAE     0.2198   Time 1231.232166 ms
# Sample size    128   iteration number   1421   MSE     0.1052   MAE     0.2304   Time 849.566698 ms
# Sample size    128   iteration number   1431   MSE     0.0878   MAE     0.2104   Time 767.123461 ms
# Sample size    128   iteration number   1441   MSE     0.0948   MAE     0.2125   Time 521.188021 ms
# Sample size    128   iteration number   1451   MSE     0.1183   MAE     0.2224   Time 453.723192 ms
# Sample size    128   iteration number   1461   MSE     0.1000   MAE     0.2135   Time 869.973660 ms
# Sample size    128   iteration number   1471   MSE     0.1350   MAE     0.2454   Time 629.329443 ms
# Sample size    128   iteration number   1481   MSE     0.1102   MAE     0.2306   Time 689.782858 ms
# Sample size    128   iteration number   1491   MSE     0.1001   MAE     0.2292   Time 431.649208 ms
# Sample size    128   iteration number   1501   MSE     0.1006   MAE     0.2162   Time 694.509268 ms
# Sample size    128   iteration number   1511   MSE     0.0819   MAE     0.1862   Time 1126.427412 ms
# Sample size    128   iteration number   1521   MSE     0.1411   MAE     0.2384   Time 596.959114 ms
# Sample size    128   iteration number   1531   MSE     0.1091   MAE     0.2232   Time 965.723038 ms
# Sample size    128   iteration number   1541   MSE     0.1507   MAE     0.2521   Time 1057.543278 ms
# Sample size    128   iteration number   1551   MSE     0.1532   MAE     0.2644   Time 860.389709 ms
# Sample size    128   iteration number   1561   MSE     0.1318   MAE     0.2448   Time 708.558321 ms
# Sample size    128   iteration number   1571   MSE     0.1327   MAE     0.2417   Time 595.000744 ms
# Sample size    128   iteration number   1581   MSE     0.1143   MAE     0.2225   Time 661.450148 ms
# Sample size    128   iteration number   1591   MSE     0.1389   MAE     0.2384   Time 616.559744 ms
# Sample size    128   iteration number   1601   MSE     0.0935   MAE     0.1979   Time 743.985891 ms
# Sample size    128   iteration number   1611   MSE     0.1283   MAE     0.2353   Time 987.906933 ms
# Sample size    128   iteration number   1621   MSE     0.0685   MAE     0.1838   Time 964.693069 ms
# Sample size    128   iteration number   1631   MSE     0.1078   MAE     0.2285   Time 891.508579 ms
# Sample size    128   iteration number   1641   MSE     0.1057   MAE     0.2185   Time 625.488520 ms
# Sample size    128   iteration number   1651   MSE     0.0963   MAE     0.2092   Time 804.249525 ms
# Sample size    128   iteration number   1661   MSE     0.1186   MAE     0.2389   Time 654.046297 ms
# Sample size    128   iteration number   1671   MSE     0.1422   MAE     0.2564   Time 689.605474 ms
# Sample size    128   iteration number   1681   MSE     0.0796   MAE     0.1909   Time 773.284197 ms
# Sample size    128   iteration number   1691   MSE     0.1237   MAE     0.2443   Time 521.375418 ms
# Sample size    128   iteration number   1701   MSE     0.1158   MAE     0.2227   Time 602.746964 ms
# Sample size    128   iteration number   1711   MSE     0.0978   MAE     0.1992   Time 463.272333 ms
# Sample size    128   iteration number   1721   MSE     0.1225   MAE     0.2292   Time 557.689428 ms
# Sample size    128   iteration number   1731   MSE     0.1654   MAE     0.2863   Time 860.655546 ms
# Sample size    128   iteration number   1741   MSE     0.0689   MAE     0.1893   Time 676.897049 ms
# Sample size    128   iteration number   1751   MSE     0.0941   MAE     0.2055   Time 649.287462 ms
# Sample size    128   iteration number   1761   MSE     0.0966   MAE     0.2172   Time 919.589281 ms
# Sample size    128   iteration number   1771   MSE     0.1264   MAE     0.2328   Time 767.315388 ms
# Sample size    128   iteration number   1781   MSE     0.0795   MAE     0.1827   Time 516.473055 ms
# Sample size    128   iteration number   1791   MSE     0.0768   MAE     0.1928   Time 842.642307 ms
# Sample size    128   iteration number   1801   MSE     0.0791   MAE     0.2113   Time 741.647482 ms
# Sample size    128   iteration number   1811   MSE     0.0766   MAE     0.2190   Time 401.737452 ms
# Sample size    128   iteration number   1821   MSE     0.1092   MAE     0.2474   Time 462.903500 ms
# Sample size    128   iteration number   1831   MSE     0.0904   MAE     0.2108   Time 422.473669 ms
# Sample size    128   iteration number   1841   MSE     0.1242   MAE     0.2503   Time 436.365366 ms
# Sample size    128   iteration number   1851   MSE     0.0797   MAE     0.1900   Time 790.503263 ms
# Sample size    128   iteration number   1861   MSE     0.1169   MAE     0.2258   Time 1132.923365 ms
# Sample size    128   iteration number   1871   MSE     0.1050   MAE     0.2283   Time 1037.603378 ms
# Sample size    128   iteration number   1881   MSE     0.1119   MAE     0.2228   Time 348.021984 ms
# Sample size    128   iteration number   1891   MSE     0.1121   MAE     0.2192   Time 648.119926 ms
# Sample size    128   iteration number   1901   MSE     0.1219   MAE     0.2405   Time 432.011843 ms
# Sample size    128   iteration number   1911   MSE     0.1031   MAE     0.2198   Time 699.476480 ms
# Sample size    128   iteration number   1921   MSE     0.1131   MAE     0.2412   Time 929.535627 ms
# Sample size    128   iteration number   1931   MSE     0.1099   MAE     0.2331   Time 930.982828 ms
# Sample size    128   iteration number   1941   MSE     0.1341   MAE     0.2419   Time 596.926928 ms
# Sample size    128   iteration number   1951   MSE     0.0644   MAE     0.1772   Time 490.640640 ms
# Sample size    128   iteration number   1961   MSE     0.0752   MAE     0.1905   Time 976.746082 ms
# Sample size    128   iteration number   1971   MSE     0.1242   MAE     0.2432   Time 677.192926 ms
# Sample size    128   iteration number   1981   MSE     0.1071   MAE     0.2383   Time 948.039055 ms
# Sample size    128   iteration number   1991   MSE     0.1161   MAE     0.2336   Time 723.921776 ms
# Sample size    128   iteration number   2001   MSE     0.1202   MAE     0.2456   Time 602.293730 ms
# Sample size    512   iteration number      1   MSE     0.1255   MAE     0.2499   Time 1105.001211 ms
# Sample size    512   iteration number     11   MSE     0.1189   MAE     0.2345   Time 994.764566 ms
# Sample size    512   iteration number     21   MSE     0.1356   MAE     0.2392   Time 934.560061 ms
# Sample size    512   iteration number     31   MSE     0.1057   MAE     0.2158   Time 1032.851219 ms
# Sample size    512   iteration number     41   MSE     0.0891   MAE     0.2063   Time 1210.998535 ms
# Sample size    512   iteration number     51   MSE     0.0995   MAE     0.2122   Time 897.329807 ms
# Sample size    512   iteration number     61   MSE     0.1330   MAE     0.2359   Time 829.013824 ms
# Sample size    512   iteration number     71   MSE     0.1102   MAE     0.2221   Time 1355.090857 ms
# Sample size    512   iteration number     81   MSE     0.0883   MAE     0.2021   Time 1046.287060 ms
# Sample size    512   iteration number     91   MSE     0.1143   MAE     0.2182   Time 1203.482151 ms
# Sample size    512   iteration number    101   MSE     0.1088   MAE     0.2129   Time 1395.626307 ms
# Sample size    512   iteration number    111   MSE     0.0958   MAE     0.2153   Time 1086.148500 ms
# Sample size    512   iteration number    121   MSE     0.1177   MAE     0.2292   Time 1104.588270 ms
# Sample size    512   iteration number    131   MSE     0.1131   MAE     0.2200   Time 1061.938286 ms
# Sample size    512   iteration number    141   MSE     0.0867   MAE     0.2005   Time 1588.379145 ms
# Sample size    512   iteration number    151   MSE     0.1089   MAE     0.2126   Time 1109.987736 ms
# Sample size    512   iteration number    161   MSE     0.1035   MAE     0.2080   Time 1109.010935 ms
# Sample size    512   iteration number    171   MSE     0.1152   MAE     0.2201   Time 1024.307013 ms
# Sample size    512   iteration number    181   MSE     0.0986   MAE     0.2139   Time 1193.866968 ms
# Sample size    512   iteration number    191   MSE     0.1234   MAE     0.2363   Time 1040.603399 ms
# Sample size    512   iteration number    201   MSE     0.1270   MAE     0.2344   Time 1065.093517 ms
# Sample size    512   iteration number    211   MSE     0.1273   MAE     0.2325   Time 1112.602711 ms
# Sample size    512   iteration number    221   MSE     0.1199   MAE     0.2301   Time 1075.379133 ms
# Sample size    512   iteration number    231   MSE     0.0997   MAE     0.2122   Time 731.670141 ms
# Sample size    512   iteration number    241   MSE     0.1080   MAE     0.2199   Time 1364.357948 ms
# Sample size    512   iteration number    251   MSE     0.0962   MAE     0.2086   Time 1404.989719 ms
# Sample size    512   iteration number    261   MSE     0.1169   MAE     0.2243   Time 1135.037184 ms
# Sample size    512   iteration number    271   MSE     0.0943   MAE     0.1983   Time 1095.765352 ms
# Sample size    512   iteration number    281   MSE     0.1174   MAE     0.2276   Time 1730.164289 ms
# Sample size    512   iteration number    291   MSE     0.0925   MAE     0.2058   Time 1160.589218 ms
# Sample size    512   iteration number    301   MSE     0.0950   MAE     0.2141   Time 1194.266319 ms
# Sample size    512   iteration number    311   MSE     0.1076   MAE     0.2137   Time 1128.149986 ms
# Sample size    512   iteration number    321   MSE     0.0962   MAE     0.2071   Time 1027.276039 ms
# Sample size    512   iteration number    331   MSE     0.0977   MAE     0.2078   Time 1153.556108 ms
# Sample size    512   iteration number    341   MSE     0.1071   MAE     0.2071   Time 1092.190742 ms
# Sample size    512   iteration number    351   MSE     0.0985   MAE     0.2018   Time 1195.823669 ms
# Sample size    512   iteration number    361   MSE     0.1042   MAE     0.2220   Time 1119.717360 ms
# Sample size    512   iteration number    371   MSE     0.1077   MAE     0.2125   Time 840.883493 ms
# Sample size    512   iteration number    381   MSE     0.1081   MAE     0.2164   Time 1254.231930 ms
# Sample size    512   iteration number    391   MSE     0.0994   MAE     0.2114   Time 1041.910410 ms
# Sample size    512   iteration number    401   MSE     0.1227   MAE     0.2209   Time 1113.731861 ms
# Sample size    512   iteration number    411   MSE     0.1318   MAE     0.2237   Time 1345.419168 ms
# Sample size    512   iteration number    421   MSE     0.1156   MAE     0.2293   Time 1059.935570 ms
# Sample size    512   iteration number    431   MSE     0.1113   MAE     0.2164   Time 1134.347677 ms
# Sample size    512   iteration number    441   MSE     0.1290   MAE     0.2284   Time 1067.309141 ms
# Sample size    512   iteration number    451   MSE     0.1258   MAE     0.2297   Time 1197.166681 ms
# Sample size    512   iteration number    461   MSE     0.1093   MAE     0.2241   Time 918.094397 ms
# Sample size    512   iteration number    471   MSE     0.0886   MAE     0.2093   Time 1175.855875 ms
# Sample size    512   iteration number    481   MSE     0.1083   MAE     0.2208   Time 1222.932577 ms
# Sample size    512   iteration number    491   MSE     0.1043   MAE     0.2203   Time 925.887346 ms
# Sample size    512   iteration number    501   MSE     0.1132   MAE     0.2177   Time 831.594229 ms
# Sample size    512   iteration number    511   MSE     0.1124   MAE     0.2218   Time 1173.193455 ms
# Sample size    512   iteration number    521   MSE     0.1155   MAE     0.2160   Time 1239.058971 ms
# Sample size    512   iteration number    531   MSE     0.1174   MAE     0.2325   Time 925.930977 ms
# Sample size    512   iteration number    541   MSE     0.0987   MAE     0.2082   Time 1183.489561 ms
# Sample size    512   iteration number    551   MSE     0.0991   MAE     0.2084   Time 942.718267 ms
# Sample size    512   iteration number    561   MSE     0.0906   MAE     0.1983   Time 987.618923 ms
# Sample size    512   iteration number    571   MSE     0.1026   MAE     0.2171   Time 1059.341431 ms
# Sample size    512   iteration number    581   MSE     0.0999   MAE     0.2080   Time 1007.785320 ms
# Sample size    512   iteration number    591   MSE     0.1052   MAE     0.2181   Time 1259.300709 ms
# Sample size    512   iteration number    601   MSE     0.0775   MAE     0.1835   Time 1077.678680 ms
# Sample size    512   iteration number    611   MSE     0.0883   MAE     0.1954   Time 1054.689884 ms
# Sample size    512   iteration number    621   MSE     0.0917   MAE     0.2114   Time 1101.500273 ms
# Sample size    512   iteration number    631   MSE     0.1061   MAE     0.2143   Time 1192.490339 ms
# Sample size    512   iteration number    641   MSE     0.0868   MAE     0.1980   Time 1098.508358 ms
# Sample size    512   iteration number    651   MSE     0.0971   MAE     0.2108   Time 1339.433908 ms
# Sample size    512   iteration number    661   MSE     0.0991   MAE     0.2061   Time 1209.676027 ms
# Sample size    512   iteration number    671   MSE     0.0852   MAE     0.1982   Time 868.115425 ms
# Sample size    512   iteration number    681   MSE     0.1113   MAE     0.2323   Time 877.183199 ms
# Sample size    512   iteration number    691   MSE     0.1270   MAE     0.2294   Time 842551.603317 ms
# Sample size    512   iteration number    701   MSE     0.1329   MAE     0.2370   Time 1060.691595 ms
# Sample size    512   iteration number    711   MSE     0.1006   MAE     0.2000   Time 1265.217543 ms
# Sample size    512   iteration number    721   MSE     0.0951   MAE     0.2075   Time 1045.062304 ms
# Sample size    512   iteration number    731   MSE     0.1086   MAE     0.2151   Time 1139.006853 ms
# Sample size    512   iteration number    741   MSE     0.1003   MAE     0.2057   Time 975.483894 ms
# Sample size    512   iteration number    751   MSE     0.1023   MAE     0.2159   Time 1011.797667 ms
# Sample size    512   iteration number    761   MSE     0.1002   MAE     0.2068   Time 1104.759455 ms
# Sample size    512   iteration number    771   MSE     0.1053   MAE     0.2274   Time 1232.746363 ms
# Sample size    512   iteration number    781   MSE     0.0972   MAE     0.2063   Time 928.837299 ms
# Sample size    512   iteration number    791   MSE     0.1007   MAE     0.2149   Time 782.485008 ms
# Sample size    512   iteration number    801   MSE     0.1167   MAE     0.2237   Time 759.032726 ms
# Sample size    512   iteration number    811   MSE     0.1222   MAE     0.2310   Time 1203.361034 ms
# Sample size    512   iteration number    821   MSE     0.0918   MAE     0.2059   Time 1234.240770 ms
# Sample size    512   iteration number    831   MSE     0.1103   MAE     0.2247   Time 1071.115971 ms
# Sample size    512   iteration number    841   MSE     0.1271   MAE     0.2338   Time 1056.283712 ms
# Sample size    512   iteration number    851   MSE     0.1232   MAE     0.2197   Time 1141.011715 ms
# Sample size    512   iteration number    861   MSE     0.1082   MAE     0.2148   Time 959.521294 ms
# Sample size    512   iteration number    871   MSE     0.1053   MAE     0.2172   Time 1344.326735 ms
# Sample size    512   iteration number    881   MSE     0.1019   MAE     0.2105   Time 1103.025675 ms
# Sample size    512   iteration number    891   MSE     0.0932   MAE     0.2006   Time 1304.858685 ms
# Sample size    512   iteration number    901   MSE     0.1128   MAE     0.2224   Time 678.159714 ms
# Sample size    512   iteration number    911   MSE     0.0969   MAE     0.2060   Time 465.920210 ms
# Sample size    512   iteration number    921   MSE     0.1046   MAE     0.2193   Time 530.540228 ms
# Sample size    512   iteration number    931   MSE     0.1237   MAE     0.2303   Time 593.374729 ms
# Sample size    512   iteration number    941   MSE     0.1087   MAE     0.2190   Time 635.608673 ms
# Sample size    512   iteration number    951   MSE     0.1074   MAE     0.2185   Time 1175.153494 ms
# Sample size    512   iteration number    961   MSE     0.1088   MAE     0.2137   Time 1219.053268 ms
# Sample size    512   iteration number    971   MSE     0.1167   MAE     0.2230   Time 1340.750217 ms
# Sample size    512   iteration number    981   MSE     0.1116   MAE     0.2138   Time 1401.360750 ms
# Sample size    512   iteration number    991   MSE     0.0980   MAE     0.2109   Time 1444.223404 ms
# Sample size    512   iteration number   1001   MSE     0.1285   MAE     0.2350   Time 1311.146259 ms
# CPU times: user 1h 40min 7s, sys: 2h 41min 37s, total: 4h 21min 45s
# Wall time: 1h 24min

# %% [markdown]
# ### 6. TEST MODEL

# %%
def predict(network, trajectory):
    """ Predict parameters of the force field from the trajectory using the deep learnign network.
    
    Inputs:
    network: deep learning network
    image: trajectroy [numpy array of real numbers]
    
    Output:
    predicted_targets: predicted parameters of the calibrated force field [1D numpy array containing outputs]
    """
    
    from numpy import reshape
    
    network_blocksize = network.get_layer(index=0).get_config()['batch_input_shape'][1:][1]
    predicted_targets = network.predict(reshape(trajectory, [1,round(trajectory.size/network_blocksize),network_blocksize]))   
        
    return predicted_targets


def test_performance(simulate_trajectory, network, rescale_targets, number_of_predictions_to_show=100):#, dt = 1e-1):

    import numpy as np

    
    network_blocksize = network.get_layer(index=0).get_config()['batch_input_shape'][1:][1]


    predictions_scaled = []
    predictions_physical = []

    batch_size = number_of_predictions_to_show
    trajectory, trajectory_real, targets, targets_real = simulate_trajectory(batch_size)
    targets_physical = list(targets_real)#targets.values)
    targets_scaled = list(targets)#.scaled_values)
    #trajectory = trajectory.scaled_values
    trajectory_dimensions = [number_of_predictions_to_show, round(trajectory.size/network_blocksize/number_of_predictions_to_show) , network_blocksize]
    trajectories = np.array(trajectory).reshape(trajectory_dimensions)
       

    for i in range(number_of_predictions_to_show):
        predictions = predict(network, trajectories[i])


        predictions_scaled.append(predictions[0])
        predictions_physical.append(rescale_targets(*predictions[0]))

    number_of_outputs = network.get_layer(index=-1).get_config()['units']    

    targets_physical = np.array(targets_physical).transpose()
    targets_scaled = np.array(targets_scaled).transpose()
    predictions_scaled = np.array(predictions_scaled).transpose()
    predictions_physical = np.array(predictions_physical).transpose()

    # Do not show results at the edges of the training range 

    if number_of_outputs>1:

        ind = np.isfinite(targets_scaled[0])
        for target_number in range(number_of_outputs):
            target_max = .9 * np.max(targets_scaled[target_number]) + .1 * np.min(targets_scaled[target_number])
            target_min = .1 * np.max(targets_scaled[target_number]) + .9 * np.min(targets_scaled[target_number])
            ind = np.logical_and(ind, targets_scaled[target_number] < target_max)
            ind = np.logical_and(ind, targets_scaled[target_number] > target_min)
    else:
        target_max = .9 * np.max(targets_scaled) + .1 * np.min(targets_scaled)
        target_min = .1 * np.max(targets_scaled) + .9 * np.min(targets_scaled)
        ind = np.logical_and(targets_scaled < target_max, targets_scaled > target_min)

    return targets_scaled, targets_physical, predictions_scaled, predictions_physical, ind


def plot_test_performance(targets_scaled, targets_physical, predictions_scaled, predictions_physical, ind, network):
    
    import matplotlib.pyplot as plt
    import numpy as np
    #from . import predict

    number_of_outputs = network.get_layer(index=-1).get_config()['units']    
    
    if number_of_outputs>1:

        for target_number in range(number_of_outputs):
            plt.figure(figsize=(20, 10))

            plt.subplot(121)
            plt.plot(targets_scaled[target_number],
                     predictions_scaled[target_number],
                     '.')
            #plt.xlabel(targets.scalings[target_number], fontsize=18)
            #plt.ylabel('Predicted ' + targets.scalings[target_number], fontsize=18)
            plt.axis('square')
            plt.title('Prediction performance in scaled units', fontsize=18)

            plt.subplot(122)
            plt.plot(targets_physical[target_number],
                     predictions_physical[target_number],
                    '.')
            #plt.xlabel(targets.names[target_number], fontsize=18)
            #plt.ylabel('Predicted ' + targets.names[target_number], fontsize=18)
            plt.axis('square')
            plt.title('Prediction performance in real units', fontsize=18)


    else: 
        plt.figure(figsize=(20, 10))

        plt.subplot(121)
        plt.plot(targets_scaled[ind],
                 predictions_scaled.transpose()[ind],
                 '.')
        #plt.xlabel(targets.scalings[0], fontsize=18)
        #plt.ylabel('Predicted ' + targets.scalings[0], fontsize=18)
        plt.axis('square')
        plt.title('Prediction performance in scaled units', fontsize=18)

        plt.subplot(122)
        plt.plot(targets_physical[ind],
                 predictions_physical.transpose()[ind],
                '.')
        #plt.xlabel(targets.names[0], fontsize=18)
        #plt.ylabel('Predicted ' + targets.names[0], fontsize=18)
        plt.axis('square')
        plt.title('Prediction performance in real units', fontsize=18)

# %%
# %%time

number_of_predictions_to_show = 1000
prediction_test = test_performance(simulate_trajectory, network, rescale_targets, number_of_predictions_to_show)
# Out:
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 0s 90ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 167ms/step
# 1/1 [==============================] - 0s 58ms/step
# 1/1 [==============================] - 0s 95ms/step
# 1/1 [==============================] - 0s 101ms/step
# 1/1 [==============================] - 0s 100ms/step
# 1/1 [==============================] - 0s 99ms/step
# 1/1 [==============================] - 0s 105ms/step
# 1/1 [==============================] - 0s 115ms/step
# 1/1 [==============================] - 0s 98ms/step
# 1/1 [==============================] - 0s 100ms/step
# 1/1 [==============================] - 0s 91ms/step
# 1/1 [==============================] - 0s 84ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 98ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 184ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 74ms/step
# 1/1 [==============================] - 0s 112ms/step
# 1/1 [==============================] - 0s 126ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 85ms/step
# 1/1 [==============================] - 0s 90ms/step
# 1/1 [==============================] - 0s 83ms/step
# 1/1 [==============================] - 0s 113ms/step
# 1/1 [==============================] - 0s 148ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 130ms/step
# 1/1 [==============================] - 0s 119ms/step
# 1/1 [==============================] - 0s 105ms/step
# 1/1 [==============================] - 0s 125ms/step
# 1/1 [==============================] - 0s 123ms/step
# 1/1 [==============================] - 0s 91ms/step
# 1/1 [==============================] - 0s 98ms/step
# 1/1 [==============================] - 0s 111ms/step
# 1/1 [==============================] - 0s 108ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 99ms/step
# 1/1 [==============================] - 0s 105ms/step
# 1/1 [==============================] - 0s 107ms/step
# 1/1 [==============================] - 0s 138ms/step
# 1/1 [==============================] - 0s 109ms/step
# 1/1 [==============================] - 0s 116ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 124ms/step
# 1/1 [==============================] - 0s 144ms/step
# 1/1 [==============================] - 0s 73ms/step
# 1/1 [==============================] - 0s 86ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 119ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 122ms/step
# 1/1 [==============================] - 0s 100ms/step
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 54ms/step
# 1/1 [==============================] - 0s 80ms/step
# 1/1 [==============================] - 0s 86ms/step
# 1/1 [==============================] - 0s 81ms/step
# 1/1 [==============================] - 0s 140ms/step
# 1/1 [==============================] - 0s 136ms/step
# 1/1 [==============================] - 0s 124ms/step
# 1/1 [==============================] - 0s 58ms/step
# 1/1 [==============================] - 0s 73ms/step
# 1/1 [==============================] - 0s 86ms/step
# 1/1 [==============================] - 0s 122ms/step
# 1/1 [==============================] - 0s 71ms/step
# 1/1 [==============================] - 0s 126ms/step
# 1/1 [==============================] - 0s 109ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 161ms/step
# 1/1 [==============================] - 0s 95ms/step
# 1/1 [==============================] - 0s 58ms/step
# 1/1 [==============================] - 0s 83ms/step
# 1/1 [==============================] - 0s 81ms/step
# 1/1 [==============================] - 0s 104ms/step
# 1/1 [==============================] - 0s 103ms/step
# 1/1 [==============================] - 0s 71ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 121ms/step
# 1/1 [==============================] - 0s 96ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 114ms/step
# 1/1 [==============================] - 0s 97ms/step
# 1/1 [==============================] - 0s 165ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 112ms/step
# 1/1 [==============================] - 0s 104ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 119ms/step
# 1/1 [==============================] - 0s 126ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 90ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 101ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 95ms/step
# 1/1 [==============================] - 0s 107ms/step
# 1/1 [==============================] - 0s 115ms/step
# 1/1 [==============================] - 0s 148ms/step
# 1/1 [==============================] - 0s 162ms/step
# 1/1 [==============================] - 0s 86ms/step
# 1/1 [==============================] - 0s 121ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 103ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 225ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 178ms/step
# 1/1 [==============================] - 0s 122ms/step
# 1/1 [==============================] - 0s 112ms/step
# 1/1 [==============================] - 0s 87ms/step
# 1/1 [==============================] - 0s 87ms/step
# 1/1 [==============================] - 0s 90ms/step
# 1/1 [==============================] - 0s 96ms/step
# 1/1 [==============================] - 0s 76ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 77ms/step
# 1/1 [==============================] - 0s 84ms/step
# 1/1 [==============================] - 0s 92ms/step
# 1/1 [==============================] - 0s 137ms/step
# 1/1 [==============================] - 0s 100ms/step
# 1/1 [==============================] - 0s 83ms/step
# 1/1 [==============================] - 0s 126ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 118ms/step
# 1/1 [==============================] - 0s 95ms/step
# 1/1 [==============================] - 0s 109ms/step
# 1/1 [==============================] - 0s 104ms/step
# 1/1 [==============================] - 0s 161ms/step
# 1/1 [==============================] - 0s 154ms/step
# 1/1 [==============================] - 0s 117ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 126ms/step
# 1/1 [==============================] - 0s 121ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 106ms/step
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 167ms/step
# 1/1 [==============================] - 0s 96ms/step
# 1/1 [==============================] - 0s 102ms/step
# 1/1 [==============================] - 0s 154ms/step
# 1/1 [==============================] - 0s 130ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 85ms/step
# 1/1 [==============================] - 0s 110ms/step
# 1/1 [==============================] - 0s 73ms/step
# 1/1 [==============================] - 0s 129ms/step
# 1/1 [==============================] - 0s 133ms/step
# 1/1 [==============================] - 0s 100ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 98ms/step
# 1/1 [==============================] - 0s 166ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 126ms/step
# 1/1 [==============================] - 0s 119ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 75ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 96ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 100ms/step
# 1/1 [==============================] - 0s 171ms/step
# 1/1 [==============================] - 0s 99ms/step
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 71ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 61ms/step
# 1/1 [==============================] - 0s 86ms/step
# 1/1 [==============================] - 0s 121ms/step
# 1/1 [==============================] - 0s 150ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 79ms/step
# 1/1 [==============================] - 0s 227ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 122ms/step
# 1/1 [==============================] - 0s 144ms/step
# 1/1 [==============================] - 0s 135ms/step
# 1/1 [==============================] - 0s 148ms/step
# 1/1 [==============================] - 0s 122ms/step
# 1/1 [==============================] - 0s 57ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 106ms/step
# 1/1 [==============================] - 0s 130ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 100ms/step
# 1/1 [==============================] - 0s 133ms/step
# 1/1 [==============================] - 0s 112ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 104ms/step
# 1/1 [==============================] - 0s 80ms/step
# 1/1 [==============================] - 0s 97ms/step
# 1/1 [==============================] - 0s 104ms/step
# 1/1 [==============================] - 0s 72ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 123ms/step
# 1/1 [==============================] - 0s 61ms/step
# 1/1 [==============================] - 0s 90ms/step
# 1/1 [==============================] - 0s 112ms/step
# 1/1 [==============================] - 0s 82ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 103ms/step
# 1/1 [==============================] - 0s 130ms/step
# 1/1 [==============================] - 0s 82ms/step
# 1/1 [==============================] - 0s 88ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 99ms/step
# 1/1 [==============================] - 0s 114ms/step
# 1/1 [==============================] - 0s 89ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 98ms/step
# 1/1 [==============================] - 0s 96ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 56ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 57ms/step
# 1/1 [==============================] - 0s 82ms/step
# 1/1 [==============================] - 0s 81ms/step
# 1/1 [==============================] - 0s 73ms/step
# 1/1 [==============================] - 0s 85ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 135ms/step
# 1/1 [==============================] - 0s 84ms/step
# 1/1 [==============================] - 0s 86ms/step
# 1/1 [==============================] - 0s 112ms/step
# 1/1 [==============================] - 0s 85ms/step
# 1/1 [==============================] - 0s 57ms/step
# 1/1 [==============================] - 0s 56ms/step
# 1/1 [==============================] - 0s 187ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 147ms/step
# 1/1 [==============================] - 0s 81ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 102ms/step
# 1/1 [==============================] - 0s 100ms/step
# 1/1 [==============================] - 0s 109ms/step
# 1/1 [==============================] - 0s 102ms/step
# 1/1 [==============================] - 0s 60ms/step
# 1/1 [==============================] - 0s 80ms/step
# 1/1 [==============================] - 0s 77ms/step
# 1/1 [==============================] - 0s 147ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 129ms/step
# 1/1 [==============================] - 0s 59ms/step
# 1/1 [==============================] - 0s 96ms/step
# 1/1 [==============================] - 0s 118ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 139ms/step
# 1/1 [==============================] - 0s 71ms/step
# 1/1 [==============================] - 0s 221ms/step
# 1/1 [==============================] - 0s 91ms/step
# 1/1 [==============================] - 0s 135ms/step
# 1/1 [==============================] - 0s 59ms/step
# 1/1 [==============================] - 0s 206ms/step
# 1/1 [==============================] - 0s 109ms/step
# 1/1 [==============================] - 0s 107ms/step
# 1/1 [==============================] - 0s 115ms/step
# 1/1 [==============================] - 0s 110ms/step
# 1/1 [==============================] - 0s 122ms/step
# 1/1 [==============================] - 0s 86ms/step
# 1/1 [==============================] - 0s 89ms/step
# 1/1 [==============================] - 0s 101ms/step
# 1/1 [==============================] - 0s 61ms/step
# 1/1 [==============================] - 0s 156ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 148ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 97ms/step
# 1/1 [==============================] - 0s 125ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 112ms/step
# 1/1 [==============================] - 0s 158ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 109ms/step
# 1/1 [==============================] - 0s 157ms/step
# 1/1 [==============================] - 0s 91ms/step
# 1/1 [==============================] - 0s 126ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 56ms/step
# 1/1 [==============================] - 0s 109ms/step
# 1/1 [==============================] - 0s 78ms/step
# 1/1 [==============================] - 0s 165ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 82ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 87ms/step
# 1/1 [==============================] - 0s 86ms/step
# 1/1 [==============================] - 0s 146ms/step
# 1/1 [==============================] - 0s 122ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 103ms/step
# 1/1 [==============================] - 0s 73ms/step
# 1/1 [==============================] - 0s 86ms/step
# 1/1 [==============================] - 0s 111ms/step
# 1/1 [==============================] - 0s 107ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 73ms/step
# 1/1 [==============================] - 0s 174ms/step
# 1/1 [==============================] - 0s 89ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 76ms/step
# 1/1 [==============================] - 0s 162ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 124ms/step
# 1/1 [==============================] - 0s 81ms/step
# 1/1 [==============================] - 0s 101ms/step
# 1/1 [==============================] - 0s 142ms/step
# 1/1 [==============================] - 0s 134ms/step
# 1/1 [==============================] - 0s 105ms/step
# 1/1 [==============================] - 0s 85ms/step
# 1/1 [==============================] - 0s 128ms/step
# 1/1 [==============================] - 0s 81ms/step
# 1/1 [==============================] - 0s 123ms/step
# 1/1 [==============================] - 0s 109ms/step
# 1/1 [==============================] - 0s 92ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 120ms/step
# 1/1 [==============================] - 0s 88ms/step
# 1/1 [==============================] - 0s 77ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 100ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 91ms/step
# 1/1 [==============================] - 0s 76ms/step
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 123ms/step
# 1/1 [==============================] - 0s 86ms/step
# 1/1 [==============================] - 0s 72ms/step
# 1/1 [==============================] - 0s 131ms/step
# 1/1 [==============================] - 0s 197ms/step
# 1/1 [==============================] - 0s 124ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 72ms/step
# 1/1 [==============================] - 0s 151ms/step
# 1/1 [==============================] - 0s 140ms/step
# 1/1 [==============================] - 0s 155ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 145ms/step
# 1/1 [==============================] - 0s 128ms/step
# 1/1 [==============================] - 0s 98ms/step
# 1/1 [==============================] - 0s 79ms/step
# 1/1 [==============================] - 0s 95ms/step
# 1/1 [==============================] - 0s 54ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 87ms/step
# 1/1 [==============================] - 0s 109ms/step
# 1/1 [==============================] - 0s 101ms/step
# 1/1 [==============================] - 0s 101ms/step
# 1/1 [==============================] - 0s 98ms/step
# 1/1 [==============================] - 0s 132ms/step
# 1/1 [==============================] - 0s 75ms/step
# 1/1 [==============================] - 0s 76ms/step
# 1/1 [==============================] - 0s 57ms/step
# 1/1 [==============================] - 0s 129ms/step
# 1/1 [==============================] - 0s 71ms/step
# 1/1 [==============================] - 0s 119ms/step
# 1/1 [==============================] - 0s 72ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 101ms/step
# 1/1 [==============================] - 0s 120ms/step
# 1/1 [==============================] - 0s 134ms/step
# 1/1 [==============================] - 0s 118ms/step
# 1/1 [==============================] - 0s 108ms/step
# 1/1 [==============================] - 0s 78ms/step
# 1/1 [==============================] - 0s 132ms/step
# 1/1 [==============================] - 0s 102ms/step
# 1/1 [==============================] - 0s 90ms/step
# 1/1 [==============================] - 0s 118ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 148ms/step
# 1/1 [==============================] - 0s 134ms/step
# 1/1 [==============================] - 0s 155ms/step
# 1/1 [==============================] - 0s 197ms/step
# 1/1 [==============================] - 0s 78ms/step
# 1/1 [==============================] - 0s 89ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 95ms/step
# 1/1 [==============================] - 0s 90ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 89ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 111ms/step
# 1/1 [==============================] - 0s 172ms/step
# 1/1 [==============================] - 0s 102ms/step
# 1/1 [==============================] - 0s 164ms/step
# 1/1 [==============================] - 0s 235ms/step
# 1/1 [==============================] - 0s 85ms/step
# 1/1 [==============================] - 0s 104ms/step
# 1/1 [==============================] - 0s 91ms/step
# 1/1 [==============================] - 0s 111ms/step
# 1/1 [==============================] - 0s 102ms/step
# 1/1 [==============================] - 0s 59ms/step
# 1/1 [==============================] - 0s 96ms/step
# 1/1 [==============================] - 0s 82ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 142ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 92ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 142ms/step
# 1/1 [==============================] - 0s 84ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 142ms/step
# 1/1 [==============================] - 0s 102ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 101ms/step
# 1/1 [==============================] - 0s 158ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 82ms/step
# 1/1 [==============================] - 0s 77ms/step
# 1/1 [==============================] - 0s 123ms/step
# 1/1 [==============================] - 0s 128ms/step
# 1/1 [==============================] - 0s 79ms/step
# 1/1 [==============================] - 0s 126ms/step
# 1/1 [==============================] - 0s 132ms/step
# 1/1 [==============================] - 0s 74ms/step
# 1/1 [==============================] - 0s 168ms/step
# 1/1 [==============================] - 0s 90ms/step
# 1/1 [==============================] - 0s 116ms/step
# 1/1 [==============================] - 0s 103ms/step
# 1/1 [==============================] - 0s 90ms/step
# 1/1 [==============================] - 0s 99ms/step
# 1/1 [==============================] - 0s 150ms/step
# 1/1 [==============================] - 0s 130ms/step
# 1/1 [==============================] - 0s 98ms/step
# 1/1 [==============================] - 0s 105ms/step
# 1/1 [==============================] - 0s 77ms/step
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 98ms/step
# 1/1 [==============================] - 0s 100ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 122ms/step
# 1/1 [==============================] - 0s 74ms/step
# 1/1 [==============================] - 0s 112ms/step
# 1/1 [==============================] - 0s 182ms/step
# 1/1 [==============================] - 0s 116ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 102ms/step
# 1/1 [==============================] - 0s 116ms/step
# 1/1 [==============================] - 0s 148ms/step
# 1/1 [==============================] - 0s 185ms/step
# 1/1 [==============================] - 0s 80ms/step
# 1/1 [==============================] - 0s 126ms/step
# 1/1 [==============================] - 0s 140ms/step
# 1/1 [==============================] - 0s 59ms/step
# 1/1 [==============================] - 0s 89ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 104ms/step
# 1/1 [==============================] - 0s 127ms/step
# 1/1 [==============================] - 0s 84ms/step
# 1/1 [==============================] - 0s 75ms/step
# 1/1 [==============================] - 0s 126ms/step
# 1/1 [==============================] - 0s 109ms/step
# 1/1 [==============================] - 0s 146ms/step
# 1/1 [==============================] - 0s 113ms/step
# 1/1 [==============================] - 0s 97ms/step
# 1/1 [==============================] - 0s 108ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 80ms/step
# 1/1 [==============================] - 0s 125ms/step
# 1/1 [==============================] - 0s 86ms/step
# 1/1 [==============================] - 0s 137ms/step
# 1/1 [==============================] - 0s 108ms/step
# 1/1 [==============================] - 0s 82ms/step
# 1/1 [==============================] - 0s 157ms/step
# 1/1 [==============================] - 0s 166ms/step
# 1/1 [==============================] - 0s 130ms/step
# 1/1 [==============================] - 0s 127ms/step
# 1/1 [==============================] - 0s 123ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 85ms/step
# 1/1 [==============================] - 0s 115ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 71ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 72ms/step
# 1/1 [==============================] - 0s 106ms/step
# 1/1 [==============================] - 0s 100ms/step
# 1/1 [==============================] - 0s 176ms/step
# 1/1 [==============================] - 0s 135ms/step
# 1/1 [==============================] - 0s 184ms/step
# 1/1 [==============================] - 0s 91ms/step
# 1/1 [==============================] - 0s 110ms/step
# 1/1 [==============================] - 0s 54ms/step
# 1/1 [==============================] - 0s 106ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 81ms/step
# 1/1 [==============================] - 0s 74ms/step
# 1/1 [==============================] - 0s 79ms/step
# 1/1 [==============================] - 0s 101ms/step
# 1/1 [==============================] - 0s 57ms/step
# 1/1 [==============================] - 0s 114ms/step
# 1/1 [==============================] - 0s 167ms/step
# 1/1 [==============================] - 0s 89ms/step
# 1/1 [==============================] - 0s 73ms/step
# 1/1 [==============================] - 0s 102ms/step
# 1/1 [==============================] - 0s 110ms/step
# 1/1 [==============================] - 0s 105ms/step
# 1/1 [==============================] - 0s 57ms/step
# 1/1 [==============================] - 0s 54ms/step
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 125ms/step
# 1/1 [==============================] - 0s 57ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 98ms/step
# 1/1 [==============================] - 0s 75ms/step
# 1/1 [==============================] - 0s 102ms/step
# 1/1 [==============================] - 0s 127ms/step
# 1/1 [==============================] - 0s 58ms/step
# 1/1 [==============================] - 0s 54ms/step
# 1/1 [==============================] - 0s 152ms/step
# 1/1 [==============================] - 0s 95ms/step
# 1/1 [==============================] - 0s 113ms/step
# 1/1 [==============================] - 0s 117ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 76ms/step
# 1/1 [==============================] - 0s 136ms/step
# 1/1 [==============================] - 0s 105ms/step
# 1/1 [==============================] - 0s 124ms/step
# 1/1 [==============================] - 0s 133ms/step
# 1/1 [==============================] - 0s 103ms/step
# 1/1 [==============================] - 0s 85ms/step
# 1/1 [==============================] - 0s 84ms/step
# 1/1 [==============================] - 0s 119ms/step
# 1/1 [==============================] - 0s 155ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 74ms/step
# 1/1 [==============================] - 0s 82ms/step
# 1/1 [==============================] - 0s 104ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 90ms/step
# 1/1 [==============================] - 0s 114ms/step
# 1/1 [==============================] - 0s 128ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 102ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 136ms/step
# 1/1 [==============================] - 0s 54ms/step
# 1/1 [==============================] - 0s 119ms/step
# 1/1 [==============================] - 0s 136ms/step
# 1/1 [==============================] - 0s 203ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 80ms/step
# 1/1 [==============================] - 0s 191ms/step
# 1/1 [==============================] - 0s 175ms/step
# 1/1 [==============================] - 0s 99ms/step
# 1/1 [==============================] - 0s 164ms/step
# 1/1 [==============================] - 0s 175ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 90ms/step
# 1/1 [==============================] - 0s 107ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 111ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 78ms/step
# 1/1 [==============================] - 0s 115ms/step
# 1/1 [==============================] - 0s 98ms/step
# 1/1 [==============================] - 0s 86ms/step
# 1/1 [==============================] - 0s 115ms/step
# 1/1 [==============================] - 0s 112ms/step
# 1/1 [==============================] - 0s 88ms/step
# 1/1 [==============================] - 0s 87ms/step
# 1/1 [==============================] - 0s 75ms/step
# 1/1 [==============================] - 0s 89ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 73ms/step
# 1/1 [==============================] - 0s 82ms/step
# 1/1 [==============================] - 0s 107ms/step
# 1/1 [==============================] - 0s 114ms/step
# 1/1 [==============================] - 0s 92ms/step
# 1/1 [==============================] - 0s 160ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 114ms/step
# 1/1 [==============================] - 0s 176ms/step
# 1/1 [==============================] - 0s 130ms/step
# 1/1 [==============================] - 0s 88ms/step
# 1/1 [==============================] - 0s 89ms/step
# 1/1 [==============================] - 0s 72ms/step
# 1/1 [==============================] - 0s 72ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 125ms/step
# 1/1 [==============================] - 0s 99ms/step
# 1/1 [==============================] - 0s 102ms/step
# 1/1 [==============================] - 0s 54ms/step
# 1/1 [==============================] - 0s 104ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 104ms/step
# 1/1 [==============================] - 0s 110ms/step
# 1/1 [==============================] - 0s 106ms/step
# 1/1 [==============================] - 0s 147ms/step
# 1/1 [==============================] - 0s 118ms/step
# 1/1 [==============================] - 0s 72ms/step
# 1/1 [==============================] - 0s 101ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 81ms/step
# 1/1 [==============================] - 0s 108ms/step
# 1/1 [==============================] - 0s 79ms/step
# 1/1 [==============================] - 0s 101ms/step
# 1/1 [==============================] - 0s 78ms/step
# 1/1 [==============================] - 0s 81ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 87ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 61ms/step
# 1/1 [==============================] - 0s 59ms/step
# 1/1 [==============================] - 0s 58ms/step
# 1/1 [==============================] - 0s 59ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 58ms/step
# 1/1 [==============================] - 0s 79ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 80ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 89ms/step
# 1/1 [==============================] - 0s 96ms/step
# 1/1 [==============================] - 0s 92ms/step
# 1/1 [==============================] - 0s 82ms/step
# 1/1 [==============================] - 0s 82ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 101ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 92ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 73ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 79ms/step
# 1/1 [==============================] - 0s 59ms/step
# 1/1 [==============================] - 0s 74ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 61ms/step
# 1/1 [==============================] - 0s 73ms/step
# 1/1 [==============================] - 0s 71ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 81ms/step
# 1/1 [==============================] - 0s 81ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 78ms/step
# 1/1 [==============================] - 0s 100ms/step
# 1/1 [==============================] - 0s 72ms/step
# 1/1 [==============================] - 0s 83ms/step
# 1/1 [==============================] - 0s 110ms/step
# 1/1 [==============================] - 0s 117ms/step
# 1/1 [==============================] - 0s 74ms/step
# 1/1 [==============================] - 0s 99ms/step
# 1/1 [==============================] - 0s 77ms/step
# 1/1 [==============================] - 0s 100ms/step
# 1/1 [==============================] - 0s 92ms/step
# 1/1 [==============================] - 0s 80ms/step
# 1/1 [==============================] - 0s 78ms/step
# 1/1 [==============================] - 0s 61ms/step
# 1/1 [==============================] - 0s 111ms/step
# 1/1 [==============================] - 0s 77ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 58ms/step
# 1/1 [==============================] - 0s 79ms/step
# 1/1 [==============================] - 0s 83ms/step
# 1/1 [==============================] - 0s 76ms/step
# 1/1 [==============================] - 0s 104ms/step
# 1/1 [==============================] - 0s 107ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 83ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 60ms/step
# 1/1 [==============================] - 0s 61ms/step
# 1/1 [==============================] - 0s 71ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 79ms/step
# 1/1 [==============================] - 0s 84ms/step
# 1/1 [==============================] - 0s 76ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 57ms/step
# 1/1 [==============================] - 0s 56ms/step
# 1/1 [==============================] - 0s 61ms/step
# 1/1 [==============================] - 0s 82ms/step
# 1/1 [==============================] - 0s 168ms/step
# 1/1 [==============================] - 0s 60ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 79ms/step
# 1/1 [==============================] - 0s 116ms/step
# 1/1 [==============================] - 0s 61ms/step
# 1/1 [==============================] - 0s 72ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 56ms/step
# 1/1 [==============================] - 0s 75ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 80ms/step
# 1/1 [==============================] - 0s 75ms/step
# 1/1 [==============================] - 0s 77ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 92ms/step
# 1/1 [==============================] - 0s 78ms/step
# 1/1 [==============================] - 0s 56ms/step
# 1/1 [==============================] - 0s 96ms/step
# 1/1 [==============================] - 0s 72ms/step
# 1/1 [==============================] - 0s 96ms/step
# 1/1 [==============================] - 0s 88ms/step
# 1/1 [==============================] - 0s 114ms/step
# 1/1 [==============================] - 0s 72ms/step
# 1/1 [==============================] - 0s 75ms/step
# 1/1 [==============================] - 0s 81ms/step
# 1/1 [==============================] - 0s 84ms/step
# 1/1 [==============================] - 0s 87ms/step
# 1/1 [==============================] - 0s 89ms/step
# 1/1 [==============================] - 0s 92ms/step
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 82ms/step
# 1/1 [==============================] - 0s 103ms/step
# 1/1 [==============================] - 0s 104ms/step
# 1/1 [==============================] - 0s 90ms/step
# 1/1 [==============================] - 0s 85ms/step
# 1/1 [==============================] - 0s 80ms/step
# 1/1 [==============================] - 0s 101ms/step
# 1/1 [==============================] - 0s 72ms/step
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 113ms/step
# 1/1 [==============================] - 0s 102ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 71ms/step
# 1/1 [==============================] - 0s 77ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 80ms/step
# 1/1 [==============================] - 0s 57ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 96ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 107ms/step
# 1/1 [==============================] - 0s 89ms/step
# 1/1 [==============================] - 0s 83ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 58ms/step
# 1/1 [==============================] - 0s 58ms/step
# 1/1 [==============================] - 0s 105ms/step
# 1/1 [==============================] - 0s 112ms/step
# 1/1 [==============================] - 0s 92ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 81ms/step
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 58ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 90ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 73ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 101ms/step
# 1/1 [==============================] - 0s 81ms/step
# 1/1 [==============================] - 0s 84ms/step
# 1/1 [==============================] - 0s 131ms/step
# 1/1 [==============================] - 0s 108ms/step
# 1/1 [==============================] - 0s 123ms/step
# 1/1 [==============================] - 0s 101ms/step
# 1/1 [==============================] - 0s 121ms/step
# 1/1 [==============================] - 0s 120ms/step
# 1/1 [==============================] - 0s 107ms/step
# 1/1 [==============================] - 0s 90ms/step
# 1/1 [==============================] - 0s 103ms/step
# 1/1 [==============================] - 0s 114ms/step
# 1/1 [==============================] - 0s 86ms/step
# 1/1 [==============================] - 0s 81ms/step
# 1/1 [==============================] - 0s 90ms/step
# 1/1 [==============================] - 0s 132ms/step
# 1/1 [==============================] - 0s 99ms/step
# 1/1 [==============================] - 0s 111ms/step
# 1/1 [==============================] - 0s 142ms/step
# 1/1 [==============================] - 0s 90ms/step
# 1/1 [==============================] - 0s 73ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 58ms/step
# 1/1 [==============================] - 0s 74ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 103ms/step
# 1/1 [==============================] - 0s 74ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 164ms/step
# 1/1 [==============================] - 0s 146ms/step
# 1/1 [==============================] - 0s 106ms/step
# 1/1 [==============================] - 0s 81ms/step
# 1/1 [==============================] - 0s 90ms/step
# 1/1 [==============================] - 0s 76ms/step
# 1/1 [==============================] - 0s 83ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 73ms/step
# 1/1 [==============================] - 0s 88ms/step
# 1/1 [==============================] - 0s 80ms/step
# 1/1 [==============================] - 0s 81ms/step
# 1/1 [==============================] - 0s 84ms/step
# 1/1 [==============================] - 0s 78ms/step
# 1/1 [==============================] - 0s 87ms/step
# 1/1 [==============================] - 0s 117ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 61ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 109ms/step
# 1/1 [==============================] - 0s 97ms/step
# 1/1 [==============================] - 0s 147ms/step
# 1/1 [==============================] - 0s 128ms/step
# 1/1 [==============================] - 0s 137ms/step
# 1/1 [==============================] - 0s 108ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 72ms/step
# 1/1 [==============================] - 0s 88ms/step
# 1/1 [==============================] - 0s 59ms/step
# 1/1 [==============================] - 0s 99ms/step
# 1/1 [==============================] - 0s 74ms/step
# 1/1 [==============================] - 0s 61ms/step
# 1/1 [==============================] - 0s 96ms/step
# 1/1 [==============================] - 0s 73ms/step
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 77ms/step
# 1/1 [==============================] - 0s 84ms/step
# 1/1 [==============================] - 0s 139ms/step
# 1/1 [==============================] - 0s 110ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 82ms/step
# 1/1 [==============================] - 0s 84ms/step
# 1/1 [==============================] - 0s 73ms/step
# 1/1 [==============================] - 0s 77ms/step
# 1/1 [==============================] - 0s 73ms/step
# 1/1 [==============================] - 0s 79ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 87ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 77ms/step
# 1/1 [==============================] - 0s 117ms/step
# 1/1 [==============================] - 0s 83ms/step
# 1/1 [==============================] - 0s 84ms/step
# 1/1 [==============================] - 0s 88ms/step
# 1/1 [==============================] - 0s 88ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 105ms/step
# 1/1 [==============================] - 0s 96ms/step
# 1/1 [==============================] - 0s 78ms/step
# 1/1 [==============================] - 0s 75ms/step
# 1/1 [==============================] - 0s 108ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 116ms/step
# 1/1 [==============================] - 0s 80ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 79ms/step
# 1/1 [==============================] - 0s 88ms/step
# 1/1 [==============================] - 0s 114ms/step
# 1/1 [==============================] - 0s 85ms/step
# 1/1 [==============================] - 0s 71ms/step
# 1/1 [==============================] - 0s 75ms/step
# 1/1 [==============================] - 0s 83ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 80ms/step
# 1/1 [==============================] - 0s 71ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 86ms/step
# 1/1 [==============================] - 0s 115ms/step
# 1/1 [==============================] - 0s 111ms/step
# 1/1 [==============================] - 0s 111ms/step
# 1/1 [==============================] - 0s 91ms/step
# 1/1 [==============================] - 0s 136ms/step
# 1/1 [==============================] - 0s 123ms/step
# 1/1 [==============================] - 0s 125ms/step
# 1/1 [==============================] - 0s 103ms/step
# 1/1 [==============================] - 0s 115ms/step
# 1/1 [==============================] - 0s 103ms/step
# 1/1 [==============================] - 0s 149ms/step
# 1/1 [==============================] - 0s 84ms/step
# 1/1 [==============================] - 0s 108ms/step
# 1/1 [==============================] - 0s 102ms/step
# 1/1 [==============================] - 0s 78ms/step
# 1/1 [==============================] - 0s 143ms/step
# 1/1 [==============================] - 0s 71ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 60ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 75ms/step
# 1/1 [==============================] - 0s 102ms/step
# 1/1 [==============================] - 0s 102ms/step
# 1/1 [==============================] - 0s 59ms/step
# 1/1 [==============================] - 0s 98ms/step
# 1/1 [==============================] - 0s 111ms/step
# 1/1 [==============================] - 0s 102ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 79ms/step
# 1/1 [==============================] - 0s 130ms/step
# 1/1 [==============================] - 0s 61ms/step
# 1/1 [==============================] - 0s 116ms/step
# 1/1 [==============================] - 0s 119ms/step
# 1/1 [==============================] - 0s 100ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 80ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 79ms/step
# 1/1 [==============================] - 0s 103ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 73ms/step
# 1/1 [==============================] - 0s 60ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 80ms/step
# 1/1 [==============================] - 0s 115ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 108ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 58ms/step
# 1/1 [==============================] - 0s 79ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 151ms/step
# 1/1 [==============================] - 0s 90ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 61ms/step
# 1/1 [==============================] - 0s 61ms/step
# CPU times: user 4min 50s, sys: 9min 55s, total: 14min 46s
# Wall time: 3min 14s

# %% [markdown]
# ### 7. Store Training and Predicted history

# %%
import pickle
def save_data(a, name):
    with open('{}.pkl'.format(name), 'wb') as f:
        pickle.dump(a, f) #, protocol=pickle.HIGHEST_PROTOCOL)
    # close file
    f.close()

#from datetime import datetime
#date = datetime.today().strftime('%Y-%m-%d')

## file name
name_train = 'training_history_{}_{}'.format(DNN, case_study)
name_pred = 'prediction_{}_test_{}'.format(DNN, case_study)

if normal_values == False:
    name_train = name_train + '_B'
    name_pred = name_pred + '_B'
if attention == True:
    name_train = name_train + '_attention'
    name_pred = name_pred + '_attention' 

# save train data
save_data(training_history, name_train)
# save test data
save_data(prediction_test, name_pred)

#load
#with open('filename.pickle', 'rb') as handle:
#    b = pickle.load(handle)

# %% [markdown]
# ### 8. Plot results

# %%
### Plot learning performance
number_of_timesteps_for_average = 100
train_DNN.plot_learning_performance(training_history, number_of_timesteps_for_average)

# %%
# average MSE and MAE
avg_mae= round(sum(training_history["MAE"])/len(training_history["MAE"]), 5)
avg_mse=round(sum(training_history["MSE"])/len(training_history["MSE"]), 5)
print('MSE: ',avg_mae)
print('MAE: ',avg_mae)
# Out:
# MSE:  0.24209
# MAE:  0.24209

# %%
### Plot test performance
plot_test_performance(prediction_test[0], prediction_test[1], prediction_test[2], prediction_test[3], prediction_test[4], network)

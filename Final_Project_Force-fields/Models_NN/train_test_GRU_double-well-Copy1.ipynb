# %% [markdown]
# ### GENERATE TRAJECTORIES USING **DOUBLE-WELL POTENTIAL**

# %% [markdown]
# using different physical parameters (Stefano's)

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
#from scipy.constants import Boltzmann as kB
from numpy.random import randn as gauss
from numpy.random import rand as uniform


kB = 1
### Physical parameters 
R = 1e-7                                # Radius of the Brownian particle [m]
eta = 0.001                             # Viscosity of the medium [kg m^-1 s^-1]
T = 1                                 # Temperature [K]
L0 = 5                               # Reference distance from middle to one minimum [m]
H0 = 4                             # Barrier height [Joule]
gamma0 = 1            # Reference friction coefficient [kg s^-1]

### Simulation parameters
N = 1000                   # Number of samples of the trajectory
Dt = 1                  # Timestep 
oversampling = 5           # Simulation oversampling
offset = 1000              # Number of equilibration timesteps
batch_size = 32            # Number of trajectories

### Define functions to scale and rescale inputs
scale_inputs = lambda x: x * 1e+6                    # Scales input trajectory to order 1
rescale_inputs = lambda scaled_x: scaled_x * 1e-6    # Rescales input trajectory to physical units

### Define function to scale and rescale targets
scale_targets = lambda L, H: [L/L0 -1, np.log(H / H0)]                        # Scales targets to order 1
rescale_targets = lambda scaled_L, scaled_H: [(1 + scaled_L)*L0*1e6, 
                                              np.exp(scaled_H) * H0/kB/300] # Inverse of targets_scaling

def simulate_trajectory(batch_size=batch_size, 
                        T=T,
                        H0=H0,
                        L0=L0,
                        gamma0=gamma0,
                        N=N, 
                        Dt=Dt, 
                        oversampling=oversampling, 
                        offset=offset):#, 
                        #scale_inputs=scale_inputs, 
                        #scale_targets=scale_targets):
    
    ### Randomize trajectory parameters
    L = L0 * (uniform(batch_size)+.5) 
    H = H0 * 10**(uniform(batch_size)*1.75 - .75)       # Generates random values for computing the stiffness
    gamma = gamma0 * (uniform(batch_size) * .1 + .95)   # Marginal randomization of friction coefficient to tolarate small changes

    ### Simulate
    dt = Dt / oversampling                 # time step of the simulation
    x = np.zeros((batch_size, N))          # initialization of the x array
    k0 = 4*H/L**2 
    k1 = 4*H/L**4
    D = kB * T / gamma                     # diffusion coefficient
    C1 = +k0 / gamma * dt
    C2 = -k1 / gamma * dt                  # drift coefficient of the Langevin equation
    C3 = np.sqrt(2 * D * dt)               # random walk coefficient of the Langevin equation
    X = x[:, 0]
    n = 0
    
    for t in range(offset):                      # Offset (for some prerun before running)
        X = X + C1 * X + C2 * X**3 + C3 * gauss(batch_size)
        #X = X - (2 * X**3) + (12 * X**2) - (18 * X) + 3 + (C3 * gauss(batch_size))
        
    for t in range(N * oversampling):            # Simulation                
        X = X + C1 * X + C2 * X**3 + C3 * gauss(batch_size)
        #X = X - (2 * X**3) + (12 * X**2) - (18 * X) + 3 + (C3 * gauss(batch_size))
        if t % oversampling == 0:                # We save every oversampling^th values 
            x[:, n] = X 
            n += 1

    inputs = scale_inputs(x)
    targets = np.swapaxes(scale_targets(*[L, H]),0,1)
    target_reals = np.swapaxes([L*1e6, H/kB/300],0,1)

    return inputs, targets, target_reals

# %% [markdown]
# ##### TRAIN THE DEEP NEURAL NETWORK

# %%
def train_deep_learning_network(
    network,
    simulate_trajectory,
    sample_sizes = (32, 128, 512),#(32, 128, 512, 2048),
    iteration_numbers = (3001, 2001, 1001),#(1001, 2001, 3001),#(3001, 2001, 1001, 101),
    verbose=.1):
    """Train a deep learning network.
    
    Input:
    network: deep learning network
    simulate_trajectory: trajectory generator function
    sample_sizes: sizes of the batches of trajectories used in the training [tuple of positive integers]
    iteration_numbers: numbers of batches used in the training [tuple of positive integers]
    verbose: frequency of the update messages [number between 0 and 1]
        
    Output:
    training_history: dictionary with training history
    """  
    
    import numpy as np
    from time import time
     
    training_history = {}
    training_history['Sample Size'] = []
    training_history['Iteration Number'] = []
    training_history['Iteration Time'] = []
    training_history['MSE'] = []
    training_history['MAE'] = []
    
    for sample_size, iteration_number in zip(sample_sizes, iteration_numbers):
        for iteration in range(iteration_number):
            
            # measure initial time for iteration
            initial_time = time()

            # generate trajectories and targets
            network_blocksize = network.get_layer(index=0).get_config()['batch_input_shape'][1:][1]                        
            number_of_outputs = network.get_layer(index=-1).get_config()['units']
            output_shape = (sample_size, number_of_outputs)
            targets = np.zeros(output_shape)
            
            
            batch_size = sample_size
            trajectory, target, target_real = simulate_trajectory(batch_size)
            #trajectory = trajectory.scaled_values
            trajectory_dimensions = [sample_size, round(trajectory.size/network_blocksize/sample_size), network_blocksize]
            trajectories = np.array(trajectory).reshape(trajectory_dimensions)
            targets = target#.scaled_values
                
                

            # training
            history = network.fit(trajectories,
                                targets,
                                epochs=1, 
                                batch_size=sample_size,
                                verbose=False)
                        
            # measure elapsed time during iteration
            iteration_time = time() - initial_time

            # record training history
            mse = history.history['mse'][0]
            mae = history.history['mae'][0]
                        
            training_history['Sample Size'].append(sample_size)
            training_history['Iteration Number'].append(iteration)
            training_history['Iteration Time'].append(iteration_time)
            training_history['MSE'].append(mse)
            training_history['MAE'].append(mae)

            if not(iteration%int(verbose**-1)):
                print('Sample size %6d   iteration number %6d   MSE %10.4f   MAE %10.4f   Time %10f ms' % (sample_size, iteration + 1, mse, mae, iteration_time * 1000))
                
    return training_history

# %% [markdown]
# ##### PLOT THE PERFORMANCE

# %%
def plot_learning_performance(training_history, number_of_timesteps_for_average = 100, figsize=(20,20)):
    """Plot the learning performance of the deep learning network.
    
    Input:
    training_history: dictionary with training history, typically obtained from train_deep_learning_network()
    number_of_timesteps_for_average: length of the average [positive integer number]
    figsize: figure size [list of two positive numbers]
        
    Output: none
    """    

    import matplotlib.pyplot as plt
    from numpy import convolve, ones
    
    plt.figure(figsize=figsize)

    plt.subplot(5, 1, 1)
    plt.semilogy(training_history['MSE'], 'k')
    plt.semilogy(convolve(training_history['MSE'], ones(number_of_timesteps_for_average) / number_of_timesteps_for_average, mode='valid'), 'r')
    plt.ylabel('MSE', fontsize=24)
    plt.xlabel('Epochs', fontsize=24)

    plt.subplot(5, 1, 2)
    plt.semilogy(training_history['MAE'], 'k')
    plt.semilogy(convolve(training_history['MAE'], ones(number_of_timesteps_for_average) / number_of_timesteps_for_average, mode='valid'), 'r')
    plt.ylabel('MAE', fontsize=24)
    plt.xlabel('Epochs', fontsize=24)
    plt.show()

# %% [markdown]
# ##### TEST THE DNN ON NEW SIMULATED TRAJECTORIES

# %%
def predict(network, trajectory):
    """ Predict parameters of the force field from the trajectory using the deep learnign network.
    
    Inputs:
    network: deep learning network
    image: trajectroy [numpy array of real numbers]
    
    Output:
    predicted_targets: predicted parameters of the calibrated force field [1D numpy array containing outputs]
    """
    
    from numpy import reshape
    
    network_blocksize = network.get_layer(index=0).get_config()['batch_input_shape'][1:][1]
    predicted_targets = network.predict(reshape(trajectory, [1,round(trajectory.size/network_blocksize),network_blocksize]))   
        
    return predicted_targets


def test_performance(simulate_trajectory, network, rescale_targets, number_of_predictions_to_show=100):#, dt = 1e-1):

    
    network_blocksize = network.get_layer(index=0).get_config()['batch_input_shape'][1:][1]


    predictions_scaled = []
    predictions_physical = []

    batch_size = number_of_predictions_to_show
    trajectory, targets, targets_real = simulate_trajectory(batch_size)
    targets_physical = list(targets_real)#targets.values)
    targets_scaled = list(targets)#.scaled_values)
    #trajectory = trajectory.scaled_values
    trajectory_dimensions = [number_of_predictions_to_show, round(trajectory.size/network_blocksize/number_of_predictions_to_show) , network_blocksize]
    trajectories = np.array(trajectory).reshape(trajectory_dimensions)
       

    for i in range(number_of_predictions_to_show):
        predictions = predict(network, trajectories[i])


        predictions_scaled.append(predictions[0])
        predictions_physical.append(rescale_targets(*predictions[0]))

    number_of_outputs = network.get_layer(index=-1).get_config()['units']    

    targets_physical = np.array(targets_physical).transpose()
    targets_scaled = np.array(targets_scaled).transpose()
    predictions_scaled = np.array(predictions_scaled).transpose()
    predictions_physical = np.array(predictions_physical).transpose()

    # Do not show results at the edges of the training range 

    if number_of_outputs>1:

        ind = np.isfinite(targets_scaled[0])
        for target_number in range(number_of_outputs):
            target_max = .9 * np.max(targets_scaled[target_number]) + .1 * np.min(targets_scaled[target_number])
            target_min = .1 * np.max(targets_scaled[target_number]) + .9 * np.min(targets_scaled[target_number])
            ind = np.logical_and(ind, targets_scaled[target_number] < target_max)
            ind = np.logical_and(ind, targets_scaled[target_number] > target_min)
    else:
        target_max = .9 * np.max(targets_scaled) + .1 * np.min(targets_scaled)
        target_min = .1 * np.max(targets_scaled) + .9 * np.min(targets_scaled)
        ind = np.logical_and(targets_scaled < target_max, targets_scaled > target_min)

    return targets_scaled, targets_physical, predictions_scaled, predictions_physical


def plot_test_performance(targets_scaled, targets_physical, predictions_scaled, predictions_physical, network):
    
    import matplotlib.pyplot as plt
    import numpy as np
    #from . import predict

    number_of_outputs = network.get_layer(index=-1).get_config()['units']    
    
    if number_of_outputs>1:

        for target_number in range(number_of_outputs):
            plt.figure(figsize=(20, 10))

            plt.subplot(121)
            plt.plot(targets_scaled[target_number],
                     predictions_scaled[target_number],
                     '.')
            #plt.xlabel(targets.scalings[target_number], fontsize=18)
            #plt.ylabel('Predicted ' + targets.scalings[target_number], fontsize=18)
            plt.axis('square')
            plt.title('Prediction performance in scaled units', fontsize=18)

            plt.subplot(122)
            plt.plot(targets_physical[target_number],
                     predictions_physical[target_number],
                    '.')
            #plt.xlabel(targets.names[target_number], fontsize=18)
            #plt.ylabel('Predicted ' + targets.names[target_number], fontsize=18)
            plt.axis('square')
            plt.title('Prediction performance in real units', fontsize=18)


    else: 
        plt.figure(figsize=(20, 10))

        plt.subplot(121)
        plt.plot(targets_scaled[ind],
                 predictions_scaled.transpose()[ind],
                 '.')
        #plt.xlabel(targets.scalings[0], fontsize=18)
        #plt.ylabel('Predicted ' + targets.scalings[0], fontsize=18)
        plt.axis('square')
        plt.title('Prediction performance in scaled units', fontsize=18)

        plt.subplot(122)
        plt.plot(targets_physical[ind],
                 predictions_physical.transpose()[ind],
                '.')
        #plt.xlabel(targets.names[0], fontsize=18)
        #plt.ylabel('Predicted ' + targets.names[0], fontsize=18)
        plt.axis('square')
        plt.title('Prediction performance in real units', fontsize=18)

# %% [markdown]
# ## GRU
#
# CREATE MODEL

# %%
def create_deep_learning_network(
    input_shape=(None, 50),
    lstm_layers_dimensions=(100, 50),
    number_of_outputs=2) :
    """Creates and compiles a deep learning network.
    
    Inputs:    
    input_shape: Should be the same size of the input trajectory []
    lstm_layers_dimensions: number of neurons in each LSTM layer [tuple of positive integers]
        
    Output:
    network: deep learning network
    """    

    from keras import models, layers, optimizers
    
    ### INITIALIZE DEEP LEARNING NETWORK
    network = models.Sequential()

    ### CONVOLUTIONAL BASIS
    for lstm_layer_number, lstm_layer_dimension in zip(range(len(lstm_layers_dimensions)), lstm_layers_dimensions):

        # add LSTM layer
        lstm_layer_name = 'lstm_' + str(lstm_layer_number + 1)
        if lstm_layer_number + 1 < len(lstm_layers_dimensions): # All layers but last
            lstm_layer = layers.GRU(lstm_layer_dimension,
                                     return_sequences=True,
                                     dropout=0,
                                     recurrent_dropout=0,
                                     input_shape=input_shape,
                                     name=lstm_layer_name)
        else: # Last layer
            lstm_layer = layers.GRU(lstm_layer_dimension,
                                     return_sequences=False,
                                     dropout=0,
                                     recurrent_dropout=0,
                                     input_shape=input_shape,
                                     name=lstm_layer_name)

        network.add(lstm_layer)
    # OUTPUT LAYER
    output_layer = layers.Dense(number_of_outputs, name='output')
    network.add(output_layer)
    
    network.compile(optimizer=optimizers.Adam(lr=1e-3), loss='mse', metrics=['mse', 'mae'])
    
    return network

# %%
### Create deep learning network
networkGRU = create_deep_learning_network()

### Print deep learning network summary
networkGRU.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_1 (GRU)                (None, None, 100)         45600
#
#  lstm_2 (GRU)                (None, 50)                22800
#
#  output (Dense)              (None, 2)                 102
#
# =================================================================
# Total params: 68,502
# Trainable params: 68,502
# Non-trainable params: 0
# _________________________________________________________________
# C:\Users\fap_9\anaconda3\lib\site-packages\keras\optimizers\optimizer_v2\adam.py:117: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super().__init__(name, **kwargs)

# %% [markdown]
# #### TRAIN MODEL

# %%
# %%time

training_history_GRU = train_deep_learning_network(networkGRU, simulate_trajectory)
# Out:
# C:\Users\fap_9\AppData\Local\Temp\ipykernel_44372\2641657375.py:64: RuntimeWarning: overflow encountered in power
#   X = X + C1 * X + C2 * X**3 + C3 * gauss(batch_size)
# C:\Users\fap_9\AppData\Local\Temp\ipykernel_44372\2641657375.py:64: RuntimeWarning: invalid value encountered in add
#   X = X + C1 * X + C2 * X**3 + C3 * gauss(batch_size)
# Sample size     32   iteration number      1   MSE        nan   MAE        nan   Time 3713.323593 ms
# C:\Users\fap_9\AppData\Local\Temp\ipykernel_44372\2641657375.py:68: RuntimeWarning: overflow encountered in power
#   X = X + C1 * X + C2 * X**3 + C3 * gauss(batch_size)
# C:\Users\fap_9\AppData\Local\Temp\ipykernel_44372\2641657375.py:68: RuntimeWarning: invalid value encountered in add
#   X = X + C1 * X + C2 * X**3 + C3 * gauss(batch_size)
# C:\Users\fap_9\anaconda3\lib\site-packages\tensorflow\python\framework\constant_op.py:102: RuntimeWarning: overflow encountered in cast
#   return ops.EagerTensor(value, ctx.device_name, dtype)
# Sample size     32   iteration number     11   MSE        nan   MAE        nan   Time 339.995861 ms
# Sample size     32   iteration number     21   MSE        nan   MAE        nan   Time 166.312218 ms
# Sample size     32   iteration number     31   MSE        nan   MAE        nan   Time 210.313082 ms
# Sample size     32   iteration number     41   MSE        nan   MAE        nan   Time 140.480518 ms
# Sample size     32   iteration number     51   MSE        nan   MAE        nan   Time 140.620708 ms
# Sample size     32   iteration number     61   MSE        nan   MAE        nan   Time 225.247145 ms
# Sample size     32   iteration number     71   MSE        nan   MAE        nan   Time 206.060171 ms
# Sample size     32   iteration number     81   MSE        nan   MAE        nan   Time 151.917458 ms
# Sample size     32   iteration number     91   MSE        nan   MAE        nan   Time 180.876970 ms
# Sample size     32   iteration number    101   MSE        nan   MAE        nan   Time 160.219193 ms
# Sample size     32   iteration number    111   MSE        nan   MAE        nan   Time 192.834854 ms
# Sample size     32   iteration number    121   MSE        nan   MAE        nan   Time 180.844307 ms
# Sample size     32   iteration number    131   MSE        nan   MAE        nan   Time 140.394211 ms
# Sample size     32   iteration number    141   MSE        nan   MAE        nan   Time 160.733938 ms
# Sample size     32   iteration number    151   MSE        nan   MAE        nan   Time 146.687746 ms
# Sample size     32   iteration number    161   MSE        nan   MAE        nan   Time 293.888092 ms
# Sample size     32   iteration number    171   MSE        nan   MAE        nan   Time 178.383112 ms
# Sample size     32   iteration number    181   MSE        nan   MAE        nan   Time 152.043581 ms
# Sample size     32   iteration number    191   MSE        nan   MAE        nan   Time 151.132584 ms
# Sample size     32   iteration number    201   MSE        nan   MAE        nan   Time 206.532001 ms
# Sample size     32   iteration number    211   MSE        nan   MAE        nan   Time 270.719528 ms
# Sample size     32   iteration number    221   MSE        nan   MAE        nan   Time 148.193598 ms
# Sample size     32   iteration number    231   MSE        nan   MAE        nan   Time 148.375034 ms
# Sample size     32   iteration number    241   MSE        nan   MAE        nan   Time 162.696600 ms
# Sample size     32   iteration number    251   MSE        nan   MAE        nan   Time 159.763813 ms
# Sample size     32   iteration number    261   MSE        nan   MAE        nan   Time 216.388464 ms
# Sample size     32   iteration number    271   MSE        nan   MAE        nan   Time 160.712481 ms
# Sample size     32   iteration number    281   MSE        nan   MAE        nan   Time 197.221756 ms
# Sample size     32   iteration number    291   MSE        nan   MAE        nan   Time 204.427481 ms
# C:\Users\fap_9\AppData\Local\Temp\ipykernel_44372\2641657375.py:26: RuntimeWarning: overflow encountered in multiply
#   scale_inputs = lambda x: x * 1e+6                    # Scales input trajectory to order 1
# Sample size     32   iteration number    301   MSE        nan   MAE        nan   Time 141.707659 ms
# Sample size     32   iteration number    311   MSE        nan   MAE        nan   Time 153.864384 ms
# Sample size     32   iteration number    321   MSE        nan   MAE        nan   Time 156.102180 ms
# Sample size     32   iteration number    331   MSE        nan   MAE        nan   Time 157.865047 ms
# Sample size     32   iteration number    341   MSE        nan   MAE        nan   Time 170.572996 ms
# Sample size     32   iteration number    351   MSE        nan   MAE        nan   Time 173.063993 ms
# Sample size     32   iteration number    361   MSE        nan   MAE        nan   Time 157.565832 ms
# Sample size     32   iteration number    371   MSE        nan   MAE        nan   Time 157.222986 ms
# Sample size     32   iteration number    381   MSE        nan   MAE        nan   Time 154.373169 ms
# Sample size     32   iteration number    391   MSE        nan   MAE        nan   Time 141.828537 ms
# Sample size     32   iteration number    401   MSE        nan   MAE        nan   Time 189.178228 ms
# Sample size     32   iteration number    411   MSE        nan   MAE        nan   Time 211.166859 ms
# Sample size     32   iteration number    421   MSE        nan   MAE        nan   Time 224.854231 ms
# Sample size     32   iteration number    431   MSE        nan   MAE        nan   Time 163.443565 ms
# Sample size     32   iteration number    441   MSE        nan   MAE        nan   Time 149.648190 ms
# Sample size     32   iteration number    451   MSE        nan   MAE        nan   Time 154.209852 ms
# Sample size     32   iteration number    461   MSE        nan   MAE        nan   Time 176.380873 ms
# Sample size     32   iteration number    471   MSE        nan   MAE        nan   Time 163.393259 ms
# Sample size     32   iteration number    481   MSE        nan   MAE        nan   Time 179.405689 ms
# Sample size     32   iteration number    491   MSE        nan   MAE        nan   Time 141.547441 ms
# Sample size     32   iteration number    501   MSE        nan   MAE        nan   Time 168.145895 ms
# Sample size     32   iteration number    511   MSE        nan   MAE        nan   Time 171.148777 ms
# Sample size     32   iteration number    521   MSE        nan   MAE        nan   Time 147.100687 ms
# Sample size     32   iteration number    531   MSE        nan   MAE        nan   Time 152.478218 ms
# Sample size     32   iteration number    541   MSE        nan   MAE        nan   Time 151.647329 ms
# Sample size     32   iteration number    551   MSE        nan   MAE        nan   Time 166.394234 ms
# Sample size     32   iteration number    561   MSE        nan   MAE        nan   Time 163.628578 ms
# Sample size     32   iteration number    571   MSE        nan   MAE        nan   Time 174.728155 ms
# Sample size     32   iteration number    581   MSE        nan   MAE        nan   Time 148.634672 ms
# Sample size     32   iteration number    591   MSE        nan   MAE        nan   Time 154.304981 ms
# Sample size     32   iteration number    601   MSE        nan   MAE        nan   Time 239.761591 ms
# Sample size     32   iteration number    611   MSE        nan   MAE        nan   Time 184.402227 ms
# Sample size     32   iteration number    621   MSE        nan   MAE        nan   Time 193.442106 ms
# Sample size     32   iteration number    631   MSE        nan   MAE        nan   Time 168.358088 ms
# Sample size     32   iteration number    641   MSE        nan   MAE        nan   Time 175.927877 ms
# Sample size     32   iteration number    651   MSE        nan   MAE        nan   Time 162.076712 ms
# Sample size     32   iteration number    661   MSE        nan   MAE        nan   Time 163.082600 ms
# Sample size     32   iteration number    671   MSE        nan   MAE        nan   Time 159.763813 ms
# Sample size     32   iteration number    681   MSE        nan   MAE        nan   Time 178.142786 ms
# Sample size     32   iteration number    691   MSE        nan   MAE        nan   Time 165.926695 ms
# Sample size     32   iteration number    701   MSE        nan   MAE        nan   Time 181.295633 ms
# Sample size     32   iteration number    711   MSE        nan   MAE        nan   Time 176.385641 ms
# Sample size     32   iteration number    721   MSE        nan   MAE        nan   Time 155.378342 ms
# Sample size     32   iteration number    731   MSE        nan   MAE        nan   Time 168.426991 ms
# Sample size     32   iteration number    741   MSE        nan   MAE        nan   Time 180.340052 ms
# Sample size     32   iteration number    751   MSE        nan   MAE        nan   Time 165.723801 ms
# Sample size     32   iteration number    761   MSE        nan   MAE        nan   Time 172.954798 ms
# Sample size     32   iteration number    771   MSE        nan   MAE        nan   Time 165.689945 ms
# Sample size     32   iteration number    781   MSE        nan   MAE        nan   Time 158.170462 ms
# Sample size     32   iteration number    791   MSE        nan   MAE        nan   Time 161.017895 ms
# Sample size     32   iteration number    801   MSE        nan   MAE        nan   Time 181.491613 ms
# Sample size     32   iteration number    811   MSE        nan   MAE        nan   Time 166.075945 ms
# Sample size     32   iteration number    821   MSE        nan   MAE        nan   Time 161.583424 ms
# Sample size     32   iteration number    831   MSE        nan   MAE        nan   Time 176.729202 ms
# Sample size     32   iteration number    841   MSE        nan   MAE        nan   Time 154.021502 ms
# Sample size     32   iteration number    851   MSE        nan   MAE        nan   Time 161.081553 ms
# Sample size     32   iteration number    861   MSE        nan   MAE        nan   Time 173.703671 ms
# Sample size     32   iteration number    871   MSE        nan   MAE        nan   Time 177.497864 ms
# Sample size     32   iteration number    881   MSE        nan   MAE        nan   Time 158.717632 ms
# Sample size     32   iteration number    891   MSE        nan   MAE        nan   Time 155.754566 ms
# Sample size     32   iteration number    901   MSE        nan   MAE        nan   Time 151.126862 ms
# Sample size     32   iteration number    911   MSE        nan   MAE        nan   Time 152.831078 ms
# Sample size     32   iteration number    921   MSE        nan   MAE        nan   Time 183.926582 ms
# Sample size     32   iteration number    931   MSE        nan   MAE        nan   Time 170.670033 ms
# Sample size     32   iteration number    941   MSE        nan   MAE        nan   Time 148.289204 ms
# Sample size     32   iteration number    951   MSE        nan   MAE        nan   Time 171.994209 ms
# Sample size     32   iteration number    961   MSE        nan   MAE        nan   Time 163.899422 ms
# Sample size     32   iteration number    971   MSE        nan   MAE        nan   Time 181.711912 ms
# Sample size     32   iteration number    981   MSE        nan   MAE        nan   Time 193.430185 ms
# Sample size     32   iteration number    991   MSE        nan   MAE        nan   Time 166.782141 ms
# Sample size     32   iteration number   1001   MSE        nan   MAE        nan   Time 156.102896 ms
# Sample size     32   iteration number   1011   MSE        nan   MAE        nan   Time 159.677267 ms
# Sample size     32   iteration number   1021   MSE        nan   MAE        nan   Time 173.708200 ms
# Sample size     32   iteration number   1031   MSE        nan   MAE        nan   Time 192.720890 ms
# Sample size     32   iteration number   1041   MSE        nan   MAE        nan   Time 184.177637 ms
# Sample size     32   iteration number   1051   MSE        nan   MAE        nan   Time 190.757990 ms
# Sample size     32   iteration number   1061   MSE        nan   MAE        nan   Time 172.786951 ms
# Sample size     32   iteration number   1071   MSE        nan   MAE        nan   Time 159.052849 ms
# Sample size     32   iteration number   1081   MSE        nan   MAE        nan   Time 148.065329 ms
# Sample size     32   iteration number   1091   MSE        nan   MAE        nan   Time 191.498280 ms
# Sample size     32   iteration number   1101   MSE        nan   MAE        nan   Time 186.983824 ms
# Sample size     32   iteration number   1111   MSE        nan   MAE        nan   Time 171.144009 ms
# Sample size     32   iteration number   1121   MSE        nan   MAE        nan   Time 178.394556 ms
# Sample size     32   iteration number   1131   MSE        nan   MAE        nan   Time 169.365883 ms
# Sample size     32   iteration number   1141   MSE        nan   MAE        nan   Time 171.528101 ms
# Sample size     32   iteration number   1151   MSE        nan   MAE        nan   Time 186.515093 ms
# Sample size     32   iteration number   1161   MSE        nan   MAE        nan   Time 180.608988 ms
# Sample size     32   iteration number   1171   MSE        nan   MAE        nan   Time 176.375628 ms
# Sample size     32   iteration number   1181   MSE        nan   MAE        nan   Time 141.358137 ms
# Sample size     32   iteration number   1191   MSE        nan   MAE        nan   Time 162.533760 ms
# Sample size     32   iteration number   1201   MSE        nan   MAE        nan   Time 180.321455 ms
# Sample size     32   iteration number   1211   MSE        nan   MAE        nan   Time 168.434143 ms
# Sample size     32   iteration number   1221   MSE        nan   MAE        nan   Time 188.305140 ms
# Sample size     32   iteration number   1231   MSE        nan   MAE        nan   Time 179.717064 ms
# Sample size     32   iteration number   1241   MSE        nan   MAE        nan   Time 168.881655 ms
# Sample size     32   iteration number   1251   MSE        nan   MAE        nan   Time 160.395861 ms
# Sample size     32   iteration number   1261   MSE        nan   MAE        nan   Time 180.211544 ms
# Sample size     32   iteration number   1271   MSE        nan   MAE        nan   Time 178.621769 ms
# Sample size     32   iteration number   1281   MSE        nan   MAE        nan   Time 143.880129 ms
# Sample size     32   iteration number   1291   MSE        nan   MAE        nan   Time 179.625750 ms
# Sample size     32   iteration number   1301   MSE        nan   MAE        nan   Time 189.228058 ms
# Sample size     32   iteration number   1311   MSE        nan   MAE        nan   Time 179.607153 ms
# Sample size     32   iteration number   1321   MSE        nan   MAE        nan   Time 184.603214 ms
# Sample size     32   iteration number   1331   MSE        nan   MAE        nan   Time 198.618412 ms
# Sample size     32   iteration number   1341   MSE        nan   MAE        nan   Time 194.432735 ms
# Sample size     32   iteration number   1351   MSE        nan   MAE        nan   Time 192.525625 ms
# Sample size     32   iteration number   1361   MSE        nan   MAE        nan   Time 189.766169 ms
# Sample size     32   iteration number   1371   MSE        nan   MAE        nan   Time 194.221020 ms
# Sample size     32   iteration number   1381   MSE        nan   MAE        nan   Time 195.917845 ms
# Sample size     32   iteration number   1391   MSE        nan   MAE        nan   Time 175.690413 ms
# Sample size     32   iteration number   1401   MSE        nan   MAE        nan   Time 174.668074 ms
# Sample size     32   iteration number   1411   MSE        nan   MAE        nan   Time 184.696436 ms
# Sample size     32   iteration number   1421   MSE        nan   MAE        nan   Time 179.788828 ms
# Sample size     32   iteration number   1431   MSE        nan   MAE        nan   Time 210.452795 ms
# Sample size     32   iteration number   1441   MSE        nan   MAE        nan   Time 178.234577 ms
# Sample size     32   iteration number   1451   MSE        nan   MAE        nan   Time 196.946383 ms
# Sample size     32   iteration number   1461   MSE        nan   MAE        nan   Time 188.866138 ms
# Sample size     32   iteration number   1471   MSE        nan   MAE        nan   Time 210.021019 ms
# Sample size     32   iteration number   1481   MSE        nan   MAE        nan   Time 204.416990 ms
# Sample size     32   iteration number   1491   MSE        nan   MAE        nan   Time 193.023920 ms
# Sample size     32   iteration number   1501   MSE        nan   MAE        nan   Time 202.868223 ms
# Sample size     32   iteration number   1511   MSE        nan   MAE        nan   Time 200.756788 ms
# Sample size     32   iteration number   1521   MSE        nan   MAE        nan   Time 192.253590 ms
# Sample size     32   iteration number   1531   MSE        nan   MAE        nan   Time 184.426546 ms
# Sample size     32   iteration number   1541   MSE        nan   MAE        nan   Time 181.551933 ms
# Sample size     32   iteration number   1551   MSE        nan   MAE        nan   Time 181.960583 ms
# Sample size     32   iteration number   1561   MSE        nan   MAE        nan   Time 147.773027 ms
# Sample size     32   iteration number   1571   MSE        nan   MAE        nan   Time 174.762487 ms
# Sample size     32   iteration number   1581   MSE        nan   MAE        nan   Time 189.553499 ms
# Sample size     32   iteration number   1591   MSE        nan   MAE        nan   Time 192.140102 ms
# Sample size     32   iteration number   1601   MSE        nan   MAE        nan   Time 218.111753 ms
# Sample size     32   iteration number   1611   MSE        nan   MAE        nan   Time 236.349344 ms
# Sample size     32   iteration number   1621   MSE        nan   MAE        nan   Time 182.331324 ms
# Sample size     32   iteration number   1631   MSE        nan   MAE        nan   Time 193.682194 ms
# Sample size     32   iteration number   1641   MSE        nan   MAE        nan   Time 191.274405 ms
# Sample size     32   iteration number   1651   MSE        nan   MAE        nan   Time 212.345600 ms
# Sample size     32   iteration number   1661   MSE        nan   MAE        nan   Time 190.747499 ms
# Sample size     32   iteration number   1671   MSE        nan   MAE        nan   Time 188.323498 ms
# Sample size     32   iteration number   1681   MSE        nan   MAE        nan   Time 206.216574 ms
# Sample size     32   iteration number   1691   MSE        nan   MAE        nan   Time 181.619167 ms
# Sample size     32   iteration number   1701   MSE        nan   MAE        nan   Time 177.059412 ms
# Sample size     32   iteration number   1711   MSE        nan   MAE        nan   Time 188.683271 ms
# Sample size     32   iteration number   1721   MSE        nan   MAE        nan   Time 186.784506 ms
# Sample size     32   iteration number   1731   MSE        nan   MAE        nan   Time 198.643684 ms
# Sample size     32   iteration number   1741   MSE        nan   MAE        nan   Time 199.839354 ms
# Sample size     32   iteration number   1751   MSE        nan   MAE        nan   Time 194.336414 ms
# Sample size     32   iteration number   1761   MSE        nan   MAE        nan   Time 180.433989 ms
# Sample size     32   iteration number   1771   MSE        nan   MAE        nan   Time 182.657719 ms
# Sample size     32   iteration number   1781   MSE        nan   MAE        nan   Time 172.535896 ms
# Sample size     32   iteration number   1791   MSE        nan   MAE        nan   Time 196.993351 ms
# Sample size     32   iteration number   1801   MSE        nan   MAE        nan   Time 171.174765 ms
# Sample size     32   iteration number   1811   MSE        nan   MAE        nan   Time 196.500540 ms
# Sample size     32   iteration number   1821   MSE        nan   MAE        nan   Time 204.594612 ms
# Sample size     32   iteration number   1831   MSE        nan   MAE        nan   Time 187.650681 ms
# Sample size     32   iteration number   1841   MSE        nan   MAE        nan   Time 195.674181 ms
# Sample size     32   iteration number   1851   MSE        nan   MAE        nan   Time 204.461575 ms
# Sample size     32   iteration number   1861   MSE        nan   MAE        nan   Time 203.555822 ms
# Sample size     32   iteration number   1871   MSE        nan   MAE        nan   Time 223.968506 ms
# Sample size     32   iteration number   1881   MSE        nan   MAE        nan   Time 235.828400 ms
# Sample size     32   iteration number   1891   MSE        nan   MAE        nan   Time 221.235037 ms
# Sample size     32   iteration number   1901   MSE        nan   MAE        nan   Time 175.445557 ms
# Sample size     32   iteration number   1911   MSE        nan   MAE        nan   Time 199.043512 ms
# Sample size     32   iteration number   1921   MSE        nan   MAE        nan   Time 202.057123 ms
# Sample size     32   iteration number   1931   MSE        nan   MAE        nan   Time 407.808065 ms
# Sample size     32   iteration number   1941   MSE        nan   MAE        nan   Time 512.527704 ms
# Sample size     32   iteration number   1951   MSE        nan   MAE        nan   Time 472.884655 ms
# Sample size     32   iteration number   1961   MSE        nan   MAE        nan   Time 318.794966 ms
# Sample size     32   iteration number   1971   MSE        nan   MAE        nan   Time 300.595045 ms
# Sample size     32   iteration number   1981   MSE        nan   MAE        nan   Time 309.822321 ms
# Sample size     32   iteration number   1991   MSE        nan   MAE        nan   Time 260.150909 ms
# Sample size     32   iteration number   2001   MSE        nan   MAE        nan   Time 216.683388 ms
# Sample size     32   iteration number   2011   MSE        nan   MAE        nan   Time 205.442190 ms
# Sample size     32   iteration number   2021   MSE        nan   MAE        nan   Time 225.386143 ms
# Sample size     32   iteration number   2031   MSE        nan   MAE        nan   Time 233.890533 ms
# Sample size     32   iteration number   2041   MSE        nan   MAE        nan   Time 230.026484 ms
# Sample size     32   iteration number   2051   MSE        nan   MAE        nan   Time 216.470003 ms
# Sample size     32   iteration number   2061   MSE        nan   MAE        nan   Time 220.802546 ms
# Sample size     32   iteration number   2071   MSE        nan   MAE        nan   Time 243.540287 ms
# Sample size     32   iteration number   2081   MSE        nan   MAE        nan   Time 251.163960 ms
# Sample size     32   iteration number   2091   MSE        nan   MAE        nan   Time 273.614645 ms
# Sample size     32   iteration number   2101   MSE        nan   MAE        nan   Time 274.645805 ms
# Sample size     32   iteration number   2111   MSE        nan   MAE        nan   Time 262.299538 ms
# Sample size     32   iteration number   2121   MSE        nan   MAE        nan   Time 236.040831 ms
# Sample size     32   iteration number   2131   MSE        nan   MAE        nan   Time 220.300674 ms
# Sample size     32   iteration number   2141   MSE        nan   MAE        nan   Time 219.919443 ms
# Sample size     32   iteration number   2151   MSE        nan   MAE        nan   Time 276.998997 ms
# Sample size     32   iteration number   2161   MSE        nan   MAE        nan   Time 262.703657 ms
# Sample size     32   iteration number   2171   MSE        nan   MAE        nan   Time 279.004574 ms
# Sample size     32   iteration number   2181   MSE        nan   MAE        nan   Time 255.189419 ms
# Sample size     32   iteration number   2191   MSE        nan   MAE        nan   Time 307.366133 ms
# Sample size     32   iteration number   2201   MSE        nan   MAE        nan   Time 293.823719 ms
# Sample size     32   iteration number   2211   MSE        nan   MAE        nan   Time 363.440037 ms
# Sample size     32   iteration number   2221   MSE        nan   MAE        nan   Time 251.137257 ms
# Sample size     32   iteration number   2231   MSE        nan   MAE        nan   Time 230.401754 ms
# Sample size     32   iteration number   2241   MSE        nan   MAE        nan   Time 233.270168 ms
# Sample size     32   iteration number   2251   MSE        nan   MAE        nan   Time 248.588562 ms
# Sample size     32   iteration number   2261   MSE        nan   MAE        nan   Time 252.900839 ms
# Sample size     32   iteration number   2271   MSE        nan   MAE        nan   Time 249.692678 ms
# Sample size     32   iteration number   2281   MSE        nan   MAE        nan   Time 325.378895 ms
# Sample size     32   iteration number   2291   MSE        nan   MAE        nan   Time 298.154116 ms
# Sample size     32   iteration number   2301   MSE        nan   MAE        nan   Time 230.422497 ms
# Sample size     32   iteration number   2311   MSE        nan   MAE        nan   Time 211.419106 ms
# Sample size     32   iteration number   2321   MSE        nan   MAE        nan   Time 280.848265 ms
# Sample size     32   iteration number   2331   MSE        nan   MAE        nan   Time 224.620104 ms
# Sample size     32   iteration number   2341   MSE        nan   MAE        nan   Time 270.745754 ms
# Sample size     32   iteration number   2351   MSE        nan   MAE        nan   Time 274.044514 ms
# Sample size     32   iteration number   2361   MSE        nan   MAE        nan   Time 289.079428 ms
# Sample size     32   iteration number   2371   MSE        nan   MAE        nan   Time 248.969078 ms
# Sample size     32   iteration number   2381   MSE        nan   MAE        nan   Time 248.102427 ms
# Sample size     32   iteration number   2391   MSE        nan   MAE        nan   Time 245.898008 ms
# Sample size     32   iteration number   2401   MSE        nan   MAE        nan   Time 248.049021 ms
# Sample size     32   iteration number   2411   MSE        nan   MAE        nan   Time 280.378580 ms
# Sample size     32   iteration number   2421   MSE        nan   MAE        nan   Time 301.841021 ms
# Sample size     32   iteration number   2431   MSE        nan   MAE        nan   Time 294.100523 ms
# Sample size     32   iteration number   2441   MSE        nan   MAE        nan   Time 262.700319 ms
# Sample size     32   iteration number   2451   MSE        nan   MAE        nan   Time 261.299133 ms
# Sample size     32   iteration number   2461   MSE        nan   MAE        nan   Time 237.743616 ms
# Sample size     32   iteration number   2471   MSE        nan   MAE        nan   Time 311.489820 ms
# Sample size     32   iteration number   2481   MSE        nan   MAE        nan   Time 241.732836 ms
# Sample size     32   iteration number   2491   MSE        nan   MAE        nan   Time 248.445511 ms
# Sample size     32   iteration number   2501   MSE        nan   MAE        nan   Time 238.296270 ms
# Sample size     32   iteration number   2511   MSE        nan   MAE        nan   Time 236.000776 ms
# Sample size     32   iteration number   2521   MSE        nan   MAE        nan   Time 222.245455 ms
# Sample size     32   iteration number   2531   MSE        nan   MAE        nan   Time 251.805544 ms
# Sample size     32   iteration number   2541   MSE        nan   MAE        nan   Time 256.710768 ms
# Sample size     32   iteration number   2551   MSE        nan   MAE        nan   Time 262.689590 ms
# Sample size     32   iteration number   2561   MSE        nan   MAE        nan   Time 278.548479 ms
# Sample size     32   iteration number   2571   MSE        nan   MAE        nan   Time 237.937450 ms
# Sample size     32   iteration number   2581   MSE        nan   MAE        nan   Time 226.469040 ms
# Sample size     32   iteration number   2591   MSE        nan   MAE        nan   Time 235.432625 ms
# Sample size     32   iteration number   2601   MSE        nan   MAE        nan   Time 269.301176 ms
# Sample size     32   iteration number   2611   MSE        nan   MAE        nan   Time 258.284092 ms
# Sample size     32   iteration number   2621   MSE        nan   MAE        nan   Time 239.851952 ms
# Sample size     32   iteration number   2631   MSE        nan   MAE        nan   Time 249.300957 ms
# Sample size     32   iteration number   2641   MSE        nan   MAE        nan   Time 292.956352 ms
# Sample size     32   iteration number   2651   MSE        nan   MAE        nan   Time 264.266968 ms
# Sample size     32   iteration number   2661   MSE        nan   MAE        nan   Time 277.253389 ms
# Sample size     32   iteration number   2671   MSE        nan   MAE        nan   Time 305.134773 ms
# Sample size     32   iteration number   2681   MSE        nan   MAE        nan   Time 241.943836 ms
# Sample size     32   iteration number   2691   MSE        nan   MAE        nan   Time 257.901430 ms
# Sample size     32   iteration number   2701   MSE        nan   MAE        nan   Time 250.242949 ms
# Sample size     32   iteration number   2711   MSE        nan   MAE        nan   Time 241.698742 ms
# Sample size     32   iteration number   2721   MSE        nan   MAE        nan   Time 269.576788 ms
# Sample size     32   iteration number   2731   MSE        nan   MAE        nan   Time 267.348766 ms
# Sample size     32   iteration number   2741   MSE        nan   MAE        nan   Time 272.147417 ms
# Sample size     32   iteration number   2751   MSE        nan   MAE        nan   Time 301.094532 ms
# Sample size     32   iteration number   2761   MSE        nan   MAE        nan   Time 283.119202 ms
# Sample size     32   iteration number   2771   MSE        nan   MAE        nan   Time 355.001688 ms
# Sample size     32   iteration number   2781   MSE        nan   MAE        nan   Time 318.376303 ms
# Sample size     32   iteration number   2791   MSE        nan   MAE        nan   Time 266.944885 ms
# Sample size     32   iteration number   2801   MSE        nan   MAE        nan   Time 288.362265 ms
# Sample size     32   iteration number   2811   MSE        nan   MAE        nan   Time 282.253265 ms
# Sample size     32   iteration number   2821   MSE        nan   MAE        nan   Time 279.527187 ms
# Sample size     32   iteration number   2831   MSE        nan   MAE        nan   Time 271.075726 ms
# Sample size     32   iteration number   2841   MSE        nan   MAE        nan   Time 249.880314 ms
# Sample size     32   iteration number   2851   MSE        nan   MAE        nan   Time 304.102659 ms
# Sample size     32   iteration number   2861   MSE        nan   MAE        nan   Time 273.289442 ms
# Sample size     32   iteration number   2871   MSE        nan   MAE        nan   Time 270.433903 ms
# Sample size     32   iteration number   2881   MSE        nan   MAE        nan   Time 263.220072 ms
# Sample size     32   iteration number   2891   MSE        nan   MAE        nan   Time 275.119066 ms
# Sample size     32   iteration number   2901   MSE        nan   MAE        nan   Time 307.282925 ms
# Sample size     32   iteration number   2911   MSE        nan   MAE        nan   Time 254.079819 ms
# Sample size     32   iteration number   2921   MSE        nan   MAE        nan   Time 265.528679 ms
# Sample size     32   iteration number   2931   MSE        nan   MAE        nan   Time 299.533129 ms
# Sample size     32   iteration number   2941   MSE        nan   MAE        nan   Time 262.384653 ms
# Sample size     32   iteration number   2951   MSE        nan   MAE        nan   Time 247.307539 ms
# Sample size     32   iteration number   2961   MSE        nan   MAE        nan   Time 244.769335 ms
# Sample size     32   iteration number   2971   MSE        nan   MAE        nan   Time 254.867077 ms
# Sample size     32   iteration number   2981   MSE        nan   MAE        nan   Time 253.677368 ms
# Sample size     32   iteration number   2991   MSE        nan   MAE        nan   Time 238.487482 ms
# Sample size     32   iteration number   3001   MSE        nan   MAE        nan   Time 265.222073 ms
# Sample size    128   iteration number      1   MSE        nan   MAE        nan   Time 3744.932175 ms
# Sample size    128   iteration number     11   MSE        nan   MAE        nan   Time 468.554735 ms
# Sample size    128   iteration number     21   MSE        nan   MAE        nan   Time 395.413160 ms
# C:\Users\fap_9\AppData\Local\Temp\ipykernel_44372\2641657375.py:64: RuntimeWarning: overflow encountered in add
#   X = X + C1 * X + C2 * X**3 + C3 * gauss(batch_size)
# Sample size    128   iteration number     31   MSE        nan   MAE        nan   Time 401.735067 ms
# Sample size    128   iteration number     41   MSE        nan   MAE        nan   Time 474.464178 ms
# Sample size    128   iteration number     51   MSE        nan   MAE        nan   Time 430.627823 ms
# Sample size    128   iteration number     61   MSE        nan   MAE        nan   Time 418.010712 ms
# Sample size    128   iteration number     71   MSE        nan   MAE        nan   Time 380.255699 ms
# Sample size    128   iteration number     81   MSE        nan   MAE        nan   Time 437.066555 ms
# Sample size    128   iteration number     91   MSE        nan   MAE        nan   Time 396.482944 ms
# Sample size    128   iteration number    101   MSE        nan   MAE        nan   Time 400.140762 ms
# Sample size    128   iteration number    111   MSE        nan   MAE        nan   Time 361.958265 ms
# Sample size    128   iteration number    121   MSE        nan   MAE        nan   Time 442.044020 ms
# Sample size    128   iteration number    131   MSE        nan   MAE        nan   Time 469.106674 ms
# Sample size    128   iteration number    141   MSE        nan   MAE        nan   Time 460.298300 ms
# Sample size    128   iteration number    151   MSE        nan   MAE        nan   Time 402.964830 ms
# Sample size    128   iteration number    161   MSE        nan   MAE        nan   Time 433.686733 ms
# Sample size    128   iteration number    171   MSE        nan   MAE        nan   Time 363.837242 ms
# Sample size    128   iteration number    181   MSE        nan   MAE        nan   Time 455.977917 ms
# Sample size    128   iteration number    191   MSE        nan   MAE        nan   Time 485.367775 ms
# Sample size    128   iteration number    201   MSE        nan   MAE        nan   Time 467.516184 ms
# Sample size    128   iteration number    211   MSE        nan   MAE        nan   Time 467.716694 ms
# Sample size    128   iteration number    221   MSE        nan   MAE        nan   Time 496.242762 ms
# Sample size    128   iteration number    231   MSE        nan   MAE        nan   Time 469.609499 ms
# Sample size    128   iteration number    241   MSE        nan   MAE        nan   Time 502.011538 ms
# Sample size    128   iteration number    251   MSE        nan   MAE        nan   Time 474.081278 ms
# Sample size    128   iteration number    261   MSE        nan   MAE        nan   Time 447.233438 ms
# Sample size    128   iteration number    271   MSE        nan   MAE        nan   Time 517.833710 ms
# Sample size    128   iteration number    281   MSE        nan   MAE        nan   Time 461.576223 ms
# Sample size    128   iteration number    291   MSE        nan   MAE        nan   Time 539.358616 ms
# Sample size    128   iteration number    301   MSE        nan   MAE        nan   Time 498.149395 ms
# Sample size    128   iteration number    311   MSE        nan   MAE        nan   Time 430.608034 ms
# Sample size    128   iteration number    321   MSE        nan   MAE        nan   Time 468.868732 ms
# Sample size    128   iteration number    331   MSE        nan   MAE        nan   Time 459.380388 ms
# Sample size    128   iteration number    341   MSE        nan   MAE        nan   Time 454.896212 ms
# Sample size    128   iteration number    351   MSE        nan   MAE        nan   Time 434.203386 ms
# Sample size    128   iteration number    361   MSE        nan   MAE        nan   Time 466.289520 ms
# Sample size    128   iteration number    371   MSE        nan   MAE        nan   Time 466.891050 ms
# Sample size    128   iteration number    381   MSE        nan   MAE        nan   Time 427.708387 ms
# Sample size    128   iteration number    391   MSE        nan   MAE        nan   Time 575.272799 ms
# Sample size    128   iteration number    401   MSE        nan   MAE        nan   Time 567.867756 ms
# Sample size    128   iteration number    411   MSE        nan   MAE        nan   Time 468.021154 ms
# Sample size    128   iteration number    421   MSE        nan   MAE        nan   Time 532.727957 ms
# Sample size    128   iteration number    431   MSE        nan   MAE        nan   Time 500.036955 ms
# Sample size    128   iteration number    441   MSE        nan   MAE        nan   Time 406.271219 ms
# Sample size    128   iteration number    451   MSE        nan   MAE        nan   Time 417.568445 ms
# Sample size    128   iteration number    461   MSE        nan   MAE        nan   Time 476.810694 ms
# Sample size    128   iteration number    471   MSE        nan   MAE        nan   Time 480.440378 ms
# Sample size    128   iteration number    481   MSE        nan   MAE        nan   Time 484.786749 ms
# Sample size    128   iteration number    491   MSE        nan   MAE        nan   Time 530.920982 ms
# Sample size    128   iteration number    501   MSE        nan   MAE        nan   Time 470.668316 ms
# Sample size    128   iteration number    511   MSE        nan   MAE        nan   Time 486.350060 ms
# Sample size    128   iteration number    521   MSE        nan   MAE        nan   Time 580.030441 ms
# Sample size    128   iteration number    531   MSE        nan   MAE        nan   Time 499.955416 ms
# Sample size    128   iteration number    541   MSE        nan   MAE        nan   Time 547.202349 ms
# Sample size    128   iteration number    551   MSE        nan   MAE        nan   Time 432.208538 ms
# Sample size    128   iteration number    561   MSE        nan   MAE        nan   Time 476.853848 ms
# Sample size    128   iteration number    571   MSE        nan   MAE        nan   Time 454.519272 ms
# Sample size    128   iteration number    581   MSE        nan   MAE        nan   Time 446.636915 ms
# Sample size    128   iteration number    591   MSE        nan   MAE        nan   Time 441.032410 ms
# Sample size    128   iteration number    601   MSE        nan   MAE        nan   Time 425.346136 ms
# Sample size    128   iteration number    611   MSE        nan   MAE        nan   Time 467.599869 ms
# Sample size    128   iteration number    621   MSE        nan   MAE        nan   Time 484.939575 ms
# Sample size    128   iteration number    631   MSE        nan   MAE        nan   Time 458.743334 ms
# Sample size    128   iteration number    641   MSE        nan   MAE        nan   Time 535.737991 ms
# Sample size    128   iteration number    651   MSE        nan   MAE        nan   Time 497.735023 ms
# Sample size    128   iteration number    661   MSE        nan   MAE        nan   Time 494.574308 ms
# Sample size    128   iteration number    671   MSE        nan   MAE        nan   Time 519.108772 ms
# Sample size    128   iteration number    681   MSE        nan   MAE        nan   Time 634.193182 ms
# Sample size    128   iteration number    691   MSE        nan   MAE        nan   Time 468.951464 ms
# Sample size    128   iteration number    701   MSE        nan   MAE        nan   Time 503.527403 ms
# Sample size    128   iteration number    711   MSE        nan   MAE        nan   Time 447.567701 ms
# Sample size    128   iteration number    721   MSE        nan   MAE        nan   Time 500.376701 ms
# Sample size    128   iteration number    731   MSE        nan   MAE        nan   Time 472.019434 ms
# Sample size    128   iteration number    741   MSE        nan   MAE        nan   Time 425.957918 ms
# Sample size    128   iteration number    751   MSE        nan   MAE        nan   Time 523.694277 ms
# Sample size    128   iteration number    761   MSE        nan   MAE        nan   Time 464.939356 ms
# Sample size    128   iteration number    771   MSE        nan   MAE        nan   Time 454.926252 ms
# Sample size    128   iteration number    781   MSE        nan   MAE        nan   Time 482.314587 ms
# Sample size    128   iteration number    791   MSE        nan   MAE        nan   Time 502.718210 ms
# Sample size    128   iteration number    801   MSE        nan   MAE        nan   Time 483.580589 ms
# Sample size    128   iteration number    811   MSE        nan   MAE        nan   Time 448.863268 ms
# Sample size    128   iteration number    821   MSE        nan   MAE        nan   Time 552.946091 ms
# Sample size    128   iteration number    831   MSE        nan   MAE        nan   Time 474.920988 ms
# Sample size    128   iteration number    841   MSE        nan   MAE        nan   Time 635.603189 ms
# Sample size    128   iteration number    851   MSE        nan   MAE        nan   Time 489.339828 ms
# Sample size    128   iteration number    861   MSE        nan   MAE        nan   Time 547.794104 ms
# Sample size    128   iteration number    871   MSE        nan   MAE        nan   Time 538.531780 ms
# Sample size    128   iteration number    881   MSE        nan   MAE        nan   Time 502.979279 ms
# Sample size    128   iteration number    891   MSE        nan   MAE        nan   Time 510.082006 ms
# Sample size    128   iteration number    901   MSE        nan   MAE        nan   Time 576.934338 ms
# Sample size    128   iteration number    911   MSE        nan   MAE        nan   Time 484.982491 ms
# Sample size    128   iteration number    921   MSE        nan   MAE        nan   Time 509.702206 ms
# Sample size    128   iteration number    931   MSE        nan   MAE        nan   Time 486.197233 ms
# Sample size    128   iteration number    941   MSE        nan   MAE        nan   Time 488.656044 ms
# Sample size    128   iteration number    951   MSE        nan   MAE        nan   Time 493.626118 ms
# Sample size    128   iteration number    961   MSE        nan   MAE        nan   Time 415.348291 ms
# Sample size    128   iteration number    971   MSE        nan   MAE        nan   Time 483.407259 ms
# Sample size    128   iteration number    981   MSE        nan   MAE        nan   Time 489.930630 ms
# Sample size    128   iteration number    991   MSE        nan   MAE        nan   Time 498.384476 ms
# Sample size    128   iteration number   1001   MSE        nan   MAE        nan   Time 586.620569 ms
# Sample size    128   iteration number   1011   MSE        nan   MAE        nan   Time 421.555042 ms
# Sample size    128   iteration number   1021   MSE        nan   MAE        nan   Time 464.843988 ms
# Sample size    128   iteration number   1031   MSE        nan   MAE        nan   Time 498.308420 ms
# Sample size    128   iteration number   1041   MSE        nan   MAE        nan   Time 476.104498 ms
# Sample size    128   iteration number   1051   MSE        nan   MAE        nan   Time 500.706196 ms
# Sample size    128   iteration number   1061   MSE        nan   MAE        nan   Time 482.749939 ms
# Sample size    128   iteration number   1071   MSE        nan   MAE        nan   Time 495.775700 ms
# Sample size    128   iteration number   1081   MSE        nan   MAE        nan   Time 475.875616 ms
# Sample size    128   iteration number   1091   MSE        nan   MAE        nan   Time 580.798388 ms
# Sample size    128   iteration number   1101   MSE        nan   MAE        nan   Time 484.029293 ms
# Sample size    128   iteration number   1111   MSE        nan   MAE        nan   Time 516.912222 ms
# Sample size    128   iteration number   1121   MSE        nan   MAE        nan   Time 529.350042 ms
# Sample size    128   iteration number   1131   MSE        nan   MAE        nan   Time 496.113777 ms
# Sample size    128   iteration number   1141   MSE        nan   MAE        nan   Time 532.563448 ms
# Sample size    128   iteration number   1151   MSE        nan   MAE        nan   Time 578.874111 ms
# Sample size    128   iteration number   1161   MSE        nan   MAE        nan   Time 498.327732 ms
# Sample size    128   iteration number   1171   MSE        nan   MAE        nan   Time 494.648218 ms
# Sample size    128   iteration number   1181   MSE        nan   MAE        nan   Time 547.321558 ms
# Sample size    128   iteration number   1191   MSE        nan   MAE        nan   Time 422.245741 ms
# Sample size    128   iteration number   1201   MSE        nan   MAE        nan   Time 399.072170 ms
# Sample size    128   iteration number   1211   MSE        nan   MAE        nan   Time 423.695803 ms
# Sample size    128   iteration number   1221   MSE        nan   MAE        nan   Time 540.212631 ms
# Sample size    128   iteration number   1231   MSE        nan   MAE        nan   Time 456.395864 ms
# Sample size    128   iteration number   1241   MSE        nan   MAE        nan   Time 620.169878 ms
# Sample size    128   iteration number   1251   MSE        nan   MAE        nan   Time 579.614878 ms
# Sample size    128   iteration number   1261   MSE        nan   MAE        nan   Time 631.169081 ms
# Sample size    128   iteration number   1271   MSE        nan   MAE        nan   Time 563.116074 ms
# Sample size    128   iteration number   1281   MSE        nan   MAE        nan   Time 573.091745 ms
# Sample size    128   iteration number   1291   MSE        nan   MAE        nan   Time 495.302200 ms
# Sample size    128   iteration number   1301   MSE        nan   MAE        nan   Time 570.066214 ms
# Sample size    128   iteration number   1311   MSE        nan   MAE        nan   Time 940.161705 ms
# Sample size    128   iteration number   1321   MSE        nan   MAE        nan   Time 501.811028 ms
# Sample size    128   iteration number   1331   MSE        nan   MAE        nan   Time 874.355793 ms
# Sample size    128   iteration number   1341   MSE        nan   MAE        nan   Time 966.991901 ms
# Sample size    128   iteration number   1351   MSE        nan   MAE        nan   Time 425.395489 ms
# Sample size    128   iteration number   1361   MSE        nan   MAE        nan   Time 549.961567 ms
# Sample size    128   iteration number   1371   MSE        nan   MAE        nan   Time 604.583502 ms
# Sample size    128   iteration number   1381   MSE        nan   MAE        nan   Time 570.665121 ms
# Sample size    128   iteration number   1391   MSE        nan   MAE        nan   Time 594.322920 ms
# Sample size    128   iteration number   1401   MSE        nan   MAE        nan   Time 571.838140 ms
# Sample size    128   iteration number   1411   MSE        nan   MAE        nan   Time 611.962080 ms
# Sample size    128   iteration number   1421   MSE        nan   MAE        nan   Time 964.631319 ms
# Sample size    128   iteration number   1431   MSE        nan   MAE        nan   Time 630.673885 ms
# Sample size    128   iteration number   1441   MSE        nan   MAE        nan   Time 504.449606 ms
# Sample size    128   iteration number   1451   MSE        nan   MAE        nan   Time 490.107536 ms
# Sample size    128   iteration number   1461   MSE        nan   MAE        nan   Time 529.082775 ms
# Sample size    128   iteration number   1471   MSE        nan   MAE        nan   Time 433.741093 ms
# Sample size    128   iteration number   1481   MSE        nan   MAE        nan   Time 454.356432 ms
# Sample size    128   iteration number   1491   MSE        nan   MAE        nan   Time 495.927572 ms
# Sample size    128   iteration number   1501   MSE        nan   MAE        nan   Time 442.593336 ms
# Sample size    128   iteration number   1511   MSE        nan   MAE        nan   Time 525.446653 ms
# Sample size    128   iteration number   1521   MSE        nan   MAE        nan   Time 673.925638 ms
# Sample size    128   iteration number   1531   MSE        nan   MAE        nan   Time 593.077183 ms
# Sample size    128   iteration number   1541   MSE        nan   MAE        nan   Time 623.624325 ms
# Sample size    128   iteration number   1551   MSE        nan   MAE        nan   Time 715.080261 ms
# Sample size    128   iteration number   1561   MSE        nan   MAE        nan   Time 462.033272 ms
# Sample size    128   iteration number   1571   MSE        nan   MAE        nan   Time 472.569942 ms
# Sample size    128   iteration number   1581   MSE        nan   MAE        nan   Time 595.241785 ms
# Sample size    128   iteration number   1591   MSE        nan   MAE        nan   Time 705.768585 ms
# C:\Users\fap_9\AppData\Local\Temp\ipykernel_44372\2641657375.py:64: RuntimeWarning: overflow encountered in multiply
#   X = X + C1 * X + C2 * X**3 + C3 * gauss(batch_size)
# Sample size    128   iteration number   1601   MSE        nan   MAE        nan   Time 555.569649 ms
# Sample size    128   iteration number   1611   MSE        nan   MAE        nan   Time 443.480968 ms
# Sample size    128   iteration number   1621   MSE        nan   MAE        nan   Time 438.658714 ms
# Sample size    128   iteration number   1631   MSE        nan   MAE        nan   Time 420.367956 ms
# Sample size    128   iteration number   1641   MSE        nan   MAE        nan   Time 437.936306 ms
# Sample size    128   iteration number   1651   MSE        nan   MAE        nan   Time 462.287188 ms
# Sample size    128   iteration number   1661   MSE        nan   MAE        nan   Time 424.869537 ms
# Sample size    128   iteration number   1671   MSE        nan   MAE        nan   Time 689.366102 ms
# Sample size    128   iteration number   1681   MSE        nan   MAE        nan   Time 433.509588 ms
# Sample size    128   iteration number   1691   MSE        nan   MAE        nan   Time 448.169947 ms
# Sample size    128   iteration number   1701   MSE        nan   MAE        nan   Time 438.616037 ms
# Sample size    128   iteration number   1711   MSE        nan   MAE        nan   Time 457.988977 ms
# Sample size    128   iteration number   1721   MSE        nan   MAE        nan   Time 443.970680 ms
# Sample size    128   iteration number   1731   MSE        nan   MAE        nan   Time 471.097946 ms
# Sample size    128   iteration number   1741   MSE        nan   MAE        nan   Time 533.912659 ms
# Sample size    128   iteration number   1751   MSE        nan   MAE        nan   Time 451.148510 ms
# Sample size    128   iteration number   1761   MSE        nan   MAE        nan   Time 487.372875 ms
# Sample size    128   iteration number   1771   MSE        nan   MAE        nan   Time 478.631735 ms
# Sample size    128   iteration number   1781   MSE        nan   MAE        nan   Time 435.377598 ms
# Sample size    128   iteration number   1791   MSE        nan   MAE        nan   Time 478.770494 ms
# Sample size    128   iteration number   1801   MSE        nan   MAE        nan   Time 519.281626 ms
# Sample size    128   iteration number   1811   MSE        nan   MAE        nan   Time 455.220222 ms
# Sample size    128   iteration number   1821   MSE        nan   MAE        nan   Time 466.884375 ms
# Sample size    128   iteration number   1831   MSE        nan   MAE        nan   Time 437.721729 ms
# Sample size    128   iteration number   1841   MSE        nan   MAE        nan   Time 443.664074 ms
# Sample size    128   iteration number   1851   MSE        nan   MAE        nan   Time 511.637688 ms
# Sample size    128   iteration number   1861   MSE        nan   MAE        nan   Time 675.454140 ms
# Sample size    128   iteration number   1871   MSE        nan   MAE        nan   Time 569.590807 ms
# Sample size    128   iteration number   1881   MSE        nan   MAE        nan   Time 498.048306 ms
# Sample size    128   iteration number   1891   MSE        nan   MAE        nan   Time 485.836506 ms
# Sample size    128   iteration number   1901   MSE        nan   MAE        nan   Time 472.733498 ms
# Sample size    128   iteration number   1911   MSE        nan   MAE        nan   Time 449.235916 ms
# Sample size    128   iteration number   1921   MSE        nan   MAE        nan   Time 507.155180 ms
# Sample size    128   iteration number   1931   MSE        nan   MAE        nan   Time 602.970839 ms
# Sample size    128   iteration number   1941   MSE        nan   MAE        nan   Time 444.429636 ms
# Sample size    128   iteration number   1951   MSE        nan   MAE        nan   Time 565.025806 ms
# Sample size    128   iteration number   1961   MSE        nan   MAE        nan   Time 555.899143 ms
# Sample size    128   iteration number   1971   MSE        nan   MAE        nan   Time 467.710495 ms
# Sample size    128   iteration number   1981   MSE        nan   MAE        nan   Time 557.601452 ms
# Sample size    128   iteration number   1991   MSE        nan   MAE        nan   Time 614.227772 ms
# Sample size    128   iteration number   2001   MSE        nan   MAE        nan   Time 625.225544 ms
# Sample size    512   iteration number      1   MSE        nan   MAE        nan   Time 2083.741665 ms
# Sample size    512   iteration number     11   MSE        nan   MAE        nan   Time 2301.466465 ms
# Sample size    512   iteration number     21   MSE        nan   MAE        nan   Time 1995.380640 ms
# Sample size    512   iteration number     31   MSE        nan   MAE        nan   Time 1965.389490 ms
# Sample size    512   iteration number     41   MSE        nan   MAE        nan   Time 1404.389858 ms
# Sample size    512   iteration number     51   MSE        nan   MAE        nan   Time 1369.457960 ms
# Sample size    512   iteration number     61   MSE        nan   MAE        nan   Time 2036.639690 ms
# Sample size    512   iteration number     71   MSE        nan   MAE        nan   Time 1952.505589 ms
# Sample size    512   iteration number     81   MSE        nan   MAE        nan   Time 1963.622808 ms
# Sample size    512   iteration number     91   MSE        nan   MAE        nan   Time 1837.543488 ms
# Sample size    512   iteration number    101   MSE        nan   MAE        nan   Time 1863.300085 ms
# Sample size    512   iteration number    111   MSE        nan   MAE        nan   Time 1885.278225 ms
# Sample size    512   iteration number    121   MSE        nan   MAE        nan   Time 1863.196135 ms
# Sample size    512   iteration number    131   MSE        nan   MAE        nan   Time 1364.968538 ms
# Sample size    512   iteration number    141   MSE        nan   MAE        nan   Time 1357.503891 ms
# Sample size    512   iteration number    151   MSE        nan   MAE        nan   Time 1429.030895 ms
# Sample size    512   iteration number    161   MSE        nan   MAE        nan   Time 1337.813616 ms
# Sample size    512   iteration number    171   MSE        nan   MAE        nan   Time 1426.493645 ms
# Sample size    512   iteration number    181   MSE        nan   MAE        nan   Time 1459.551573 ms
# Sample size    512   iteration number    191   MSE        nan   MAE        nan   Time 1372.060537 ms
# Sample size    512   iteration number    201   MSE        nan   MAE        nan   Time 1412.339449 ms
# Sample size    512   iteration number    211   MSE        nan   MAE        nan   Time 1391.233683 ms
# Sample size    512   iteration number    221   MSE        nan   MAE        nan   Time 1375.104189 ms
# Sample size    512   iteration number    231   MSE        nan   MAE        nan   Time 1490.120173 ms
# Sample size    512   iteration number    241   MSE        nan   MAE        nan   Time 1860.841036 ms
# Sample size    512   iteration number    251   MSE        nan   MAE        nan   Time 1649.428606 ms
# Sample size    512   iteration number    261   MSE        nan   MAE        nan   Time 1614.278555 ms
# Sample size    512   iteration number    271   MSE        nan   MAE        nan   Time 1511.048317 ms
# Sample size    512   iteration number    281   MSE        nan   MAE        nan   Time 1951.804399 ms
# Sample size    512   iteration number    291   MSE        nan   MAE        nan   Time 1976.022959 ms
# Sample size    512   iteration number    301   MSE        nan   MAE        nan   Time 1597.601175 ms
# Sample size    512   iteration number    311   MSE        nan   MAE        nan   Time 1732.138157 ms
# Sample size    512   iteration number    321   MSE        nan   MAE        nan   Time 1803.212404 ms
# Sample size    512   iteration number    331   MSE        nan   MAE        nan   Time 1645.313740 ms
# Sample size    512   iteration number    341   MSE        nan   MAE        nan   Time 1667.515993 ms
# Sample size    512   iteration number    351   MSE        nan   MAE        nan   Time 1504.188061 ms
# Sample size    512   iteration number    361   MSE        nan   MAE        nan   Time 1413.377047 ms
# Sample size    512   iteration number    371   MSE        nan   MAE        nan   Time 1448.861837 ms
# Sample size    512   iteration number    381   MSE        nan   MAE        nan   Time 2092.821360 ms
# Sample size    512   iteration number    391   MSE        nan   MAE        nan   Time 1520.697355 ms
# Sample size    512   iteration number    401   MSE        nan   MAE        nan   Time 1670.776606 ms
# Sample size    512   iteration number    411   MSE        nan   MAE        nan   Time 1939.841747 ms
# Sample size    512   iteration number    421   MSE        nan   MAE        nan   Time 1522.758245 ms
# Sample size    512   iteration number    431   MSE        nan   MAE        nan   Time 1628.097296 ms
# Sample size    512   iteration number    441   MSE        nan   MAE        nan   Time 1956.405163 ms
# Sample size    512   iteration number    451   MSE        nan   MAE        nan   Time 1568.769693 ms
# Sample size    512   iteration number    461   MSE        nan   MAE        nan   Time 1913.744450 ms
# Sample size    512   iteration number    471   MSE        nan   MAE        nan   Time 1374.215364 ms
# Sample size    512   iteration number    481   MSE        nan   MAE        nan   Time 1699.379444 ms
# Sample size    512   iteration number    491   MSE        nan   MAE        nan   Time 1465.850353 ms
# Sample size    512   iteration number    501   MSE        nan   MAE        nan   Time 1435.945034 ms
# Sample size    512   iteration number    511   MSE        nan   MAE        nan   Time 1859.015703 ms
# Sample size    512   iteration number    521   MSE        nan   MAE        nan   Time 1564.852238 ms
# Sample size    512   iteration number    531   MSE        nan   MAE        nan   Time 1530.180454 ms
# Sample size    512   iteration number    541   MSE        nan   MAE        nan   Time 1403.271437 ms
# Sample size    512   iteration number    551   MSE        nan   MAE        nan   Time 1536.783934 ms
# Sample size    512   iteration number    561   MSE        nan   MAE        nan   Time 1716.274977 ms
# Sample size    512   iteration number    571   MSE        nan   MAE        nan   Time 1645.168304 ms
# Sample size    512   iteration number    581   MSE        nan   MAE        nan   Time 1679.247856 ms
# Sample size    512   iteration number    591   MSE        nan   MAE        nan   Time 2261.087656 ms
# Sample size    512   iteration number    601   MSE        nan   MAE        nan   Time 1680.904388 ms
# Sample size    512   iteration number    611   MSE        nan   MAE        nan   Time 1646.233320 ms
# Sample size    512   iteration number    621   MSE        nan   MAE        nan   Time 1728.656054 ms
# Sample size    512   iteration number    631   MSE        nan   MAE        nan   Time 2168.613434 ms
# Sample size    512   iteration number    641   MSE        nan   MAE        nan   Time 1571.317434 ms
# Sample size    512   iteration number    651   MSE        nan   MAE        nan   Time 1794.291735 ms
# Sample size    512   iteration number    661   MSE        nan   MAE        nan   Time 1464.614153 ms
# Sample size    512   iteration number    671   MSE        nan   MAE        nan   Time 2159.311533 ms
# Sample size    512   iteration number    681   MSE        nan   MAE        nan   Time 1591.161489 ms
# Sample size    512   iteration number    691   MSE        nan   MAE        nan   Time 1591.954947 ms
# Sample size    512   iteration number    701   MSE        nan   MAE        nan   Time 1530.486345 ms
# Sample size    512   iteration number    711   MSE        nan   MAE        nan   Time 1908.528090 ms
# Sample size    512   iteration number    721   MSE        nan   MAE        nan   Time 1537.014484 ms
# Sample size    512   iteration number    731   MSE        nan   MAE        nan   Time 1710.815668 ms
# Sample size    512   iteration number    741   MSE        nan   MAE        nan   Time 2212.386608 ms
# Sample size    512   iteration number    751   MSE        nan   MAE        nan   Time 1910.147667 ms
# Sample size    512   iteration number    761   MSE        nan   MAE        nan   Time 1881.161690 ms
# Sample size    512   iteration number    771   MSE        nan   MAE        nan   Time 2253.787279 ms
# Sample size    512   iteration number    781   MSE        nan   MAE        nan   Time 1855.559826 ms
# Sample size    512   iteration number    791   MSE        nan   MAE        nan   Time 1835.532188 ms
# Sample size    512   iteration number    801   MSE        nan   MAE        nan   Time 1392.189264 ms
# Sample size    512   iteration number    811   MSE        nan   MAE        nan   Time 1356.851339 ms
# Sample size    512   iteration number    821   MSE        nan   MAE        nan   Time 1335.637093 ms
# Sample size    512   iteration number    831   MSE        nan   MAE        nan   Time 1369.118214 ms
# Sample size    512   iteration number    841   MSE        nan   MAE        nan   Time 1482.987404 ms
# Sample size    512   iteration number    851   MSE        nan   MAE        nan   Time 1487.293720 ms
# Sample size    512   iteration number    861   MSE        nan   MAE        nan   Time 1548.237801 ms
# Sample size    512   iteration number    871   MSE        nan   MAE        nan   Time 2213.891983 ms
# Sample size    512   iteration number    881   MSE        nan   MAE        nan   Time 2021.278381 ms
# Sample size    512   iteration number    891   MSE        nan   MAE        nan   Time 1875.231981 ms
# Sample size    512   iteration number    901   MSE        nan   MAE        nan   Time 1881.543875 ms
# Sample size    512   iteration number    911   MSE        nan   MAE        nan   Time 1798.468590 ms
# Sample size    512   iteration number    921   MSE        nan   MAE        nan   Time 1494.294167 ms
# Sample size    512   iteration number    931   MSE        nan   MAE        nan   Time 1767.087936 ms
# Sample size    512   iteration number    941   MSE        nan   MAE        nan   Time 1535.793066 ms
# Sample size    512   iteration number    951   MSE        nan   MAE        nan   Time 1557.479858 ms
# Sample size    512   iteration number    961   MSE        nan   MAE        nan   Time 1705.873013 ms
# Sample size    512   iteration number    971   MSE        nan   MAE        nan   Time 1839.750051 ms
# Sample size    512   iteration number    981   MSE        nan   MAE        nan   Time 2368.486643 ms
# Sample size    512   iteration number    991   MSE        nan   MAE        nan   Time 2097.810984 ms
# Sample size    512   iteration number   1001   MSE        nan   MAE        nan   Time 2282.990932 ms
# CPU times: total: 15min 51s
# Wall time: 56min 10s

# %% [markdown]
# #### TEST MODEL

# %%
# %%time

number_of_predictions_to_show = 1000
prediction_GRU_test = test_performance(simulate_trajectory, networkGRU, rescale_targets, number_of_predictions_to_show)
# Out:
# C:\Users\fap_9\AppData\Local\Temp\ipykernel_44372\2641657375.py:64: RuntimeWarning: overflow encountered in power
#   X = X + C1 * X + C2 * X**3 + C3 * gauss(batch_size)
# C:\Users\fap_9\AppData\Local\Temp\ipykernel_44372\2641657375.py:64: RuntimeWarning: invalid value encountered in add
#   X = X + C1 * X + C2 * X**3 + C3 * gauss(batch_size)
# C:\Users\fap_9\AppData\Local\Temp\ipykernel_44372\2641657375.py:68: RuntimeWarning: overflow encountered in power
#   X = X + C1 * X + C2 * X**3 + C3 * gauss(batch_size)
# C:\Users\fap_9\AppData\Local\Temp\ipykernel_44372\2641657375.py:68: RuntimeWarning: invalid value encountered in add
#   X = X + C1 * X + C2 * X**3 + C3 * gauss(batch_size)
# 1/1 [==============================] - 1s 869ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 57ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 57ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 58ms/step
# 1/1 [==============================] - 0s 60ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 57ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 57ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 54ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 57ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 60ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 54ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 56ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 57ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 54ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 59ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 54ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 56ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 31ms/step
# CPU times: total: 40.7 s
# Wall time: 1min 22s

# %% [markdown]
# #### Save data

# %%
# save train data

# %% [markdown]
# ### Plot results

# %%
### Plot learning performance
number_of_timesteps_for_average = 100
plot_learning_performance(training_history_GRU, number_of_timesteps_for_average)

# %%
### Plot test performance
plot_test_performance(prediction_GRU_test[0], prediction_GRU_test[1], prediction_GRU_test[2], prediction_GRU_test[3], network)
